# %%
#MONGO HW - Ashley Nguyen (rhw9tv)

# %%
# !pip install --upgrade pymongo certifi
# Out:
# Requirement already satisfied: pymongo in c:\users\nguye\anaconda3\lib\site-packages (4.10.1)
# Requirement already satisfied: certifi in c:\users\nguye\anaconda3\lib\site-packages (2024.8.30)
# Requirement already satisfied: dnspython<3.0.0,>=1.16.0 in c:\users\nguye\anaconda3\lib\site-packages (from pymongo) (2.6.1)

# %%
# Import necessary libraries
from pymongo import MongoClient
import pprint

# Replace with your MongoDB Atlas connection string
connection_string = "mongodb+srv://awesomeashleyn:atlas@cluster0.upnq3.mongodb.net/test?retryWrites=true&w=majority"

# Connect to MongoDB Atlas
client = MongoClient(connection_string)

# Access the sample_mflix database and the movies collection
db = client['sample_mflix']
collection = db['movies']

# %% [markdown]
# ## Exercise 1: Basic Searching and Filtering
# Objective: Learn how to search for and filter documents in the MongoDB collection.

# %%
#1. Write a query to find the first movie that has the genre "Action".
action_movie = collection.find_one({"genres": "Action"})
pprint.pprint(action_movie)
# Out:
# {'_id': ObjectId('573a1394f29313caabcde77d'),
#  'awards': {'nominations': 1,
#             'text': 'Won 2 Oscars. Another 2 wins & 1 nomination.',
#             'wins': 4},
#  'cast': ['Deborah Kerr', 'Stewart Granger', 'Richard Carlson', 'Hugo Haas'],
#  'countries': ['USA'],
#  'directors': ['Compton Bennett', 'Andrew Marton'],
#  'fullplot': 'Guide Allan Quatermain helps a young lady (Beth) find her lost '
#              "husband somewhere in Africa. It's a spectacular adventure story "
#              'with romance, because while they fight with wild animals and '
#              'cannibals, they fall in love. Will they find the lost husband '
#              'and finish the nice connection?',
#  'genres': ['Adventure', 'Romance', 'Action'],
#  'imdb': {'id': 42646, 'rating': 6.9, 'votes': 4128},
#  'languages': ['English'],
#  'lastupdated': '2015-08-06 00:32:20.070000000',
#  'num_mflix_comments': 1,
#  'plot': 'Adventurer Allan Quartermain leads an expedition into uncharted '
#          'African territory in an attempt to locate an explorer who went '
#          'missing during his search for the fabled diamond mines of King '
#          'Solomon.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BYjZlOWFjNzktMDQ3OC00ODQxLWEzZjMtN2E0Y2MwM2FkMzE0XkEyXkFqcGdeQXVyNTEwNDcxNDc@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PASSED',
#  'released': datetime.datetime(1950, 11, 24, 0, 0),
#  'runtime': 103,
#  'title': "King Solomon's Mines",
#  'tomatoes': {'critic': {'meter': 92, 'numReviews': 12, 'rating': 7.2},
#               'dvd': datetime.datetime(2005, 1, 11, 0, 0),
#               'fresh': 11,
#               'lastUpdated': datetime.datetime(2015, 9, 10, 19, 11, 25),
#               'production': 'MGM Home Entertainment',
#               'rotten': 1,
#               'viewer': {'meter': 60, 'numReviews': 3186, 'rating': 3.3}},
#  'type': 'movie',
#  'writers': ['Helen Deutsch (screenplay)', 'H. Rider Haggard (novel)'],
#  'year': 1950}

# %%
#2. Write a query to find all movies released after the year 2000 (Return the first 5 results).
movies_after_2000 = collection.find({"year": {"$gt": 2000}}).limit(5)

for movie in movies_after_2000:
    pprint.pprint(movie)
# Out:
# {'_id': ObjectId('573a1393f29313caabcdcb42'),
#  'awards': {'nominations': 4,
#             'text': 'Nominated for 1 Oscar. Another 1 win & 4 nominations.',
#             'wins': 2},
#  'cast': ['Meg Ryan', 'Hugh Jackman', 'Liev Schreiber', 'Breckin Meyer'],
#  'countries': ['USA'],
#  'directors': ['James Mangold'],
#  'fullplot': 'Kate and her actor brother live in N.Y. in the 21st Century. Her '
#              'ex-boyfriend, Stuart, lives above her apartment. Stuart finds a '
#              'space near the Brooklyn Bridge where there is a gap in time. He '
#              'goes back to the 19th Century and takes pictures of the place. '
#              "Leopold -- a man living in the 1870s -- is puzzled by Stuart's "
#              'tiny camera, follows him back through the gap, and they both '
#              'ended up in the present day. Leopold is clueless about his new '
#              'surroundings. He gets help and insight from Charlie who thinks '
#              'that Leopold is an actor who is always in character. Leopold is '
#              'a highly intelligent man and tries his best to learn and even '
#              'improve the modern conveniences that he encounters.',
#  'genres': ['Comedy', 'Fantasy', 'Romance'],
#  'imdb': {'id': 35423, 'rating': 6.3, 'votes': 59951},
#  'languages': ['English', 'French'],
#  'lastupdated': '2015-08-31 00:19:09.717000000',
#  'metacritic': 44,
#  'num_mflix_comments': 0,
#  'plot': 'Kate and her actor brother live in N.Y. in the 21st Century. Her '
#          'ex-boyfriend, Stuart, lives above her apartment. Stuart finds a '
#          'space near the Brooklyn Bridge where there is a gap in time....',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNmNlN2VlOTctYTdhMS00NzUxLTg0ZGMtYWE2ZTJmMThlMTk2XkEyXkFqcGdeQXVyMzI0NDc4ODY@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2001, 12, 25, 0, 0),
#  'runtime': 118,
#  'title': 'Kate & Leopold',
#  'tomatoes': {'boxOffice': '$47.1M',
#               'consensus': 'Though Jackman charms, Kate and Leopold is bland '
#                            'and predictable, and the time travel scenario '
#                            'lacks inner logic.',
#               'critic': {'meter': 50, 'numReviews': 126, 'rating': 5.3},
#               'dvd': datetime.datetime(2002, 6, 11, 0, 0),
#               'fresh': 63,
#               'lastUpdated': datetime.datetime(2015, 8, 22, 18, 53, 25),
#               'production': 'Miramax Films',
#               'rotten': 63,
#               'viewer': {'meter': 62, 'numReviews': 189426, 'rating': 3.0},
#               'website': 'http://www.kateandleopold-themovie.com'},
#  'type': 'movie',
#  'writers': ['Steven Rogers (story)',
#              'James Mangold (screenplay)',
#              'Steven Rogers (screenplay)'],
#  'year': 2001}
# {'_id': ObjectId('573a139af29313caabcf0718'),
#  'awards': {'nominations': 8, 'text': '1 win & 8 nominations.', 'wins': 1},
#  'cast': ['Mariah Carey', 'Max Beesley', 'Da Brat', 'Tia Texada'],
#  'countries': ['USA'],
#  'directors': ['Vondie Curtis-Hall'],
#  'fullplot': 'Billie Frank is a shy, young multiracial girl who is sent away '
#              'by her alcoholic mother at a very early age. At an orphanage, '
#              'she befriends Louise and Roxanne. Flash forward to 1983. Billie '
#              'and her friends are spotted by a record producer, Timothy '
#              'Walker, who wants them to sing backup for his latest pop-music '
#              "discovery. But when super DJ Julian Dice hears Billie's "
#              'incredible voice, he makes a shady deal with Timothy to get her '
#              'out of that dead-end situation. Soon, Billie and Dice are making '
#              'hits inside the studio, and falling in love outside of it. '
#              'Eventually, the pressure of her newfound celebrity puts too '
#              'heavy a strain on Billie, forcing her to decide what it is she '
#              'really wants from Dice, and what she wants for herself.',
#  'genres': ['Drama', 'Music', 'Romance'],
#  'imdb': {'id': 118589, 'rating': 2.1, 'votes': 18840},
#  'languages': ['English'],
#  'lastupdated': '2015-08-21 00:47:31.610000000',
#  'metacritic': 14,
#  'num_mflix_comments': 0,
#  'plot': 'A young singer dates a disc jockey who helps her get into the music '
#          'business, but their relationship become complicated as she ascends '
#          'to super stardom.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMGJkN2IxNTYtZDE1OS00MWJhLWFhNzItNTZkMjM4OGUzMTE2L2ltYWdlXkEyXkFqcGdeQXVyNTg3MTc4ODY@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2001, 9, 21, 0, 0),
#  'runtime': 104,
#  'title': 'Glitter',
#  'tomatoes': {'boxOffice': '$3.9M',
#               'consensus': 'Glitter is a hodgepodge of movie cliches and bad '
#                            "acting that's sure to generate unintentional "
#                            'laughs. Unfortunately, the movie is not bad enough '
#                            'to be good.',
#               'critic': {'meter': 7, 'numReviews': 87, 'rating': 2.8},
#               'dvd': datetime.datetime(2002, 1, 15, 0, 0),
#               'fresh': 6,
#               'lastUpdated': datetime.datetime(2015, 9, 10, 18, 37, 3),
#               'production': '20th Century Fox',
#               'rotten': 81,
#               'viewer': {'meter': 45, 'numReviews': 44284, 'rating': 2.1},
#               'website': 'http://216.133.243.94'},
#  'type': 'movie',
#  'writers': ['Cheryl L. West (story)', 'Kate Lanier (screenplay)'],
#  'year': 2001}
# {'_id': ObjectId('573a139af29313caabcf0eb3'),
#  'awards': {'nominations': 8, 'text': '8 nominations.', 'wins': 0},
#  'cast': ['Johnny Depp', 'Heather Graham', 'Ian Holm', 'Robbie Coltrane'],
#  'countries': ['USA'],
#  'directors': ['Albert Hughes', 'Allen Hughes'],
#  'fullplot': 'It is 1888 in London, and the unfortunate poor lead horrifying '
#              "lives in the city's deadliest slum, Whitechapel. Harassed by "
#              'gangs and forced to walk the streets for a living, Mary Kelly '
#              'and her small group of companions trudge on through this daily '
#              "misery, their only consolation being that things can't get any "
#              'worse. Yet things somehow do when their friend Ann is kidnapped '
#              'and they are drawn into a conspiracy with links higher up than '
#              'they could possibly imagine. The kidnapping is soon followed by '
#              'the gruesome murder of another woman, Polly, and it becomes '
#              'apparent that they are being hunted down, one by one. Sinister '
#              'even by Whitechapel standards, the murder grabs the attention of '
#              'Inspector Fred Abberline, a brilliant yet troubled man whose '
#              'police work is often aided by his psychic abilities. Abberline '
#              'becomes deeply involved with the case, which takes on personal '
#              'meaning to him when he and Mary begin to fall in love. But as he '
#              'gets closer to the truth Whitechapel becomes more and more '
#              'dangerous for Abberline, Mary, and the other girls. Whoever is '
#              'responsible for the grisly acts is not going to give up his '
#              'secret without a fight....will they be able to survive the '
#              'avenging force that has been sent after them from hell?',
#  'genres': ['Horror', 'Mystery', 'Thriller'],
#  'imdb': {'id': 120681, 'rating': 6.8, 'votes': 116865},
#  'languages': ['English'],
#  'lastupdated': '2015-09-10 17:03:00.390000000',
#  'metacritic': 54,
#  'num_mflix_comments': 1,
#  'plot': 'In Victorian Era London, a troubled clairvoyant police detective '
#          'investigates the murders by Jack The Ripper.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTM1MjkxNTQxMV5BMl5BanBnXkFtZTYwMDMxNDg2._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2001, 10, 19, 0, 0),
#  'runtime': 122,
#  'title': 'From Hell',
#  'tomatoes': {'boxOffice': '$30.7M',
#               'consensus': 'Visually impressive, but this latest Ripper tale '
#                            'is dull and far from scary.',
#               'critic': {'meter': 57, 'numReviews': 150, 'rating': 5.7},
#               'dvd': datetime.datetime(2002, 5, 14, 0, 0),
#               'fresh': 86,
#               'lastUpdated': datetime.datetime(2015, 9, 12, 17, 58, 48),
#               'production': '20th Century Fox',
#               'rotten': 64,
#               'viewer': {'meter': 66, 'numReviews': 202710, 'rating': 3.3},
#               'website': 'http://www.fromhellmovie.com'},
#  'type': 'movie',
#  'writers': ['Alan Moore (graphic novel)',
#              'Eddie Campbell (graphic novel)',
#              'Terry Hayes (screenplay)',
#              'Rafael Yglesias (screenplay)'],
#  'year': 2001}
# {'_id': ObjectId('573a139af29313caabcf0ec0'),
#  'awards': {'nominations': 4,
#             'text': 'Nominated for 1 Oscar. Another 1 win & 4 nominations.',
#             'wins': 2},
#  'cast': ['Meg Ryan', 'Hugh Jackman', 'Liev Schreiber', 'Breckin Meyer'],
#  'countries': ['USA'],
#  'directors': ['James Mangold'],
#  'fullplot': 'Kate and her actor brother live in N.Y. in the 21st Century. Her '
#              'ex-boyfriend, Stuart, lives above her apartment. Stuart finds a '
#              'space near the Brooklyn Bridge where there is a gap in time. He '
#              'goes back to the 19th Century and takes pictures of the place. '
#              "Leopold -- a man living in the 1870s -- is puzzled by Stuart's "
#              'tiny camera, follows him back through the gap, and they both '
#              'ended up in the present day. Leopold is clueless about his new '
#              'surroundings. He gets help and insight from Charlie who thinks '
#              'that Leopold is an actor who is always in character. Leopold is '
#              'a highly intelligent man and tries his best to learn and even '
#              'improve the modern conveniences that he encounters.',
#  'genres': ['Comedy', 'Fantasy', 'Romance'],
#  'imdb': {'id': 35423, 'rating': 6.3, 'votes': 59924},
#  'languages': ['English', 'French'],
#  'lastupdated': '2015-08-29 07:39:50.323000000',
#  'metacritic': 44,
#  'num_mflix_comments': 0,
#  'plot': 'Kate and her actor brother live in N.Y. in the 21st Century. Her '
#          'ex-boyfriend, Stuart, lives above her apartment. Stuart finds a '
#          'space near the Brooklyn Bridge where there is a gap in time....',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNmNlN2VlOTctYTdhMS00NzUxLTg0ZGMtYWE2ZTJmMThlMTk2XkEyXkFqcGdeQXVyMzI0NDc4ODY@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2001, 12, 25, 0, 0),
#  'runtime': 118,
#  'title': 'Kate & Leopold',
#  'tomatoes': {'boxOffice': '$47.1M',
#               'consensus': 'Though Jackman charms, Kate and Leopold is bland '
#                            'and predictable, and the time travel scenario '
#                            'lacks inner logic.',
#               'critic': {'meter': 50, 'numReviews': 126, 'rating': 5.3},
#               'dvd': datetime.datetime(2002, 6, 11, 0, 0),
#               'fresh': 63,
#               'lastUpdated': datetime.datetime(2015, 8, 22, 18, 53, 25),
#               'production': 'Miramax Films',
#               'rotten': 63,
#               'viewer': {'meter': 62, 'numReviews': 189426, 'rating': 3.0},
#               'website': 'http://www.kateandleopold-themovie.com'},
#  'type': 'movie',
#  'writers': ['Steven Rogers (story)',
#              'James Mangold (screenplay)',
#              'Steven Rogers (screenplay)'],
#  'year': 2001}
# {'_id': ObjectId('573a139af29313caabcf0f11'),
#  'awards': {'nominations': 10,
#             'text': 'Nominated for 2 Golden Globes. Another 2 wins & 10 '
#                     'nominations.',
#             'wins': 4},
#  'cast': ['Kevin Spacey', 'Julianne Moore', 'Judi Dench', 'Cate Blanchett'],
#  'countries': ['USA'],
#  'directors': ['Lasse Hallstrèm'],
#  'fullplot': "An inksetter in New York, Quoyle returns to his family's "
#              'longtime home, a small fishing town in Newfoundland, with his '
#              'young daughter, after a traumatizing experience with her mother, '
#              'Petal, who sold her to an illegal adoption agency. Though Quoyle '
#              'has had little success thus far in life, his shipping news '
#              'column in the newspaper "The Gammy Bird" finds an audience, and '
#              'his experiences in the town change his life. Then he meets the '
#              'widow Wavey...',
#  'genres': ['Drama'],
#  'imdb': {'id': 120824, 'rating': 6.8, 'votes': 27231},
#  'languages': ['English'],
#  'lastupdated': '2015-09-15 02:07:34.900000000',
#  'metacritic': 47,
#  'num_mflix_comments': 1,
#  'plot': 'An emotionally-beaten man with his young daughter moves to his '
#          'ancestral home in Newfoundland to reclaim his life.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNWEwMmNiNjctNDY5ZC00NDIyLWFiZDctNDdlZGU5NjA0MzA2L2ltYWdlXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2002, 1, 18, 0, 0),
#  'runtime': 111,
#  'title': 'The Shipping News',
#  'tomatoes': {'boxOffice': '$11.4M',
#               'consensus': 'Though solidly made and acted, The Shipping News '
#                            'is rather heavy-handed and dull, especially given '
#                            'the nature of its protagonist.',
#               'critic': {'meter': 55, 'numReviews': 130, 'rating': 5.8},
#               'dvd': datetime.datetime(2002, 6, 18, 0, 0),
#               'fresh': 72,
#               'lastUpdated': datetime.datetime(2015, 9, 16, 20, 33, 40),
#               'production': 'Miramax Films',
#               'rotten': 58,
#               'viewer': {'meter': 62, 'numReviews': 20587, 'rating': 3.2},
#               'website': 'http://www.miramaxhighlights.com/theshippingnews/index.html'},
#  'type': 'movie',
#  'writers': ['Annie Proulx (based on the novel by)',
#              'Robert Nelson Jacobs (screenplay)'],
#  'year': 2001}

# %%
#3. Write a query to find all movies where the IMDb rating is greater than 8.5 (Return the first 5 results).
high_rated_movies = collection.find({"imdb.rating": {"$gt": 8.5}}).limit(5)

for movie in high_rated_movies:
    pprint.pprint(movie)
# Out:
# {'_id': ObjectId('573a1394f29313caabcdfa00'),
#  'awards': {'nominations': 7,
#             'text': 'Nominated for 4 Oscars. Another 7 wins & 7 nominations.',
#             'wins': 11},
#  'cast': ['James Stewart', 'Grace Kelly', 'Wendell Corey', 'Thelma Ritter'],
#  'countries': ['USA'],
#  'directors': ['Alfred Hitchcock'],
#  'fullplot': 'Professional photographer L.B. "Jeff" Jeffries breaks his leg '
#              'while getting an action shot at an auto race. Confined to his '
#              'New York apartment, he spends his time looking out of the rear '
#              'window observing the neighbors. He begins to suspect that a man '
#              'across the courtyard may have murdered his wife. Jeff enlists '
#              'the help of his high society fashion-consultant girlfriend Lisa '
#              'Freemont and his visiting nurse Stella to investigate.',
#  'genres': ['Mystery', 'Thriller'],
#  'imdb': {'id': 47396, 'rating': 8.6, 'votes': 283273},
#  'languages': ['English'],
#  'lastupdated': '2015-08-31 00:31:57.327000000',
#  'num_mflix_comments': 1,
#  'plot': 'A wheelchair bound photographer spies on his neighbours from his '
#          'apartment window and becomes convinced one of them has committed '
#          'murder.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNGUxYWM3M2MtMGM3Mi00ZmRiLWE0NGQtZjE5ODI2OTJhNTU0XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'APPROVED',
#  'runtime': 112,
#  'title': 'Rear Window',
#  'tomatoes': {'consensus': 'Hitchcock exerted full potential of suspense in '
#                            'this masterpiece.',
#               'critic': {'meter': 100, 'numReviews': 63, 'rating': 8.9},
#               'dvd': datetime.datetime(2001, 3, 6, 0, 0),
#               'fresh': 63,
#               'lastUpdated': datetime.datetime(2015, 9, 12, 18, 7, 38),
#               'production': 'Paramount Pictures',
#               'rotten': 0,
#               'viewer': {'meter': 95, 'numReviews': 147500, 'rating': 4.2}},
#  'type': 'movie',
#  'writers': ['John Michael Hayes (screenplay)',
#              'Cornell Woolrich (based on the short story by)'],
#  'year': 1954}
# {'_id': ObjectId('573a1395f29313caabce144b'),
#  'awards': {'nominations': 5,
#             'text': 'Nominated for 4 Oscars. Another 7 wins & 5 nominations.',
#             'wins': 11},
#  'cast': ['Anthony Perkins', 'Vera Miles', 'John Gavin', 'Janet Leigh'],
#  'countries': ['USA'],
#  'directors': ['Alfred Hitchcock'],
#  'fullplot': 'Phoenix officeworker Marion Crane is fed up with the way life '
#              'has treated her. She has to meet her lover Sam in lunch breaks '
#              'and they cannot get married because Sam has to give most of his '
#              'money away in alimony. One Friday Marion is trusted to bank '
#              '$40,000 by her employer. Seeing the opportunity to take the '
#              'money and start a new life, Marion leaves town and heads towards '
#              "Sam's California store. Tired after the long drive and caught in "
#              'a storm, she gets off the main highway and pulls into The Bates '
#              'Motel. The motel is managed by a quiet young man called Norman '
#              'who seems to be dominated by his mother.',
#  'genres': ['Horror', 'Mystery', 'Thriller'],
#  'imdb': {'id': 54215, 'rating': 8.6, 'votes': 376318},
#  'languages': ['English'],
#  'lastupdated': '2015-09-04 00:05:08.977000000',
#  'num_mflix_comments': 0,
#  'plot': "A Phoenix secretary steals $40,000 from her employer's client, goes "
#          'on the run and checks into a remote motel run by a young man under '
#          'the domination of his mother.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNTQwNDM1YzItNDAxZC00NWY2LTk0M2UtNDIwNWI5OGUyNWUxXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(1960, 9, 8, 0, 0),
#  'runtime': 109,
#  'title': 'Psycho',
#  'tomatoes': {'consensus': 'Infamous for its shower scene, but immortal for '
#                            'its contribution to the horror genre. Because '
#                            'Psycho was filmed with tact, grace, and art, '
#                            "Hitchcock didn't just create modern horror, he "
#                            'validated it.',
#               'critic': {'meter': 96, 'numReviews': 84, 'rating': 9.2},
#               'dvd': datetime.datetime(2001, 3, 6, 0, 0),
#               'fresh': 81,
#               'lastUpdated': datetime.datetime(2015, 9, 12, 17, 44, 21),
#               'production': 'Paramount Pictures',
#               'rotten': 3,
#               'viewer': {'meter': 94, 'numReviews': 236029, 'rating': 3.9}},
#  'type': 'movie',
#  'writers': ['Joseph Stefano (screenplay)', 'Robert Bloch (novel)'],
#  'year': 1960}
# {'_id': ObjectId('573a1396f29313caabce39e5'),
#  'awards': {'nominations': 4, 'text': '5 wins & 4 nominations.', 'wins': 5},
#  'cast': ['Claudia Cardinale',
#           'Henry Fonda',
#           'Jason Robards',
#           'Charles Bronson'],
#  'countries': ['Italy', 'USA', 'Spain'],
#  'directors': ['Sergio Leone'],
#  'fullplot': 'Story of a young woman, Mrs. McBain, who moves from New Orleans '
#              'to frontier Utah, on the very edge of the American West. She '
#              'arrives to find her new husband and family slaughtered, but by '
#              'whom? The prime suspect, coffee-lover Cheyenne, befriends her '
#              'and offers to go after the real killer, assassin gang leader '
#              'Frank, in her honor. He is accompanied by Harmonica, a man '
#              'already on a quest to get even.',
#  'genres': ['Western'],
#  'imdb': {'id': 64116, 'rating': 8.6, 'votes': 195109},
#  'languages': ['English', 'Spanish', 'Italian'],
#  'lastupdated': '2015-09-14 00:00:06.893000000',
#  'metacritic': 80,
#  'num_mflix_comments': 1,
#  'plot': 'Epic story of a mysterious stranger with a harmonica who joins '
#          'forces with a notorious desperado to protect a beautiful widow from '
#          'a ruthless assassin working for the railroad.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BZGI5MjBmYzYtMzJhZi00NGI1LTk3MzItYjBjMzcxM2U3MDdiXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(1968, 12, 21, 0, 0),
#  'runtime': 175,
#  'title': 'Once Upon a Time in the West',
#  'tomatoes': {'consensus': 'A landmark Sergio Leone spaghetti western '
#                            'masterpiece featuring a classic Morricone score.',
#               'critic': {'meter': 98, 'numReviews': 54, 'rating': 9.0},
#               'dvd': datetime.datetime(2003, 11, 18, 0, 0),
#               'fresh': 53,
#               'lastUpdated': datetime.datetime(2015, 9, 12, 17, 53, 4),
#               'production': 'Paramount Pictures',
#               'rotten': 1,
#               'viewer': {'meter': 95, 'numReviews': 63662, 'rating': 4.3}},
#  'type': 'movie',
#  'writers': ['Sergio Donati (screenplay)',
#              'Sergio Leone (screenplay)',
#              'Dario Argento (from a story by)',
#              'Bernardo Bertolucci (from a story by)',
#              'Sergio Leone (from a story by)'],
#  'year': 1968}
# {'_id': ObjectId('573a1397f29313caabce5cb3'),
#  'awards': {'nominations': 12,
#             'text': 'Won 5 Oscars. Another 31 wins & 12 nominations.',
#             'wins': 36},
#  'cast': ['Michael Berryman', 'Peter Brocco', 'Dean R. Brooks', 'Alonzo Brown'],
#  'countries': ['USA'],
#  'directors': ['Milos Forman'],
#  'fullplot': 'McMurphy has a criminal past and has once again gotten himself '
#              'into trouble and is sentenced by the court. To escape labor '
#              'duties in prison, McMurphy pleads insanity and is sent to a ward '
#              'for the mentally unstable. Once here, McMurphy both endures and '
#              'stands witness to the abuse and degradation of the oppressive '
#              'Nurse Ratched, who gains superiority and power through the flaws '
#              'of the other inmates. McMurphy and the other inmates band '
#              'together to make a rebellious stance against the atrocious '
#              'Nurse.',
#  'genres': ['Drama'],
#  'imdb': {'id': 73486, 'rating': 8.7, 'votes': 611021},
#  'languages': ['English'],
#  'lastupdated': '2015-08-26 00:01:43.680000000',
#  'metacritic': 79,
#  'num_mflix_comments': 0,
#  'plot': 'Upon admittance to a mental institution, a brash rebel rallies the '
#          'patients to take on the oppressive head nurse.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BZjA0OWVhOTAtYWQxNi00YzNhLWI4ZjYtNjFjZTEyYjJlNDVlL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(1975, 11, 21, 0, 0),
#  'runtime': 133,
#  'title': "One Flew Over the Cuckoo's Nest",
#  'tomatoes': {'consensus': 'The onscreen battle between Jack Nicholson and '
#                            'Louise Fletcher serves as a personal microcosm of '
#                            'the culture wars of the 1970s -- and testament to '
#                            "the director's vision that the film retains its "
#                            'power more than three decades later.',
#               'critic': {'meter': 95, 'numReviews': 58, 'rating': 8.9},
#               'dvd': datetime.datetime(1997, 12, 9, 0, 0),
#               'fresh': 55,
#               'lastUpdated': datetime.datetime(2015, 9, 13, 17, 1, 21),
#               'production': 'United Artists',
#               'rotten': 3,
#               'viewer': {'meter': 96, 'numReviews': 275951, 'rating': 4.2}},
#  'type': 'movie',
#  'writers': ['Lawrence Hauben (screenplay)',
#              'Bo Goldman (screenplay)',
#              'Ken Kesey (based on the novel by)',
#              'Dale Wasserman (the play version: "One Flew Over the Cuckoo\'s '
#              'Nest" by)'],
#  'year': 1975}
# {'_id': ObjectId('573a1396f29313caabce557f'),
#  'awards': {'nominations': 16,
#             'text': 'Won 6 Oscars. Another 13 wins & 16 nominations.',
#             'wins': 19},
#  'cast': ['Al Pacino', 'Robert Duvall', 'Diane Keaton', 'Robert De Niro'],
#  'countries': ['USA'],
#  'directors': ['Francis Ford Coppola'],
#  'fullplot': 'The continuing saga of the Corleone crime family tells the story '
#              'of a young Vito Corleone growing up in Sicily and in 1910s New '
#              'York; and follows Michael Corleone in the 1950s as he attempts '
#              'to expand the family business into Las Vegas, Hollywood and '
#              'Cuba.',
#  'genres': ['Crime', 'Drama'],
#  'imdb': {'id': 71562, 'rating': 9.1, 'votes': 700857},
#  'languages': ['English', 'Italian', 'Spanish', 'Latin', 'Sicilian'],
#  'lastupdated': '2015-09-02 00:15:27.537000000',
#  'metacritic': 80,
#  'num_mflix_comments': 0,
#  'plot': 'The early life and career of Vito Corleone in 1920s New York is '
#          'portrayed while his son, Michael, expands and tightens his grip on '
#          'his crime syndicate stretching from Lake Tahoe, Nevada to '
#          'pre-revolution 1958 Cuba.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMWMwMGQzZTItY2JlNC00OWZiLWIyMDctNDk2ZDQ2YjRjMWQ0XkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(1974, 12, 20, 0, 0),
#  'runtime': 200,
#  'title': 'The Godfather: Part II',
#  'tomatoes': {'consensus': 'Drawing on strong performances by Al Pacino and '
#                            "Robert De Niro, Francis Ford Coppola's "
#                            "continuation of Mario Puzo's Mafia saga set new "
#                            'standards for sequels that have yet to be matched '
#                            'or broken.',
#               'critic': {'meter': 97, 'numReviews': 72, 'rating': 9.5},
#               'dvd': datetime.datetime(2005, 5, 24, 0, 0),
#               'fresh': 70,
#               'lastUpdated': datetime.datetime(2015, 9, 13, 17, 0, 43),
#               'production': 'Paramount Pictures',
#               'rotten': 2,
#               'viewer': {'meter': 97, 'numReviews': 407106, 'rating': 4.3},
#               'website': 'http://www.thegodfather.com/'},
#  'type': 'movie',
#  'writers': ['Francis Ford Coppola (screenplay)',
#              'Mario Puzo (screenplay)',
#              'Mario Puzo (based on the novel "The Godfather" by)'],
#  'year': 1974}

# %%
#4. Write a query to find all movies where the genre contains both "Action" and "Adventure".
action_adventure_movies = collection.find({"genres": {"$all": ["Action",
"Adventure"]}}).limit(5)

for movie in action_adventure_movies:
    pprint.pprint(movie)
# Out:
# {'_id': ObjectId('573a1394f29313caabcde77d'),
#  'awards': {'nominations': 1,
#             'text': 'Won 2 Oscars. Another 2 wins & 1 nomination.',
#             'wins': 4},
#  'cast': ['Deborah Kerr', 'Stewart Granger', 'Richard Carlson', 'Hugo Haas'],
#  'countries': ['USA'],
#  'directors': ['Compton Bennett', 'Andrew Marton'],
#  'fullplot': 'Guide Allan Quatermain helps a young lady (Beth) find her lost '
#              "husband somewhere in Africa. It's a spectacular adventure story "
#              'with romance, because while they fight with wild animals and '
#              'cannibals, they fall in love. Will they find the lost husband '
#              'and finish the nice connection?',
#  'genres': ['Adventure', 'Romance', 'Action'],
#  'imdb': {'id': 42646, 'rating': 6.9, 'votes': 4128},
#  'languages': ['English'],
#  'lastupdated': '2015-08-06 00:32:20.070000000',
#  'num_mflix_comments': 1,
#  'plot': 'Adventurer Allan Quartermain leads an expedition into uncharted '
#          'African territory in an attempt to locate an explorer who went '
#          'missing during his search for the fabled diamond mines of King '
#          'Solomon.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BYjZlOWFjNzktMDQ3OC00ODQxLWEzZjMtN2E0Y2MwM2FkMzE0XkEyXkFqcGdeQXVyNTEwNDcxNDc@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PASSED',
#  'released': datetime.datetime(1950, 11, 24, 0, 0),
#  'runtime': 103,
#  'title': "King Solomon's Mines",
#  'tomatoes': {'critic': {'meter': 92, 'numReviews': 12, 'rating': 7.2},
#               'dvd': datetime.datetime(2005, 1, 11, 0, 0),
#               'fresh': 11,
#               'lastUpdated': datetime.datetime(2015, 9, 10, 19, 11, 25),
#               'production': 'MGM Home Entertainment',
#               'rotten': 1,
#               'viewer': {'meter': 60, 'numReviews': 3186, 'rating': 3.3}},
#  'type': 'movie',
#  'writers': ['Helen Deutsch (screenplay)', 'H. Rider Haggard (novel)'],
#  'year': 1950}
# {'_id': ObjectId('573a1394f29313caabcde7ee'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['Errol Flynn', 'Alexis Smith', 'S.Z. Sakall', 'Douglas Kennedy'],
#  'countries': ['USA'],
#  'directors': ['Ray Enright', 'Raoul Walsh'],
#  'fullplot': 'Australian sheep-man Morgan Lane comes to Montana looking for '
#              'government-owned grazing land, and encamps his sheep at the '
#              'boundary line (where the bad grazing ends and the good grazing '
#              'begins) set up by the cattle barons to keep the sheep from '
#              'nubbing away at the good grass. He goes to town, posing as a '
#              'merchant, explains his Australian accent, and learns that Maria '
#              'Singleton, owner of a large ranch, and Rodney Ackroyd (who never '
#              'explains where he got his name), another ranch owner and Miss '
#              "Singleton's fiancèe, are the leaders of the cattlemen against "
#              'the sheep-men. Romance tugs at Morgan and Miss Singleton, who '
#              'quickly decides that Morgan has a much better name than Rodney '
#              '(and other attributes) but the cattle-vs.-sheep feud keeps them '
#              'apart. Until they meet in the street for a showdown gunfight '
#              'following a disastrous clash between the cattle and sheep '
#              'factions.',
#  'genres': ['Action', 'Adventure', 'Romance'],
#  'imdb': {'id': 42744, 'rating': 6.2, 'votes': 759},
#  'languages': ['English'],
#  'lastupdated': '2015-09-17 04:39:05.470000000',
#  'num_mflix_comments': 1,
#  'plot': 'An Australian sheepman comes to Montana looking for grazing space, '
#          'is opposed by local ranchers and a wealthy cattle-woman.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTEyNjI3MTQzMTZeQTJeQWpwZ15BbWU4MDExNjA5MDMx._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'APPROVED',
#  'released': datetime.datetime(1950, 1, 28, 0, 0),
#  'runtime': 76,
#  'title': 'Montana',
#  'tomatoes': {'dvd': datetime.datetime(2008, 8, 26, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 8, 26, 18, 0, 15),
#               'production': 'Warner Home Video',
#               'viewer': {'meter': 30, 'numReviews': 81, 'rating': 2.9}},
#  'type': 'movie',
#  'writers': ['James R. Webb (screenplay)',
#              'Borden Chase (screenplay)',
#              "Charles O'Neal (screenplay)",
#              'Ernest Haycox (story)'],
#  'year': 1950}
# {'_id': ObjectId('573a1394f29313caabcdf12c'),
#  'awards': {'nominations': 1, 'text': '1 win & 1 nomination.', 'wins': 1},
#  'cast': ['Stewart Granger', 'Eleanor Parker', 'Janet Leigh', 'Mel Ferrer'],
#  'countries': ['USA'],
#  'directors': ['George Sidney'],
#  'fullplot': "Andre-Louis Moreau is a nobleman's bastard in the days of the "
#              'French revolution. Noel, the Marquis de Mayne, a nobleman in '
#              'love with the Queen, is ordered to seek the hand of a young '
#              'ingenue, Aline, in marriage. Andre also meets Aline, and forms '
#              'an interest in her. But when the marquis kills his best friend '
#              "Andre declares himself the Marquis's enemy and vows to avenge "
#              'his friend. He hides out, a wanted man, as an actor in a '
#              'commedia troupe, and spends his days learning how to handle a '
#              'sword. When de Maynes becomes a spadassinicide, challenging '
#              'opposing National Assembly members to duels they have no hope of '
#              'winning, Andre becomes a politician to protect the third estate '
#              '(and hopefully ventilate de Maynes).',
#  'genres': ['Action', 'Adventure', 'Comedy'],
#  'imdb': {'id': 45125, 'rating': 7.7, 'votes': 4112},
#  'languages': ['English'],
#  'lastupdated': '2015-08-23 00:11:05.923000000',
#  'num_mflix_comments': 0,
#  'plot': 'After Andre Moreau finds he is the secret bastard son of a recently '
#          "deceased noble, he realizes that it his own sister that he's "
#          'romantically drawn to.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTYxODY4MzczOV5BMl5BanBnXkFtZTgwMjAyOTYyMjE@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'APPROVED',
#  'released': datetime.datetime(1952, 6, 27, 0, 0),
#  'runtime': 115,
#  'title': 'Scaramouche',
#  'tomatoes': {'dvd': datetime.datetime(2003, 7, 1, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 8, 13, 19, 16, 27),
#               'production': 'Warner Home Video',
#               'viewer': {'meter': 85, 'numReviews': 2497, 'rating': 3.8}},
#  'type': 'movie',
#  'writers': ['Ronald Millar (screenplay)',
#              'George Froeschel (screenplay)',
#              'Rafael Sabatini (based on the novel by)'],
#  'year': 1952}
# {'_id': ObjectId('573a1394f29313caabcdf340'),
#  'awards': {'nominations': 0,
#             'text': 'Nominated for 1 Oscar. Another 1 win.',
#             'wins': 2},
#  'cast': ['Richard Burton', 'James Mason', 'Robert Newton', 'Robert Douglas'],
#  'countries': ['USA'],
#  'directors': ['Robert Wise'],
#  'fullplot': 'Rommel has the British in retreat on his way to the Suez Canal. '
#              'All that stands in his way is Tobruk, held by a vastly out '
#              'numbered force of Australian troops. Richard Burton leads these '
#              'troops on daring raids against Rommel, keeping him off balance '
#              "as they earn the nickname 'The Desert Rats'.",
#  'genres': ['Action', 'Adventure', 'Drama'],
#  'imdb': {'id': 45679, 'rating': 6.8, 'votes': 3379},
#  'languages': ['English', 'German'],
#  'lastupdated': '2015-08-29 00:03:46.110000000',
#  'num_mflix_comments': 1,
#  'plot': 'Richard Burton plays a Scottish Army officer put in charge of a '
#          'disparate band of ANZAC troops on the perimeter of Tobruk with the '
#          'German Army doing their best to dislodge them.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNjViMWZhYzUtNGM4Ni00ZjQ2LWExNTEtN2M1OTA2NDUyODMwL2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyNjQzNDI3NzY@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'APPROVED',
#  'released': datetime.datetime(1953, 5, 20, 0, 0),
#  'runtime': 88,
#  'title': 'The Desert Rats',
#  'tomatoes': {'critic': {'meter': 80, 'numReviews': 5, 'rating': 6.3},
#               'dvd': datetime.datetime(2002, 5, 21, 0, 0),
#               'fresh': 4,
#               'lastUpdated': datetime.datetime(2015, 9, 1, 19, 13, 4),
#               'production': 'Fox',
#               'rotten': 1,
#               'viewer': {'meter': 71, 'numReviews': 1524, 'rating': 3.4}},
#  'type': 'movie',
#  'writers': ['Richard Murphy'],
#  'year': 1953}
# {'_id': ObjectId('573a1394f29313caabcdf465'),
#  'awards': {'nominations': 4,
#             'text': 'Nominated for 2 Oscars. Another 2 nominations.',
#             'wins': 0},
#  'cast': ['Robert Taylor', 'Ava Gardner', 'Mel Ferrer', 'Anne Crawford'],
#  'countries': ['USA'],
#  'directors': ['Richard Thorpe'],
#  'fullplot': 'King Arthur establishes the greatest reign England has ever '
#              'seen, and along for the ride are his indispensable Knights of '
#              'the Round Table, particularly Sir Lancelot. Then, Arthur finds '
#              'himself a bride, the beautiful Guenivere. While she loves '
#              'Arthur, she also loves Lancelot and though Lancelot repeatedly '
#              'fights it, he loves her, too. Treachery is brewing as the evil '
#              'Morgan le Fay and her knight Sir Modred work to trap them. So '
#              'begins the decline and eventual fall of Arthur and Camelot.',
#  'genres': ['Action', 'Adventure', 'Drama'],
#  'imdb': {'id': 45966, 'rating': 6.3, 'votes': 2262},
#  'languages': ['English'],
#  'lastupdated': '2015-09-13 00:15:19.830000000',
#  'num_mflix_comments': 0,
#  'plot': "King Arthur's rule is threatened by the adulterous love between Sir "
#          "Lancelot and Queen Guinevere, a relationship the king's enemies hope "
#          'to exploit.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BYjQyMmIyODMtYWU3YS00NTMzLWI3OTAtOWVlNzczMTc1NjQ4XkEyXkFqcGdeQXVyNjQzNDI3NzY@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'APPROVED',
#  'released': datetime.datetime(1954, 1, 15, 0, 0),
#  'runtime': 115,
#  'title': 'Knights of the Round Table',
#  'tomatoes': {'critic': {'meter': 80, 'numReviews': 5, 'rating': 6.2},
#               'dvd': datetime.datetime(2003, 7, 1, 0, 0),
#               'fresh': 4,
#               'lastUpdated': datetime.datetime(2015, 8, 4, 20, 11, 1),
#               'production': 'Metro-Goldwyn-Mayer (MGM)',
#               'rotten': 1,
#               'viewer': {'meter': 44, 'numReviews': 2883, 'rating': 3.1}},
#  'type': 'movie',
#  'writers': ['Talbot Jennings (screenplay)',
#              'Jan Lustig (screenplay)',
#              'Noel Langley (screenplay)',
#              'Thomas Malory (based on "Le Morte D\'Arthur")'],
#  'year': 1953}

# %% [markdown]
# ## Exercise 2: Sorting Results
# Objective: Learn how to sort query results in MongoDB.

# %%
#1. Write a query to find all movies where the genre is "Comedy" and sort them by IMDb rating in descending order (Return the first 5 results).
sorted_comedy_movies = collection.find({"genres": "Comedy"}).sort("imdb.rating", -1).limit(5)

for movie in sorted_comedy_movies:
    pprint.pprint(movie)
# Out:
# {'_id': ObjectId('573a13dcf29313caabdb2dec'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Jennifer Jason Leigh', 'David Thewlis', 'Tom Noonan'],
#  'countries': ['USA'],
#  'directors': ['Duke Johnson', 'Charlie Kaufman'],
#  'fullplot': "Charlie Kaufman's first stop-motion film about a man crippled by "
#              'the mundanity of his life.',
#  'genres': ['Animation', 'Comedy', 'Fantasy'],
#  'imdb': {'id': 2401878, 'rating': '', 'votes': ''},
#  'languages': ['English'],
#  'lastupdated': '2015-08-31 00:00:23.967000000',
#  'num_mflix_comments': 0,
#  'plot': "Charlie Kaufman's first stop-motion film about a man crippled by the "
#          'mundanity of his life.',
#  'rated': 'R',
#  'released': datetime.datetime(2015, 9, 8, 0, 0),
#  'runtime': 90,
#  'title': 'Anomalisa',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 7, 26, 18, 15, 38),
#               'production': 'Walt Disney Pictures International',
#               'viewer': {'numReviews': 12, 'rating': 2.5}},
#  'type': 'movie',
#  'writers': ['Charlie Kaufman'],
#  'year': 2015}
# {'_id': ObjectId('573a13d9f29313caabdaa62d'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['Ray Panthaki', 'Vicky McClure', 'Adeel Akhtar', 'Jenny Bede'],
#  'countries': ['UK'],
#  'directors': ['Keri Collins'],
#  'fullplot': 'Two convenience store robbers mess up the crime and end up '
#              'working there for the rest of the night.',
#  'genres': ['Comedy'],
#  'imdb': {'id': 2263210, 'rating': '', 'votes': ''},
#  'languages': ['English'],
#  'lastupdated': '2015-09-14 17:30:41.583000000',
#  'num_mflix_comments': 0,
#  'plot': 'Two convenience store robbers mess up the crime and end up working '
#          'there for the rest of the night.',
#  'released': datetime.datetime(2015, 10, 2, 0, 0),
#  'title': 'Convenience',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 9, 13, 9, 52, 44),
#               'viewer': {'numReviews': 3, 'rating': 4.0},
#               'website': 'http://www.convenience-movie.com'},
#  'type': 'movie',
#  'writers': ['Simon Fantauzzo'],
#  'year': 2015}
# {'_id': ObjectId('573a13dff29313caabdb909e'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['Jessie Barr',
#           'Louis Cancelmi',
#           'Margaret Daly',
#           'Caitlin FitzGerald'],
#  'countries': ['USA'],
#  'directors': ["Tom O'Brien"],
#  'fullplot': 'Danny, a commercial editor and documentary filmmaker attempts to '
#              'finish his film, a study on relationship while navigating the '
#              'relationships in his own life. Will he continue to chase the '
#              'unattainable Theresa a hippy new age dancer(Caitlin Fitzgerald) '
#              "or will he finally admit he's in love with his best friend Carla "
#              '(Katherine Waterston) who is in an unfulfilling relationship '
#              'with a political strategist(Gaby Hoffman). Manhattan Romance is '
#              'a funny insightful look at contemporary life in Manhattan. It '
#              'explores new age ideas and open relationship as well as true '
#              'friendship and connection.',
#  'genres': ['Comedy', 'Drama', 'Romance'],
#  'imdb': {'id': 2608324, 'rating': '', 'votes': ''},
#  'languages': ['English'],
#  'lastupdated': '2015-08-28 00:17:01.610000000',
#  'num_mflix_comments': 0,
#  'plot': 'Danny, a commercial editor and documentary filmmaker attempts to '
#          'finish his film, a study on relationship while navigating the '
#          'relationships in his own life. Will he continue to chase the ...',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMjMzODk2MDc0MF5BMl5BanBnXkFtZTgwMTc3NjU4NjE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2015, 10, 2, 0, 0),
#  'runtime': 94,
#  'title': 'Manhattan Romance',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 9, 2, 18, 57, 41),
#               'viewer': {'numReviews': 2, 'rating': 0.0}},
#  'type': 'movie',
#  'writers': ["Tom O'Brien"],
#  'year': 2015}
# {'_id': ObjectId('573a13def29313caabdb627d'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Gracie Mei Huntsman',
#           'Jon Huntsman',
#           'Jerome A. Cohen',
#           'Chen Guangcheng'],
#  'countries': ['China', 'USA'],
#  'directors': ['Vanessa Hope'],
#  'genres': ['Documentary', 'Comedy', 'History'],
#  'imdb': {'id': 2505376, 'rating': '', 'votes': ''},
#  'languages': ['English', 'Chinese'],
#  'lastupdated': '2015-08-26 01:05:17.383000000',
#  'num_mflix_comments': 1,
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMjAyNzYzNzIyM15BMl5BanBnXkFtZTgwMjA4ODgxNTE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2015, 4, 20, 0, 0),
#  'runtime': 90,
#  'title': 'All Eyes and Ears',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 6, 26, 18, 3, 5),
#               'viewer': {'numReviews': 1, 'rating': 1.5}},
#  'type': 'movie',
#  'writers': ['Vanessa Hope'],
#  'year': 2015}
# {'_id': ObjectId('573a13cff29313caabd88f5b'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Halston Sage',
#           'Tye Sheridan',
#           'Patrick Schwarzenegger',
#           'Cloris Leachman'],
#  'countries': ['USA'],
#  'directors': ['Christopher Landon'],
#  'fullplot': 'Three scouts, on the eve of their last camp-out, discover the '
#              'true meaning of friendship when they attempt to save their town '
#              'from a zombie outbreak.',
#  'genres': ['Comedy', 'Horror'],
#  'imdb': {'id': 1727776, 'rating': '', 'votes': ''},
#  'languages': ['English'],
#  'lastupdated': '2015-08-27 00:00:19.697000000',
#  'num_mflix_comments': 0,
#  'plot': 'Three scouts, on the eve of their last camp-out, discover the true '
#          'meaning of friendship when they attempt to save their town from a '
#          'zombie outbreak.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTY4NjczNjE4OV5BMl5BanBnXkFtZTgwODk0MjQ5NjE@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2015, 10, 30, 0, 0),
#  'runtime': 93,
#  'title': 'Scouts Guide to the Zombie Apocalypse',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 8, 30, 20, 13, 8),
#               'production': 'Paramount Pictures',
#               'viewer': {'numReviews': 91, 'rating': 2.8},
#               'website': 'http://www.scoutsandzombiesmovie.com/'},
#  'type': 'movie',
#  'writers': ['Emi Mochizuki (screenplay)',
#              'Carrie Lee Wilson (screenplay)',
#              'Christopher Landon (screenplay)',
#              'Lona Williams (screenplay)'],
#  'year': 2015}

# %%
#2. Write a query to find all movies where the genre is "Drama" and sort them by release year in ascending order (Return the first 5 results)
sorted_drama_movies = collection.find({"genres": "Drama"}).sort("year", 1).limit(5)

for movie in sorted_drama_movies:
    pprint.pprint(movie)
# Out:
# {'_id': ObjectId('573a1394f29313caabcde630'),
#  'awards': {'nominations': 1,
#             'text': 'Nominated for 3 Oscars. Another 1 win & 1 nomination.',
#             'wins': 4},
#  'cast': ['Eleanor Parker', 'Agnes Moorehead', 'Ellen Corby', 'Hope Emerson'],
#  'countries': ['USA'],
#  'directors': ['John Cromwell'],
#  'genres': ['Crime', 'Drama', 'Film-Noir'],
#  'imdb': {'id': 42296, 'rating': 7.8, 'votes': 2189},
#  'languages': ['English'],
#  'lastupdated': '2015-09-15 04:50:38.620000000',
#  'num_mflix_comments': 0,
#  'plot': 'A naive nineteen year old widow becomes coarsened and cynical when '
#          "she is sent to a woman's prison and is exposed to hardened criminals "
#          'and sadistic guards.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNGVkNTkxMDItNWYxZi00NGE2LTk5Y2YtODRhMzcwN2E4YjkyXkEyXkFqcGdeQXVyNTEwNDcxNDc@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(1950, 5, 19, 0, 0),
#  'runtime': 96,
#  'title': 'Caged',
#  'tomatoes': {'dvd': datetime.datetime(2007, 6, 26, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 9, 13, 9, 54, 12),
#               'production': 'Warner Bros. Pictures',
#               'viewer': {'meter': 85, 'numReviews': 578, 'rating': 3.9}},
#  'type': 'movie',
#  'writers': ['Virginia Kellogg (screenplay)',
#              'Virginia Kellogg (story)',
#              'Bernard C. Schoenfeld (story)'],
#  'year': 1950}
# {'_id': ObjectId('573a1394f29313caabcde5c7'),
#  'awards': {'nominations': 9,
#             'text': 'Nominated for 4 Oscars. Another 7 wins & 9 nominations.',
#             'wins': 11},
#  'cast': ['Sterling Hayden', 'Louis Calhern', 'Jean Hagen', 'James Whitmore'],
#  'countries': ['USA'],
#  'directors': ['John Huston'],
#  'fullplot': 'When the intelligent criminal Erwin "Doc" Riedenschneider is '
#              'released from prison, he seeks a fifty thousand-dollar '
#              'investment from the bookmaker Cobby to recruit a small gang of '
#              'specialists for a million-dollar heist of jewels from a jewelry. '
#              'Doc is introduced to the lawyer Alonzo D. Emmerich that offers '
#              'to finance the whole operation and buy the gems immediately '
#              'after the burglary. Doc hires the safecracker Louis Ciavelli, '
#              'the driver Gus Minissi and the gunman Dix Handley to the heist. '
#              'His plan works perfectly but bad luck and betrayals compromise '
#              'the steps after the heist and the gangsters need to flee from '
#              'the police.',
#  'genres': ['Crime', 'Film-Noir', 'Drama'],
#  'imdb': {'id': 42208, 'rating': 7.9, 'votes': 16441},
#  'languages': ['English', 'German'],
#  'lastupdated': '2015-08-22 00:29:18.017000000',
#  'num_mflix_comments': 0,
#  'plot': 'A major heist goes off as planned, until bad luck and double crosses '
#          'cause everything to unravel.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNWYxNWZjZmEtOTk1Ny00ZWE0LWI1YjAtZmQ0ZjM4OGUwNmJjXkEyXkFqcGdeQXVyMDI2NDg0NQ@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PASSED',
#  'released': datetime.datetime(1950, 5, 23, 0, 0),
#  'runtime': 112,
#  'title': 'The Asphalt Jungle',
#  'tomatoes': {'critic': {'meter': 96, 'numReviews': 25, 'rating': 8.4},
#               'dvd': datetime.datetime(2004, 7, 6, 0, 0),
#               'fresh': 24,
#               'lastUpdated': datetime.datetime(2015, 8, 20, 18, 33, 39),
#               'production': 'WARNER BROTHERS PICTURES',
#               'rotten': 1,
#               'viewer': {'meter': 87, 'numReviews': 6843, 'rating': 3.9}},
#  'type': 'movie',
#  'writers': ['Ben Maddow (screen play)',
#              'John Huston (screen play)',
#              'W.R. Burnett (from a novel by)'],
#  'year': 1950}
# {'_id': ObjectId('573a1394f29313caabcde5ff'),
#  'awards': {'nominations': 2,
#             'text': 'Won 1 BAFTA Film Award. Another 1 nomination.',
#             'wins': 0},
#  'cast': ['Jack Warner', 'Jimmy Hanley', 'Dirk Bogarde', 'Robert Flemyng'],
#  'countries': ['UK'],
#  'directors': ['Basil Dearden'],
#  'fullplot': 'We follow the daily activities of two London bobbies, veteran '
#              'George Dixon and rookie Andy Mitchell. Meanwhile, young hoods '
#              "Tom and Spud plan a series of robberies with Tom's girl Diana, a "
#              'discontented beauty, as inside worker. But in their second '
#              'crime, one of our heroes is shot, setting off a citywide '
#              'manhunt. The killer is clever, but will he outsmart himself?',
#  'genres': ['Crime', 'Drama', 'Thriller'],
#  'imdb': {'id': 42265, 'rating': 7.0, 'votes': 900},
#  'languages': ['English'],
#  'lastupdated': '2015-09-17 04:51:51.277000000',
#  'num_mflix_comments': 0,
#  'plot': 'The daily routine of two London policemen is interrupted by a '
#          'killer.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMjIzNzcxNDM0OV5BMl5BanBnXkFtZTgwMDc5ODgwMzE@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'APPROVED',
#  'released': datetime.datetime(1950, 6, 1, 0, 0),
#  'runtime': 84,
#  'title': 'The Blue Lamp',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 6, 23, 18, 9, 27),
#               'production': 'Astor Pictures Corporation',
#               'viewer': {'meter': 71, 'numReviews': 119, 'rating': 3.5}},
#  'type': 'movie',
#  'writers': ['T.E.B. Clarke (screenplay)',
#              'Jan Read (original treatment)',
#              'Ted Willis (original treatment)',
#              'Alexander Mackendrick (additional dialogue)'],
#  'year': 1950}
# {'_id': ObjectId('573a1394f29313caabcde6ed'),
#  'awards': {'nominations': 1, 'text': '1 win & 1 nomination.', 'wins': 1},
#  'cast': ['Jennifer Jones', 'David Farrar', 'Cyril Cusack', 'Sybil Thorndike'],
#  'countries': ['UK'],
#  'directors': ['Michael Powell', 'Emeric Pressburger'],
#  'fullplot': 'Hazel Woodus is a beautiful but innocent country girl who loves '
#              'all the creatures around her, especially her pet fox cub. She is '
#              'given a rough time by her father but can escape to run barefoot '
#              'through the woods when her harsh life gets too much for her. It '
#              'is there that she is found by the local squire, Jack Reddin, '
#              'finds her and is struck by her beauty. The obvious conflict '
#              'develops when the squire leads the local hunt and tries to kill '
#              'Hazel\'s pet fox. The title "Gone to Earth" is taken from the '
#              'huntsmans cry when the target is no longer obtainable.',
#  'genres': ['Drama', 'Romance'],
#  'imdb': {'id': 42513, 'rating': 7.4, 'votes': 670},
#  'languages': ['English'],
#  'lastupdated': '2015-08-23 00:26:33.593000000',
#  'num_mflix_comments': 0,
#  'plot': 'A beautiful, superstitious, animal-loving Gypsy is hotly desired by '
#          'a fox-hunting squire...even after she marries a clergyman.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BZmZiYTZmM2MtN2YzOS00NDIyLTg3OTctMmM2ZGJiOWJiYzQ5XkEyXkFqcGdeQXVyMTIyNzY1NzM@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(1950, 11, 6, 0, 0),
#  'runtime': 82,
#  'title': 'Gone to Earth',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 9, 11, 18, 33, 53),
#               'viewer': {'meter': 80, 'numReviews': 475, 'rating': 3.8}},
#  'type': 'movie',
#  'writers': ['Mary Webb (novel)', 'Michael Powell', 'Emeric Pressburger'],
#  'year': 1950}
# {'_id': ObjectId('573a1394f29313caabcde5b7'),
#  'awards': {'nominations': 16,
#             'text': 'Won 6 Oscars. Another 17 wins & 16 nominations.',
#             'wins': 23},
#  'cast': ['Bette Davis', 'Anne Baxter', 'George Sanders', 'Celeste Holm'],
#  'countries': ['USA'],
#  'directors': ['Joseph L. Mankiewicz'],
#  'fullplot': 'Aspiring actress Eve Harrington maneuvers her way into the lives '
#              'of Broadway star Margo Channing, playwright Lloyd Richards and '
#              'director Bill Sampson. This classic story of ambition and '
#              'betrayal has become part of American folklore. Bette Davis '
#              'claims to have based her character on the persona of film '
#              'actress Talullah Bankhead. Davis\' line "Fasten your seatbelts, '
#              'it\'s going to be a bumpy night" is legendary, but, in fact, all '
#              "of the film's dialog sparkles with equal brilliance.",
#  'genres': ['Drama'],
#  'imdb': {'id': 42192, 'rating': 8.4, 'votes': 75075},
#  'languages': ['English', 'French'],
#  'lastupdated': '2015-09-07 00:00:14.850000000',
#  'num_mflix_comments': 1,
#  'plot': 'An ingenue insinuates herself in to the company of an established '
#          'but aging stage actress and her circle of theater friends.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTY2MTAzODI5NV5BMl5BanBnXkFtZTgwMjM4NzQ0MjE@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'APPROVED',
#  'released': datetime.datetime(1951, 1, 15, 0, 0),
#  'runtime': 138,
#  'title': 'All About Eve',
#  'tomatoes': {'consensus': 'Smart, sophisticated, and devastatingly funny, All '
#                            'About Eve is a Hollywood classic that only '
#                            'improves with age.',
#               'critic': {'meter': 100, 'numReviews': 63, 'rating': 9.1},
#               'dvd': datetime.datetime(1999, 10, 5, 0, 0),
#               'fresh': 63,
#               'lastUpdated': datetime.datetime(2015, 9, 13, 17, 31, 56),
#               'production': '20th Century Fox',
#               'rotten': 0,
#               'viewer': {'meter': 95, 'numReviews': 43469, 'rating': 4.3}},
#  'type': 'movie',
#  'writers': ['Joseph L. Mankiewicz (written for the screen by)'],
#  'year': 1950}

# %% [markdown]
# ## Exercise 3: Aggregation Pipeline
# Objective: Use MongoDB’s aggregation framework to analyze and transform data.

# %%
#1. Write an aggregation pipeline that calculates the average IMDb rating for each genre (Return the top 5 genres).
avg_rating_by_genre = collection.aggregate([
{"$unwind": "$genres"},
{"$group": {"_id": "$genres", "avg_rating": {"$avg": "$imdb.rating"}}},
{"$sort": {"avg_rating": -1}},
{"$limit": 5}
])

for movie in avg_rating_by_genre:
    pprint.pprint(movie)
# Out:
# {'_id': 'Film-Noir', 'avg_rating': 7.396774193548388}
# {'_id': 'Short', 'avg_rating': 7.390625}
# {'_id': 'Documentary', 'avg_rating': 7.365130483064964}
# {'_id': 'News', 'avg_rating': 7.252272727272728}
# {'_id': 'History', 'avg_rating': 7.171942446043165}

# %%
#2. Write an aggregation pipeline to find the top 5 directors by the average IMDb rating of their movies.
top_directors = collection.aggregate([
{"$group": {"_id": "$directors", "avg_rating": {"$avg": "$imdb.rating"}}},
{"$sort": {"avg_rating": -1}},
{"$limit": 5}
])

for movie in top_directors:
    pprint.pprint(movie)
# Out:
# {'_id': ['Sara Hirsh Bordo'], 'avg_rating': 9.4}
# {'_id': ['Kevin Derek'], 'avg_rating': 9.3}
# {'_id': ['Michael Benson'], 'avg_rating': 9.0}
# {'_id': ['Slobodan Sijan'], 'avg_rating': 8.95}
# {'_id': ['Sundar C.'], 'avg_rating': 8.9}

# %%
#3. Write an aggregation pipeline to calculate the total number of movies released in each year (Sort the results by the year).
movies_per_year = collection.aggregate([
{"$group": {"_id": "$year", "total_movies": {"$sum": 1}}},
{"$sort": {"_id": 1}}
])

for movie in movies_per_year:
    pprint.pprint(movie)
# Out:
# {'_id': 1950, 'total_movies': 55}
# {'_id': 1951, 'total_movies': 54}
# {'_id': 1952, 'total_movies': 45}
# {'_id': 1953, 'total_movies': 65}
# {'_id': 1954, 'total_movies': 47}
# {'_id': 1955, 'total_movies': 67}
# {'_id': 1956, 'total_movies': 67}
# {'_id': 1957, 'total_movies': 71}
# {'_id': 1958, 'total_movies': 75}
# {'_id': 1959, 'total_movies': 71}
# {'_id': 1960, 'total_movies': 73}
# {'_id': 1961, 'total_movies': 68}
# {'_id': 1962, 'total_movies': 70}
# {'_id': 1963, 'total_movies': 69}
# {'_id': 1964, 'total_movies': 86}
# {'_id': 1965, 'total_movies': 77}
# {'_id': 1966, 'total_movies': 87}
# {'_id': 1967, 'total_movies': 81}
# {'_id': 1968, 'total_movies': 89}
# {'_id': 1969, 'total_movies': 107}
# {'_id': 1970, 'total_movies': 120}
# {'_id': 1971, 'total_movies': 106}
# {'_id': 1972, 'total_movies': 121}
# {'_id': 1973, 'total_movies': 112}
# {'_id': 1974, 'total_movies': 103}
# {'_id': 1975, 'total_movies': 107}
# {'_id': 1976, 'total_movies': 116}
# {'_id': 1977, 'total_movies': 123}
# {'_id': 1978, 'total_movies': 128}
# {'_id': 1979, 'total_movies': 131}
# {'_id': 1980, 'total_movies': 167}
# {'_id': 1981, 'total_movies': 168}
# {'_id': 1982, 'total_movies': 177}
# {'_id': 1983, 'total_movies': 161}
# {'_id': 1984, 'total_movies': 199}
# {'_id': 1985, 'total_movies': 189}
# {'_id': 1986, 'total_movies': 190}
# {'_id': 1987, 'total_movies': 222}
# {'_id': 1988, 'total_movies': 251}
# {'_id': 1989, 'total_movies': 232}
# {'_id': 1990, 'total_movies': 225}
# {'_id': 1991, 'total_movies': 238}
# {'_id': 1992, 'total_movies': 270}
# {'_id': 1993, 'total_movies': 274}
# {'_id': 1994, 'total_movies': 305}
# {'_id': 1995, 'total_movies': 372}
# {'_id': 1996, 'total_movies': 407}
# {'_id': 1997, 'total_movies': 439}
# {'_id': 1998, 'total_movies': 513}
# {'_id': 1999, 'total_movies': 515}
# {'_id': 2000, 'total_movies': 581}
# {'_id': 2001, 'total_movies': 612}
# {'_id': 2002, 'total_movies': 622}
# {'_id': 2003, 'total_movies': 603}
# {'_id': 2004, 'total_movies': 678}
# {'_id': 2005, 'total_movies': 713}
# {'_id': 2006, 'total_movies': 774}
# {'_id': 2007, 'total_movies': 810}
# {'_id': 2008, 'total_movies': 886}
# {'_id': 2009, 'total_movies': 917}
# {'_id': 2010, 'total_movies': 866}
# {'_id': 2011, 'total_movies': 893}
# {'_id': 2012, 'total_movies': 955}
# {'_id': 2013, 'total_movies': 1105}
# {'_id': 2014, 'total_movies': 1073}
# {'_id': 2015, 'total_movies': 480}
# {'_id': 2016, 'total_movies': 1}
# {'_id': '1981è', 'total_movies': 1}
# {'_id': '1986è', 'total_movies': 1}
# {'_id': '1987è', 'total_movies': 1}
# {'_id': '1988è', 'total_movies': 1}
# {'_id': '1994è1998', 'total_movies': 1}
# {'_id': '1995è', 'total_movies': 1}
# {'_id': '1996è', 'total_movies': 1}
# {'_id': '1997è', 'total_movies': 2}
# {'_id': '1999è', 'total_movies': 1}
# {'_id': '2000è', 'total_movies': 1}
# {'_id': '2002è', 'total_movies': 1}
# {'_id': '2003è', 'total_movies': 1}
# {'_id': '2005è', 'total_movies': 2}
# {'_id': '2006è', 'total_movies': 1}
# {'_id': '2006è2007', 'total_movies': 1}
# {'_id': '2006è2012', 'total_movies': 2}
# {'_id': '2007è', 'total_movies': 3}
# {'_id': '2009è', 'total_movies': 2}
# {'_id': '2010è', 'total_movies': 4}
# {'_id': '2011è', 'total_movies': 2}
# {'_id': '2012è', 'total_movies': 3}
# {'_id': '2014è', 'total_movies': 2}

# %% [markdown]
# ## Exercise 4: Updating and Deleting Documents
# Objective: Learn how to update and delete documents in MongoDB.

# %%
#1. Write a query to update the IMDb rating of a movie with the title "The Godfather" to 9.5.
collection.update_one({"title": "The Godfather"}, {"$set": {"imdb.rating": 9.5}})

updated_godfather = collection.find_one({"title": "The Godfather"})
pprint.pprint(updated_godfather)
# Out:
# {'_id': ObjectId('573a1396f29313caabce4a9a'),
#  'awards': {'nominations': 19,
#             'text': 'Won 3 Oscars. Another 30 wins & 19 nominations.',
#             'wins': 33},
#  'cast': ['Marlon Brando', 'Al Pacino', 'James Caan', 'Richard S. Castellano'],
#  'countries': ['USA'],
#  'directors': ['Francis Ford Coppola'],
#  'fullplot': 'When the aging head of a famous crime family decides to transfer '
#              'his position to one of his subalterns, a series of unfortunate '
#              'events start happening to the family, and a war begins between '
#              'all the well-known families leading to insolence, deportation, '
#              'murder and revenge, and ends with the favorable successor being '
#              'finally chosen.',
#  'genres': ['Crime', 'Drama'],
#  'imdb': {'id': 68646, 'rating': 9.5, 'votes': 1038358},
#  'languages': ['English', 'Italian', 'Latin'],
#  'lastupdated': '2015-09-02 00:08:23.680000000',
#  'metacritic': 100,
#  'num_mflix_comments': 131,
#  'plot': 'The aging patriarch of an organized crime dynasty transfers control '
#          'of his clandestine empire to his reluctant son.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BM2MyNjYxNmUtYTAwNi00MTYxLWJmNWYtYzZlODY3ZTk3OTFlXkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(1972, 3, 24, 0, 0),
#  'runtime': 175,
#  'title': 'The Godfather',
#  'tomatoes': {'consensus': "One of Hollywood's greatest critical and "
#                            'commercial successes, The Godfather gets '
#                            'everything right; not only did the movie transcend '
#                            'expectations, it established new benchmarks for '
#                            'American cinema.',
#               'critic': {'meter': 99, 'numReviews': 84, 'rating': 9.2},
#               'dvd': datetime.datetime(2001, 10, 9, 0, 0),
#               'fresh': 83,
#               'lastUpdated': datetime.datetime(2015, 9, 12, 17, 15, 13),
#               'production': 'Paramount Pictures',
#               'rotten': 1,
#               'viewer': {'meter': 98, 'numReviews': 725773, 'rating': 4.4},
#               'website': 'http://www.thegodfather.com'},
#  'type': 'movie',
#  'writers': ['Mario Puzo (screenplay)',
#              'Francis Ford Coppola (screenplay)',
#              'Mario Puzo (novel)'],
#  'year': 1972}

# %%
#2. Write a query to update all movies where the genre is "Horror" and set their IMDb rating to 6.0 if it is currently null.
collection.update_many({"genres": "Horror", "imdb.rating": {"$exists": False}}, {"$set":
{"imdb.rating": 6.0}})

updated_horror = collection.find({"genres": "Horror"}).limit(5)
for movie in updated_horror:
    pprint.pprint(movie)
# Out:
# {'_id': ObjectId('573a1394f29313caabcdeb58'),
#  'awards': {'nominations': 3, 'text': '1 win & 3 nominations.', 'wins': 1},
#  'cast': ['Arturo de Cèrdova',
#           'Carmen Molina',
#           'Miguel èngel Ferriz',
#           'Queta Lavat'],
#  'countries': ['Mexico'],
#  'directors': ['Juan Bustillo Oro'],
#  'genres': ['Horror', 'Thriller', 'Mystery'],
#  'imdb': {'id': 43647, 'rating': 7.2, 'votes': 54},
#  'languages': ['Spanish'],
#  'lastupdated': '2015-07-20 00:52:06.653000000',
#  'num_mflix_comments': 1,
#  'runtime': 91,
#  'title': 'El hombre sin rostro',
#  'tomatoes': {'dvd': datetime.datetime(2007, 6, 26, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 8, 6, 19, 25, 37),
#               'viewer': {'meter': 26, 'numReviews': 508, 'rating': 2.8}},
#  'type': 'movie',
#  'writers': ['Juan Bustillo Oro (story)'],
#  'year': 1950}
# {'_id': ObjectId('573a1394f29313caabcdeb00'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['William Phipps',
#           'Susan Douglas Rubes',
#           'James Anderson',
#           'Charles Lampkin'],
#  'countries': ['USA'],
#  'directors': ['Arch Oboler'],
#  'fullplot': 'Five people are miraculously spared when the fall-out from a '
#              'super-atomic bomb eventually kills all of the rest of humanity '
#              'on earth. They are Roseanne Rogers, a pregnant woman who was in '
#              'an ex-ray room; Michael, a sensitive young poet and philosopher; '
#              'Charles, a black man; Mr. Barnstaple, a banker; and Eric, a '
#              'cosmopolitan Alpinist who was saved from the radio-active dust '
#              'because he was climbing Mt. Everest at the time of the explosion '
#              'and fall-out. Eventually, they all wind up in a Frank Lloyd '
#              'Wright-designed house on a California mountaintop. There is a '
#              'lot of symbolism, especially with the mountain climber, who '
#              'represents decadent and alien fascism and the banker who brings '
#              'greed and arrogance to this new Eden on Earth. Soon, only two '
#              'are left.',
#  'genres': ['Drama', 'Horror', 'Sci-Fi'],
#  'imdb': {'id': 43539, 'rating': 6.5, 'votes': 763},
#  'languages': ['English'],
#  'lastupdated': '2015-07-23 00:45:51.693000000',
#  'num_mflix_comments': 1,
#  'plot': 'The world is destroyed in a nuclear holocaust. Only five Americans '
#          'survive, including a pregnant woman, a neo-Nazi, a black man and a '
#          'bank clerk.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNjI4NzljMzgtN2ZjNy00ODNhLTlmNTgtY2QyZDE3MTc5OGM0L2ltYWdlXkEyXkFqcGdeQXVyMTk2MzI2Ng@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'APPROVED',
#  'released': datetime.datetime(1951, 4, 25, 0, 0),
#  'runtime': 93,
#  'title': 'Five',
#  'tomatoes': {'dvd': datetime.datetime(2007, 4, 24, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 9, 17, 17, 27, 23),
#               'production': '20th Century Fox',
#               'viewer': {'meter': 68, 'numReviews': 431, 'rating': 3.6}},
#  'type': 'movie',
#  'writers': ['Arch Oboler (story)', 'James Weldon Johnson (dialogue)'],
#  'year': 1951}
# {'_id': ObjectId('573a1394f29313caabcdf1bd'),
#  'awards': {'nominations': 1,
#             'text': 'Won 1 Golden Globe. Another 4 wins & 1 nomination.',
#             'wins': 5},
#  'cast': ['Mirjami Kuosmanen',
#           'Kalervo Nissilè',
#           'èke Lindman',
#           'Jouni Tapiola'],
#  'countries': ['Finland'],
#  'directors': ['Erik Blomberg'],
#  'fullplot': 'A newly wed woman goes to the local shaman to get some help with '
#              'her lovelife, but instead gets turned into a white reindeer '
#              'vampire.',
#  'genres': ['Drama', 'Fantasy', 'Horror'],
#  'imdb': {'id': 45283, 'rating': 7.1, 'votes': 714},
#  'languages': ['Finnish'],
#  'lastupdated': '2015-09-04 00:01:03.943000000',
#  'num_mflix_comments': 0,
#  'plot': 'A newly wed woman goes to the local shaman to get some help with her '
#          'lovelife, but instead gets turned into a white reindeer vampire.',
#  'runtime': 74,
#  'title': 'The White Reindeer',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 5, 3, 18, 48, 34),
#               'viewer': {'meter': 67, 'numReviews': 120, 'rating': 3.7}},
#  'type': 'movie',
#  'writers': ['Erik Blomberg', 'Mirjami Kuosmanen'],
#  'year': 1952}
# {'_id': ObjectId('573a1394f29313caabcdf2bb'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Paul Hubschmid', 'Paula Raymond', 'Cecil Kellaway', 'Kenneth Tobey'],
#  'countries': ['USA'],
#  'directors': ['Eugène Louriè'],
#  'fullplot': 'As a result of an arctic nuclear test, a carnivorous dinosaur '
#              'thaws out and starts making its way down the east coast of North '
#              "America. Professor Tom Nesbitt, only witness to the beast's "
#              'existence, is not believed, even when he identifies it as a '
#              '"rhedosaurus" to paleontologist Thurgood Elson. All doubts '
#              'disappear, however, when Elson is swallowed whole during an '
#              'oceanic bathysphere excursion to search for the creature. Soon '
#              'thereafter the rhedosaurus emerges from the sea and lays waste '
#              'to Manhattan Island until Nesbitt comes up with a plan to try to '
#              'stop the seemingly indestructible beast.',
#  'genres': ['Adventure', 'Horror', 'Sci-Fi'],
#  'imdb': {'id': 45546, 'rating': 6.7, 'votes': 4311},
#  'languages': ['English', 'French'],
#  'lastupdated': '2015-08-21 00:12:25.313000000',
#  'num_mflix_comments': 0,
#  'plot': 'A ferocious dinosaur awakened by an Arctic atomic test terrorizes '
#          'the North Atlantic and ultimately New York City.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BOTM4MzNhMzMtNGU5Zi00MWJlLTgzYmEtY2RiM2Y5NGNmNzlhXkEyXkFqcGdeQXVyNTAyODkwOQ@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'APPROVED',
#  'released': datetime.datetime(1953, 6, 13, 0, 0),
#  'runtime': 80,
#  'title': 'The Beast from 20,000 Fathoms',
#  'tomatoes': {'critic': {'meter': 94, 'numReviews': 16, 'rating': 6.6},
#               'dvd': datetime.datetime(2003, 10, 21, 0, 0),
#               'fresh': 15,
#               'lastUpdated': datetime.datetime(2015, 8, 23, 19, 0, 48),
#               'production': 'Warner Bros. Pictures',
#               'rotten': 1,
#               'viewer': {'meter': 68, 'numReviews': 2600, 'rating': 3.5}},
#  'type': 'movie',
#  'writers': ['Lou Morheim (screenplay)',
#              'Fred Freiberger (screenplay)',
#              'Ray Bradbury (story)'],
#  'year': 1953}
# {'_id': ObjectId('573a1394f29313caabcdf42f'),
#  'awards': {'nominations': 2,
#             'text': 'Won 1 Golden Globe. Another 1 nomination.',
#             'wins': 0},
#  'cast': ['Richard Carlson', 'Barbara Rush', 'Charles Drake', 'Joe Sawyer'],
#  'countries': ['USA'],
#  'directors': ['Jack Arnold'],
#  'fullplot': 'John Putnam is a writer and an amateur stargazer with a new home '
#              'out in the beautiful Arizona desert, which he enjoys with Ellen '
#              'Fields, his girlfriend and a local schoolteacher. John is not '
#              'trusted by the people of the small town near where he lives, '
#              'certainly not by Sheriff Matt Warren, who feels protective of '
#              'Ellen, and perhaps something more. One night, John and Ellen see '
#              'a meteor crash in the desert. John drags his friend, Pete, out '
#              'of bed to take him over to the crash site in his helicopter. '
#              'Once there, John climbs down into the crater. Unfortunately, he '
#              'does so alone, as Pete and Ellen wait for him. John is the only '
#              'one who sees the spaceship before a landslide covers it. And '
#              'John is the only one who catches a glimpse of the hideous thing '
#              "inside. At first John's story seems mad, until some of the "
#              "townsfolk begin acting strange - as if they aren't really who "
#              'they seem to be.',
#  'genres': ['Horror', 'Sci-Fi'],
#  'imdb': {'id': 45920, 'rating': 6.6, 'votes': 5392},
#  'languages': ['English'],
#  'lastupdated': '2015-08-24 00:17:53.070000000',
#  'num_mflix_comments': 0,
#  'plot': 'A spaceship from another world crashes in the Arizona desert, and '
#          'only an amateur stargazer and a schoolteacher suspect alien '
#          'influence when the local townsfolk begin to act strange.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BOTUzNzM0MzQxMV5BMl5BanBnXkFtZTgwNTM5NDI1MDE@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'APPROVED',
#  'released': datetime.datetime(1953, 5, 25, 0, 0),
#  'runtime': 81,
#  'title': 'It Came from Outer Space',
#  'tomatoes': {'consensus': 'It Came From Outer Space is a pulpy-but-effective '
#                            'psychological sci-fi picture, with a provocative '
#                            'message about xenophobia.',
#               'critic': {'meter': 81, 'numReviews': 27, 'rating': 6.9},
#               'dvd': datetime.datetime(2002, 5, 21, 0, 0),
#               'fresh': 22,
#               'lastUpdated': datetime.datetime(2015, 9, 2, 18, 25, 6),
#               'production': 'Universal Pictures',
#               'rotten': 5,
#               'viewer': {'meter': 52, 'numReviews': 3680, 'rating': 3.2}},
#  'type': 'movie',
#  'writers': ['Harry Essex (screenplay)', 'Ray Bradbury (story)'],
#  'year': 1953}

# %%
#3. Write a query to delete all movies that were released before the year 1950
collection.delete_many({"year": {"$lt": 1950}})
# Out:
# DeleteResult({'n': 0, 'electionId': ObjectId('7fffffff000000000000011e'), 'opTime': {'ts': Timestamp(1727984808, 45), 't': 286}, 'ok': 1.0, '$clusterTime': {'clusterTime': Timestamp(1727984808, 45), 'signature': {'hash': b'\xfb\xcemp\x01%~\xda6.\xb5\xc7ez9FM\xb5\x85Y', 'keyId': 7363326094432272385}}, 'operationTime': Timestamp(1727984808, 45)}, acknowledged=True)

# %% [markdown]
# ## Exercise 5: Text Search
# Objective: Learn how to perform text searches in MongoDB.

# %%
#1. Ensure the title field is indexed for text search in MongoDB and write a query to search for movies that contain the word "love" in their title.
#collection.create_index([("title", "text")])
#existing text index already includes title and plot don't need to drop or create 

love_movies = collection.find({"$text": {"$search": "love"}})

for movie in love_movies:
    pprint.pprint(movie)
# Out:
# {'_id': ObjectId('573a13a6f29313caabd19168'),
#  'awards': {'nominations': 2, 'text': '2 nominations.', 'wins': 0},
#  'cast': ['Audrey Tautou',
#           'Samuel Le Bihan',
#           'Isabelle Carrè',
#           'Sophie Guillemin'],
#  'countries': ['France'],
#  'directors': ['Laetitia Colombani'],
#  'fullplot': 'Angelique, a young student, is in love with a married doctor. We '
#              'see her attempts to make him leave his pregnant wife, but he '
#              'does not appear for meetings or finally the booked journey to '
#              'Florence. Then the movie is turned back to the beginning, and '
#              'the view changes: We are now following the view of the doctor '
#              'instead of Angeliques. And things look quite different now...',
#  'genres': ['Romance', 'Thriller'],
#  'imdb': {'id': 291579, 'rating': 7.3, 'votes': 15360},
#  'languages': ['French'],
#  'lastupdated': '2015-09-10 17:15:26.557000000',
#  'metacritic': 63,
#  'num_mflix_comments': 0,
#  'plot': 'A young woman who is in love with a married doctor becomes dangerous '
#          'when her attempts to persuade him to leave his wife are '
#          'unsuccessful. However, when things are seen from his point of view, '
#          'the real situation becomes clear.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMjE0NzcwMjM4Ml5BMl5BanBnXkFtZTcwMjgyMjEyMQ@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2002, 3, 27, 0, 0),
#  'runtime': 92,
#  'title': 'He Loves Me... He Loves Me Not',
#  'tomatoes': {'boxOffice': '$0.4M',
#               'consensus': "This romantic thriller puts Tautou's sweetheart "
#                            'Amelie image to good use.',
#               'critic': {'meter': 73, 'numReviews': 71, 'rating': 6.8},
#               'dvd': datetime.datetime(2003, 8, 12, 0, 0),
#               'fresh': 52,
#               'lastUpdated': datetime.datetime(2015, 7, 23, 18, 42, 57),
#               'production': 'Samuel Goldwyn Company',
#               'rotten': 19,
#               'viewer': {'meter': 85, 'numReviews': 22933, 'rating': 3.8},
#               'website': 'http://www.helovesmethemovie.com'},
#  'type': 'movie',
#  'writers': ['Laetitia Colombani', 'Caroline Thivel (collaborating writer)'],
#  'year': 2002}
# {'_id': ObjectId('573a13c1f29313caabd65789'),
#  'awards': {'nominations': 29,
#             'text': 'Nominated for 1 Oscar. Another 16 wins & 29 nominations.',
#             'wins': 17},
#  'cast': ['Tilda Swinton',
#           'Flavio Parenti',
#           'Edoardo Gabbriellini',
#           'Alba Rohrwacher'],
#  'countries': ['Italy'],
#  'directors': ['Luca Guadagnino'],
#  'fullplot': 'Over two decades ago, Emma left Russia to follow Tancredi '
#              'Recchi, the man who had proposed to her. Now a member of a '
#              'powerful industrial Milanese family, she is the respected mother '
#              'of three. But Emma, although not unhappy, feels confusedly '
#              "unfulfilled. One day Antonio, a talented chef and her son's "
#              'friend and partner, makes her senses kindle. It does not take '
#              'long before she embarks on a passionate affair with the sensuous '
#              'young man.',
#  'genres': ['Drama', 'Romance'],
#  'imdb': {'id': 1226236, 'rating': 7.0, 'votes': 12642},
#  'languages': ['Italian', 'Russian', 'English'],
#  'lastupdated': '2015-08-28 00:09:38.160000000',
#  'metacritic': 79,
#  'num_mflix_comments': 0,
#  'plot': 'A tragic love story set at the turn of the millennium in Milan. The '
#          'film follows the fall of the haute bourgeoisie due to the forces of '
#          'passion and unconditional love.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMjAwNjY5OTUxM15BMl5BanBnXkFtZTcwNjE3MTQxMw@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2010, 7, 23, 0, 0),
#  'runtime': 120,
#  'title': 'I Am Love',
#  'tomatoes': {'boxOffice': '$5.0M',
#               'consensus': 'It stumbles into melodrama, but I Am Love backs up '
#                            'its flamboyance with tremendous visual style and a '
#                            'marvelous central performance from Tilda Swinton.',
#               'critic': {'meter': 80, 'numReviews': 123, 'rating': 7.2},
#               'dvd': datetime.datetime(2010, 10, 12, 0, 0),
#               'fresh': 99,
#               'lastUpdated': datetime.datetime(2015, 8, 23, 18, 12, 14),
#               'production': 'Magnolia Pictures',
#               'rotten': 24,
#               'viewer': {'meter': 68, 'numReviews': 15802, 'rating': 3.5},
#               'website': 'http://www.iamlovemovie.com/'},
#  'type': 'movie',
#  'writers': ['Barbara Alberti (screenplay)',
#              'Ivan Cotroneo (screenplay)',
#              'Walter Fasano (screenplay)',
#              'Luca Guadagnino (screenplay)',
#              'Luca Guadagnino (story)'],
#  'year': 2009}
# {'_id': ObjectId('573a1398f29313caabcea5dc'),
#  'awards': {'nominations': 0, 'text': '7 wins.', 'wins': 7},
#  'cast': ['Josse De Pauw', 'Geert Hunaerts', 'Michael Pas', 'Gene Bervoets'],
#  'countries': ['Belgium'],
#  'directors': ['Dominique Deruddere'],
#  'fullplot': "Three 'Bukowskian' torrid nights in the life of a man in search "
#              'of love. Harry Voss, 12, is young and naive. Love, for him, is '
#              'romantic love between princes and princesses demurely kissing '
#              'each other on the mouth. His father is a hero who kidnapped his '
#              'mother and married her on a lonely mountain peak... Later on, '
#              "he'll do the same. But Harry has a lot to learn. He also learns "
#              'that there are handsome men and ugly ones, that love can be '
#              'unfair. That one can find comfort in drinking... but above all '
#              'he learns that man is capable of anything - absolutely anything! '
#              '- to get his fair share of love.',
#  'genres': ['Drama'],
#  'imdb': {'id': 92794, 'rating': 7.0, 'votes': 860},
#  'languages': ['Dutch', 'Italian'],
#  'lastupdated': '2015-08-25 00:07:43.540000000',
#  'num_mflix_comments': 1,
#  'plot': "Three 'Bukowskian' torrid nights in the life of a man in search of "
#          'love. Harry Voss, 12, is young and naive. Love, for him, is romantic '
#          'love between princes and princesses demurely kissing ...',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNTQyMjYwNzczNV5BMl5BanBnXkFtZTcwMzk0MjA0MQ@@._V1_SY1000_SX677_AL_.jpg',
#  'runtime': 90,
#  'title': 'Crazy Love',
#  'tomatoes': {'dvd': datetime.datetime(2004, 10, 26, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 8, 18, 18, 37, 13),
#               'viewer': {'meter': 79, 'numReviews': 1083, 'rating': 3.6}},
#  'type': 'movie',
#  'writers': ['Charles Bukowski (novels)', 'Dominique Deruddere', 'Marc Didden'],
#  'year': 1987}
# {'_id': ObjectId('573a13b6f29313caabd46292'),
#  'awards': {'nominations': 9, 'text': '2 wins & 9 nominations.', 'wins': 2},
#  'cast': ['Maria Popistasu', 'Ioana Barbu', 'Tudor Chirila', 'Catalina Murgea'],
#  'countries': ['Romania', 'France'],
#  'directors': ['Tudor Giurgiu'],
#  'fullplot': "Love. It just happens. No rules. It may look sick, but it's deep "
#              'and it hurts. For everyone, Alex and Kiki are just good friends. '
#              'They happen to be two girls experiencing another kind of love. '
#              'For their family, Kiki and Sandu are sister and brother who '
#              'sometimes fight. They happen to be lovers. Love Sick is about '
#              'their stories.',
#  'genres': ['Drama'],
#  'imdb': {'id': 484437, 'rating': 7.0, 'votes': 2352},
#  'languages': ['Romanian'],
#  'lastupdated': '2015-09-07 01:15:32.507000000',
#  'num_mflix_comments': 0,
#  'plot': "Love. It just happens. No rules. It may look sick, but it's deep and "
#          'it hurts. For everyone, Alex and Kiki are just good friends. They '
#          'happen to be two girls experiencing another kind of love. For their '
#          'family, Kiki and Sandu are sister and brother who sometimes fight. '
#          'They happen to be lovers. Love Sick is about their stories.',
#  'released': datetime.datetime(2006, 6, 8, 0, 0),
#  'runtime': 86,
#  'title': 'Love Sick',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 8, 22, 18, 29, 17),
#               'production': 'Regent Releasing',
#               'viewer': {'meter': 45, 'numReviews': 654, 'rating': 3.5},
#               'website': 'http://www.Lovesick-themovie.com/'},
#  'type': 'movie',
#  'writers': ['Razvan Radulescu (dialogue)',
#              'Cecilia Stefanescu (script & dialogue)'],
#  'year': 2006}
# {'_id': ObjectId('573a13f1f29313caabddb616'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Aomi Muyock', 'Karl Glusman', 'Klara Kristin', 'Juan Saavedra'],
#  'countries': ['France', 'Belgium'],
#  'directors': ['Gaspar Noè'],
#  'fullplot': "A sexual melodrama about a boy and a girl and another girl. It's "
#              'a love story, which celebrates sex in a joyous way.',
#  'genres': ['Drama', 'Romance'],
#  'imdb': {'id': 3774694, 'rating': 6.3, 'votes': 660},
#  'languages': ['English'],
#  'lastupdated': '2015-09-05 00:41:35.807000000',
#  'metacritic': 54,
#  'num_mflix_comments': 1,
#  'plot': "A sexual melodrama about a boy and a girl and another girl. It's a "
#          'love story, which celebrates sex in a joyous way.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTQzNDUwODk5NF5BMl5BanBnXkFtZTgwNzA0MDQ2NTE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2015, 11, 6, 0, 0),
#  'runtime': 134,
#  'title': 'Love',
#  'type': 'movie',
#  'writers': ['Gaspar Noè'],
#  'year': 2015}
# {'_id': ObjectId('573a13bcf29313caabd5710b'),
#  'awards': {'nominations': 2, 'text': '2 nominations.', 'wins': 0},
#  'cast': ['Kari-Pekka Toivonen',
#           'Liisa Kuoppamèki',
#           'Matleena Kuusniemi',
#           'Suvi Aho'],
#  'countries': ['Finland'],
#  'directors': ['Peter Lindholm'],
#  'fullplot': 'Tomi finds himself in love with two women and his wife Maria '
#              'finds herself in a situation where she has to deal with the fact '
#              'that Tomi is the love of her life.',
#  'genres': ['Drama', 'Romance'],
#  'imdb': {'id': 972385, 'rating': 4.9, 'votes': 195},
#  'languages': ['Finnish'],
#  'lastupdated': '2015-06-23 00:14:44.807000000',
#  'num_mflix_comments': 0,
#  'plot': 'Tomi finds himself in love with two women and his wife Maria finds '
#          'herself in a situation where she has to deal with the fact that Tomi '
#          'is the love of her life.',
#  'released': datetime.datetime(2008, 2, 1, 0, 0),
#  'runtime': 94,
#  'title': 'Three in Love',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 5, 7, 18, 37, 56),
#               'viewer': {'meter': 15, 'numReviews': 43, 'rating': 2.6}},
#  'type': 'movie',
#  'writers': ['Kirsten Bonnèn Rask (dramatisation)', 'Peter Lindholm'],
#  'year': 2008}
# {'_id': ObjectId('573a139af29313caabcf06f9'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Meg Ryan', 'Matthew Broderick', 'Kelly Preston', 'Tchèky Karyo'],
#  'countries': ['USA'],
#  'directors': ['Griffin Dunne'],
#  'fullplot': 'Good-natured astronomer Sam is devastated when the love of his '
#              'life, Linda, leaves him for a suave Frenchman named Anton. He '
#              'therefore does what every other normal dumpee would do; go to '
#              'New York and set up home in the abandoned building opposite his '
#              "ex-girlfriend's apartment, intent on winning her back and "
#              'waiting until she decides to leave her current lover. What Sam '
#              'does not count on is being joined several weeks later by ultra '
#              'hip tomboy Maggie, a photographer and motor-cyclist who is '
#              'determined to get revenge on Anton, her ex-fiance. Hostile at '
#              'first, the two of them eventually join forces in an attempt to '
#              "separate the couple, and ruin Anton's life. However, "
#              'complications ensue when Sam and Maggie start falling for each '
#              'other.',
#  'genres': ['Comedy', 'Romance'],
#  'imdb': {'id': 118556, 'rating': 6.1, 'votes': 19004},
#  'languages': ['English', 'French'],
#  'lastupdated': '2015-09-14 08:37:26.277000000',
#  'metacritic': 49,
#  'num_mflix_comments': 2,
#  'plot': "Maggie's and Sam's former partners are in love; she wants revenge "
#          'and he wants his lost love back, so they work together to break up '
#          'the happy couple.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BZDU5ZjA5ZjMtZGZlOS00M2U4LTkyOTktYzYyNGZjN2UxYjdkXkEyXkFqcGdeQXVyNjU0NTI0Nw@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(1997, 5, 23, 0, 0),
#  'runtime': 100,
#  'title': 'Addicted to Love',
#  'tomatoes': {'critic': {'meter': 57, 'numReviews': 30, 'rating': 5.6},
#               'dvd': datetime.datetime(1997, 10, 28, 0, 0),
#               'fresh': 17,
#               'lastUpdated': datetime.datetime(2015, 9, 13, 17, 39, 34),
#               'production': 'Warner Home Video',
#               'rotten': 13,
#               'viewer': {'meter': 50, 'numReviews': 35956, 'rating': 2.8}},
#  'type': 'movie',
#  'writers': ['Robert Gordon'],
#  'year': 1997}
# {'_id': ObjectId('573a1397f29313caabce7090'),
#  'awards': {'nominations': 1, 'text': '1 win & 1 nomination.', 'wins': 1},
#  'cast': ['Jean-Pierre Lèaud', 'Marie-France Pisier', 'Claude Jade', 'Dani'],
#  'countries': ['France'],
#  'directors': ['Franèois Truffaut'],
#  'fullplot': 'Antoine Doinel is now more than thirty. He divorces from '
#              'Christine. He is a proofreader, and is in love with Sabine, a '
#              'record seller. Colette, his teenager love, is now a lawyer. She '
#              "buys Antoine's first published autobiographical novel. They meet "
#              'again in a station...',
#  'genres': ['Comedy', 'Drama', 'Romance'],
#  'imdb': {'id': 78771, 'rating': 7.1, 'votes': 4005},
#  'languages': ['French'],
#  'lastupdated': '2015-08-29 00:00:13.297000000',
#  'num_mflix_comments': 0,
#  'plot': 'Antoine Doinel is now more than thirty. He divorces from Christine. '
#          'He is a proofreader, and is in love with Sabine, a record seller. '
#          'Colette, his teenager love, is now a lawyer. She buys ...',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BYWM0OWIyMzYtMmZkNy00NGU1LTgxZWQtOGE1ZjY0ZTExZTZlXkEyXkFqcGdeQXVyNjI5NTk0MzE@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG',
#  'released': datetime.datetime(1979, 4, 6, 0, 0),
#  'runtime': 94,
#  'title': 'Love on the Run',
#  'tomatoes': {'critic': {'meter': 67, 'numReviews': 9, 'rating': 6.3},
#               'dvd': datetime.datetime(2008, 6, 16, 0, 0),
#               'fresh': 6,
#               'lastUpdated': datetime.datetime(2015, 8, 26, 18, 42, 5),
#               'production': 'Criterion Collection',
#               'rotten': 3,
#               'viewer': {'meter': 71, 'numReviews': 3164, 'rating': 3.6}},
#  'type': 'movie',
#  'writers': ['Franèois Truffaut (scenario)',
#              'Marie-France Pisier (scenario)',
#              'Jean Aurel (scenario)',
#              'Suzanne Schiffman (scenario)'],
#  'year': 1979}
# {'_id': ObjectId('573a1394f29313caabcdfd10'),
#  'awards': {'nominations': 1, 'text': '1 win & 1 nomination.', 'wins': 1},
#  'cast': ['Antonella Lualdi',
#           'Franco Interlenghi',
#           'Sergio Raimondi',
#           'Valeria Moriconi'],
#  'countries': ['Italy', 'France'],
#  'directors': ['Mauro Bolognini'],
#  'fullplot': "The film is about some youths' love stories: Franco and his "
#              'hairdresser girlfriend Adriana, Otello another hairdresser who '
#              'is hopelessly in love with Adriana. The youths usually meet in a '
#              'restaurant whose owner, Ines, seduces Franco making Adriana very '
#              "jealous. In turn the girl decides to accept Otello's courting.",
#  'genres': ['Comedy'],
#  'imdb': {'id': 48207, 'rating': 6.9, 'votes': 90},
#  'languages': ['Italian'],
#  'lastupdated': '2015-07-04 00:38:03.800000000',
#  'num_mflix_comments': 0,
#  'plot': "The film is about some youths' love stories: Franco and his "
#          'hairdresser girlfriend Adriana, Otello another hairdresser who is '
#          'hopelessly in love with Adriana. The youths usually meet in a ...',
#  'released': datetime.datetime(1955, 12, 24, 0, 0),
#  'runtime': 85,
#  'title': 'Wild Love',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 7, 29, 18, 55, 29),
#               'viewer': {'numReviews': 2, 'rating': 0.0}},
#  'type': 'movie',
#  'writers': ['Pasquale Festa Campanile (story)',
#              'Massimo Franciosa (story)',
#              'Pasquale Festa Campanile (screenplay)',
#              'Massimo Franciosa (screenplay)',
#              'Giuseppe Mangione (screenplay)',
#              'Mauro Bolognini (screenplay)'],
#  'year': 1955}
# {'_id': ObjectId('573a13aff29313caabd3266f'),
#  'awards': {'nominations': 1, 'text': '6 wins & 1 nomination.', 'wins': 6},
#  'cast': ['Antoine Monot Jr.',
#           'Dominique Horwitz',
#           'Beate Bille',
#           'Joost Siedhoff'],
#  'countries': ['Germany'],
#  'directors': ['Till Franzen'],
#  'fullplot': 'Two very different love stories cross each other in warm and '
#              'magical way. A humanistic and yet mysterious film about love and '
#              'death near the German/Danish border.',
#  'genres': ['Drama', 'Mystery', 'Romance'],
#  'imdb': {'id': 400237, 'rating': 6.3, 'votes': 149},
#  'languages': ['German', 'Danish'],
#  'lastupdated': '2015-06-18 00:18:36.687000000',
#  'num_mflix_comments': 0,
#  'plot': 'Two very different love stories cross each other in warm and magical '
#          'way. A humanistic and yet mysterious film about love and death near '
#          'the German/Danish border.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTQ2MDYwNDU5OF5BMl5BanBnXkFtZTcwNTcwNzY5MQ@@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2005, 11, 24, 0, 0),
#  'runtime': 107,
#  'title': 'A Quiet Love',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 7, 30, 18, 22, 57),
#               'viewer': {'meter': 67, 'numReviews': 51, 'rating': 3.8}},
#  'type': 'movie',
#  'writers': ['Till Franzen (screenplay)'],
#  'year': 2005}
# {'_id': ObjectId('573a13b3f29313caabd3c93f'),
#  'awards': {'nominations': 0, 'text': '2 wins.', 'wins': 2},
#  'cast': ['Christian Camargo',
#           'Alexie Gilmore',
#           'Traci Dinwiddie',
#           'David P. Emrich'],
#  'countries': ['USA'],
#  'directors': ['Erica Dunton'],
#  'fullplot': '"Find Love" is the second feature from Uk writer/director Erica '
#              'Dunton. It is the partly-improvised and partly-scripted story of '
#              "two strangers who aren't looking for love but find it anyway. It "
#              'is a twenty-four hour romance ride that truthfully captures that '
#              'first feeling of falling for someone. Alexie Gilmore and '
#              'Christian Camargo lead in this very real, almost documentary '
#              'like, feature. They are supported by an incredible cast '
#              'including Craig Sheffer, Traci Dinwiddie and Cullen Moss.',
#  'genres': ['Romance'],
#  'imdb': {'id': 443507, 'rating': 6.4, 'votes': 176},
#  'languages': ['English'],
#  'lastupdated': '2015-05-13 00:40:41.263000000',
#  'num_mflix_comments': 1,
#  'plot': "Find Love is the story of two strangers who aren't looking for love "
#          'but find it anyway. It is a Twenty-Four hour romance ride that '
#          'truthfully captures that first feeling of falling for someone.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTc4NTgzNDg2N15BMl5BanBnXkFtZTcwMjA5NDIzMQ@@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2006, 1, 1, 0, 0),
#  'title': 'Find Love',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 8, 12, 18, 29, 17),
#               'viewer': {'meter': 50, 'numReviews': 194, 'rating': 3.0}},
#  'type': 'movie',
#  'writers': ['Erica Dunton'],
#  'year': 2006}
# {'_id': ObjectId('573a1398f29313caabcea846'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Nastassja Kinski',
#           'Jean-Hugues Anglade',
#           'Michel Piccoli',
#           'Jean-Claude Brialy'],
#  'countries': ['France'],
#  'directors': ['Jacques Deray'],
#  'fullplot': 'Mad love. Two physicians, one old and one young, fall in love '
#              'with the same woman, Juliette, a quixotic hairdresser. First, '
#              'she is with Raoul, the older one; then passion for Clèment, the '
#              'younger doctor, takes over. Raoul fights back, playing on '
#              "Clèment's guilt and Juliette's lack of self-assurance; then, "
#              'Clèment makes his case to Juliette, abandons his fiancèe, and '
#              'takes her to the provinces where he sets up practice and asks '
#              'her to have a baby. She panics and abruptly leaves Clèment, '
#              "taking up with Raoul again. When she contracts Hodgkin's disease "
#              'and the treatment does no good, Raoul believes she has the '
#              'malady of love. Is there a cure?',
#  'genres': ['Drama', 'Romance'],
#  'imdb': {'id': 93481, 'rating': 5.7, 'votes': 140},
#  'languages': ['French'],
#  'lastupdated': '2015-08-15 00:14:12.880000000',
#  'num_mflix_comments': 0,
#  'plot': 'Mad love. Two physicians, one old and one young, fall in love with '
#          'the same woman, Juliette, a quixotic hairdresser. First, she is with '
#          'Raoul, the older one; then passion for Clèment, the ...',
#  'released': datetime.datetime(1987, 9, 30, 0, 0),
#  'runtime': 122,
#  'title': 'Malady of Love',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 9, 3, 18, 38, 13),
#               'production': 'MGM',
#               'viewer': {'meter': 36, 'numReviews': 467, 'rating': 2.9}},
#  'type': 'movie',
#  'writers': ['Danièle Thompson', 'Andrzej Zulawski (story)'],
#  'year': 1987}
# {'_id': ObjectId('573a13d0f29313caabd8b450'),
#  'awards': {'nominations': 2, 'text': '4 wins & 2 nominations.', 'wins': 4},
#  'cast': ['Jane Alexander',
#           'Lindsay Almond Jr.',
#           'Edward L. Ayers',
#           'Leon M. Bazile'],
#  'countries': ['USA'],
#  'directors': ['Nancy Buirski'],
#  'fullplot': 'A racially-charged criminal trial and a heart-rending love story '
#              'converge in this documentary about Richard and Mildred Loving, '
#              'set during the turbulent Civil Rights era. Long Way Home: The '
#              'Loving Story is a story of love and the struggle for dignity set '
#              'against a backdrop of historic anti-miscegenation sentiments in '
#              'the U.S. The Lovings, an interracial couple, fell in love and '
#              'married at a critical time in American history, and, because of '
#              'a confluence of social and political turmoil our reluctant '
#              'heroes bring about change where previously no one else could. '
#              'They are paired with two young and ambitious lawyers who are '
#              'driven to pave the way for Civil Rights and social justice '
#              "through an historic Supreme Court ruling, changing the country's "
#              'story forever.',
#  'genres': ['Documentary', 'Drama', 'History'],
#  'imdb': {'id': 1759682, 'rating': 7.5, 'votes': 421},
#  'languages': ['English'],
#  'lastupdated': '2015-08-13 00:01:16.787000000',
#  'num_mflix_comments': 1,
#  'plot': 'A racially-charged criminal trial and a heart-rending love story '
#          'converge in this documentary about Richard and Mildred Loving, set '
#          'during the turbulent Civil Rights era. Long Way Home: The...',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTU2NTgxOTU3Ml5BMl5BanBnXkFtZTcwNDU2OTgxNw@@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2011, 4, 15, 0, 0),
#  'runtime': 77,
#  'title': 'The Loving Story',
#  'tomatoes': {'critic': {'meter': 100, 'numReviews': 16, 'rating': 8.5},
#               'dvd': datetime.datetime(2013, 5, 27, 0, 0),
#               'fresh': 16,
#               'lastUpdated': datetime.datetime(2015, 9, 15, 17, 48, 21),
#               'production': 'HBO Films',
#               'rotten': 0,
#               'viewer': {'meter': 86, 'numReviews': 929, 'rating': 4.2},
#               'website': 'http://lovingfilm.com/'},
#  'type': 'movie',
#  'writers': ['Nancy Buirski', 'Susie Ruth Powell'],
#  'year': 2011}
# {'_id': ObjectId('573a13b8f29313caabd4d14d'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Hayden Christensen',
#           'Andy Garcia',
#           'Rachel Bilson',
#           'Natalie Portman'],
#  'countries': ['USA'],
#  'directors': ['Fatih Akin',
#                'Yvan Attal',
#                'Randall Balsmeyer',
#                'Allen Hughes',
#                'Shunji Iwai',
#                'Wen Jiang',
#                'Shekhar Kapur',
#                'Joshua Marston',
#                'Mira Nair',
#                'Natalie Portman',
#                'Brett Ratner'],
#  'fullplot': 'Ten vignettes in New York City: a pickpocket meets his match; a '
#              'young Hasidic woman, on the eve of her marriage, reveals herself '
#              'to an Indian businessman; a writer tries a pick-up line; an '
#              'artist seeks a model; a composer needs to read; two women '
#              'connect; a man takes a child to Central Park; lovers meet; a '
#              'couple takes a walk on their anniversary; a kid goes to the prom '
#              'with a girl in a wheelchair; a retired singer contemplates '
#              'suicide. There are eight million stories in the naked city: '
#              'these have been ten of them.',
#  'genres': ['Comedy', 'Drama', 'Romance'],
#  'imdb': {'id': 808399, 'rating': 6.3, 'votes': 37661},
#  'languages': ['English', 'French', 'Cantonese', 'Gujarati', 'Yiddish'],
#  'lastupdated': '2015-09-16 10:43:52.363000000',
#  'metacritic': 49,
#  'num_mflix_comments': 0,
#  'plot': 'Several love stories set in one of the most loved cities of the '
#          'world, New York.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTI3NDYxOTM4OF5BMl5BanBnXkFtZTcwOTEwNTI4Mg@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2009, 10, 16, 0, 0),
#  'runtime': 103,
#  'title': 'New York, I Love You',
#  'tomatoes': {'boxOffice': '$1.6M',
#               'consensus': 'Like many anthologies, New York, I Love You has '
#                            "problems of consistency, but it isn't without its "
#                            'moments.',
#               'critic': {'meter': 36, 'numReviews': 95, 'rating': 5.0},
#               'dvd': datetime.datetime(2010, 2, 2, 0, 0),
#               'fresh': 34,
#               'lastUpdated': datetime.datetime(2015, 8, 21, 19, 20, 54),
#               'production': 'Vivendi Entertainment',
#               'rotten': 61,
#               'viewer': {'meter': 37, 'numReviews': 120383, 'rating': 2.9},
#               'website': 'http://www.newyorkiloveyouthemovie.com/'},
#  'type': 'movie',
#  'writers': ['Hu Hong (segment)',
#              'Yao Meng (segment)',
#              'Israel Horovitz (adaptation)',
#              'Suketu Mehta (segment)',
#              'Shunji Iwai (segment)',
#              'Israel Horovitz (adaptation)',
#              'Olivier Lècot (segment)',
#              'Jeff Nathanson (segment)',
#              'Xan Cassavetes (segment)',
#              'Stephen Winter (segment)',
#              'Anthony Minghella (segment)',
#              'Natalie Portman (segment)',
#              'Fatih Akin (segment)',
#              'Joshua Marston (segment)',
#              'Hall Powell (transitions "Randy Balsmeyer")',
#              'Israel Horovitz (transitions "Randy Balsmeyer")',
#              'James C. Strouse (transitions "Randy Balsmeyer")',
#              'Emmanuel Benbihy (concept)',
#              'Tristan Carnè (premise)'],
#  'year': 2008}
# {'_id': ObjectId('573a13e2f29313caabdbdd70'),
#  'awards': {'nominations': 1, 'text': '1 win & 1 nomination.', 'wins': 1},
#  'cast': ['Dorian Boguta',
#           'Dragos Bucur',
#           'Eugen Lumezianu',
#           'Silvia Morosanu'],
#  'countries': ['Romania'],
#  'directors': ['Iulia Rugina'],
#  'fullplot': 'Love Building is a camp designed to mend broken relationships. '
#              '14 couples in the program have 7 days to re-design their love '
#              'lives. But the 3 trainers meant to assist them have problems of '
#              'their own and things gradually get out of hand.',
#  'genres': ['Comedy'],
#  'imdb': {'id': 2792332, 'rating': 7.1, 'votes': 388},
#  'languages': ['Romanian'],
#  'lastupdated': '2015-05-19 02:26:26.467000000',
#  'num_mflix_comments': 1,
#  'plot': 'Love Building is a camp designed to mend broken relationships. 14 '
#          'couples in the program have 7 days to re-design their love lives. '
#          'But the 3 trainers meant to assist them have problems of their own '
#          'and things gradually get out of hand.',
#  'released': datetime.datetime(2013, 9, 13, 0, 0),
#  'runtime': 85,
#  'title': 'Love Building',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 6, 26, 20, 23, 45),
#               'viewer': {'numReviews': 9, 'rating': 2.8}},
#  'type': 'movie',
#  'writers': ['Ana Agopian', 'Oana Rasuceanu', 'Iulia Rugina'],
#  'year': 2013}
# {'_id': ObjectId('573a13baf29313caabd51faa'),
#  'awards': {'nominations': 1,
#             'text': 'Nominated for 1 Oscar. Another 12 wins & 1 nomination.',
#             'wins': 13},
#  'cast': ['Aleksandr Palamishev',
#           'Aleksandra Zhivova',
#           'Evgeniya Kryukova',
#           'Nina Ruslanova'],
#  'countries': ['Russia', 'Japan'],
#  'directors': ['Aleksandr Petrov'],
#  'genres': ['Animation', 'Short', 'Drama'],
#  'imdb': {'id': 874952, 'rating': 8.0, 'votes': 910},
#  'languages': ['Russian'],
#  'lastupdated': '2015-07-12 00:44:44.030000000',
#  'num_mflix_comments': 0,
#  'plot': 'In nineteenth-century Russia, a teenage boy in search of love is '
#          'drawn to two very different women.',
#  'released': datetime.datetime(2008, 2, 15, 0, 0),
#  'runtime': 26,
#  'title': 'My Love',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 8, 26, 18, 10, 15),
#               'viewer': {'meter': 89, 'numReviews': 90, 'rating': 4.1}},
#  'type': 'movie',
#  'writers': ['Ivan Shmelyov (screenplay)'],
#  'year': 2006}
# {'_id': ObjectId('573a13a8f29313caabd1d4a4'),
#  'awards': {'nominations': 7, 'text': '4 wins & 7 nominations.', 'wins': 4},
#  'cast': ['Renèe Zellweger',
#           'Ewan McGregor',
#           'Sarah Paulson',
#           'David Hyde Pierce'],
#  'countries': ['USA', 'Germany'],
#  'directors': ['Peyton Reed'],
#  'fullplot': 'An homage to the early 1960s sex comedies that starred Rock '
#              'Hudson and Doris Day. The story follows a best-selling female '
#              'advice author who has all the answers until a sly journalist '
#              'playboy starts asking the questions.',
#  'genres': ['Comedy', 'Romance'],
#  'imdb': {'id': 309530, 'rating': 6.3, 'votes': 31672},
#  'languages': ['English'],
#  'lastupdated': '2015-08-29 01:02:50.420000000',
#  'metacritic': 52,
#  'num_mflix_comments': 0,
#  'plot': "Aaaah... it's New York City in 1962, and love is blooming between a "
#          "journalist and a feminist advice author, who's falling head over "
#          "heels despite her beau's playboy lifestyle.",
#  'poster': 'https://m.media-amazon.com/images/M/MV5BYjY0OTMyNmMtODEwZS00ZWJiLWI0ZjctNmNiNmJjMTMzYWM1XkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2003, 5, 16, 0, 0),
#  'runtime': 101,
#  'title': 'Down with Love',
#  'tomatoes': {'critic': {'meter': 100, 'numReviews': 5, 'rating': 8.3},
#               'dvd': datetime.datetime(2005, 2, 15, 0, 0),
#               'fresh': 5,
#               'lastUpdated': datetime.datetime(2015, 9, 11, 18, 50, 56),
#               'rotten': 0,
#               'viewer': {'meter': 50, 'numReviews': 64, 'rating': 3.3}},
#  'type': 'movie',
#  'writers': ['Eve Ahlert', 'Dennis Drake'],
#  'year': 2003}
# {'_id': ObjectId('573a13a5f29313caabd14e36'),
#  'awards': {'nominations': 0, 'text': '3 wins.', 'wins': 3},
#  'cast': ['Joaquin Phoenix', 'Claire Danes', 'Sean Penn', 'Douglas Henshall'],
#  'countries': ['Italy',
#                'France',
#                'Canada',
#                'Spain',
#                'USA',
#                'Japan',
#                'Sweden',
#                'UK',
#                'Denmark',
#                'Germany',
#                'Netherlands'],
#  'directors': ['Thomas Vinterberg'],
#  'fullplot': "It's All About Love is the story of two lovers and their "
#              'attempts to save their relationship in a near-future world on '
#              'the brink of cosmic collapse. John, and world-famous ice skating '
#              'star, Elena, are about to sign divorce papers when they realise '
#              'that, in spite of everything happening around them, their love '
#              "is worth fighting for. It's All About Love is a fresh take on "
#              'modern love and future life as two lovers struggle in a '
#              'conspiracy of epic proportions.',
#  'genres': ['Drama', 'Thriller', 'Romance'],
#  'imdb': {'id': 273689, 'rating': 5.5, 'votes': 6964},
#  'languages': ['English'],
#  'lastupdated': '2015-08-12 00:00:48.250000000',
#  'metacritic': 32,
#  'num_mflix_comments': 1,
#  'plot': "It's All About Love is the story of two lovers and their attempts to "
#          'save their relationship in a near-future world on the brink of '
#          'cosmic collapse. John, and world-famous ice skating star,...',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTQzMzc1MDI3NV5BMl5BanBnXkFtZTcwNDQyMzcyMQ@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2003, 1, 10, 0, 0),
#  'runtime': 104,
#  'title': "It's All About Love",
#  'tomatoes': {'critic': {'meter': 14, 'numReviews': 29, 'rating': 3.8},
#               'dvd': datetime.datetime(2005, 9, 27, 0, 0),
#               'fresh': 4,
#               'lastUpdated': datetime.datetime(2015, 8, 6, 20, 15, 18),
#               'production': 'Focus Features',
#               'rotten': 25,
#               'viewer': {'meter': 26, 'numReviews': 1292, 'rating': 2.6},
#               'website': 'http://www.tvropa.com/itsallaboutlove/'},
#  'type': 'movie',
#  'writers': ['Mogens Rukov', 'Thomas Vinterberg'],
#  'year': 2003}
# {'_id': ObjectId('573a1396f29313caabce40a2'),
#  'awards': {'nominations': 1, 'text': '5 wins & 1 nomination.', 'wins': 5},
#  'cast': ['Ann-Sofie Kylin',
#           'Rolf Sohlman',
#           'Anita Lindblom',
#           'Bertil Norstrèm'],
#  'countries': ['Sweden'],
#  'directors': ['Roy Andersson'],
#  'fullplot': 'Two teenagers fall in love over the summer, in spite of cynical '
#              'and disapproving adults who dismiss their relationship as being '
#              'nothing but young love.',
#  'genres': ['Drama', 'Romance'],
#  'imdb': {'id': 65955, 'rating': 7.7, 'votes': 3732},
#  'languages': ['Swedish', 'Spanish'],
#  'lastupdated': '2015-07-17 02:07:05.880000000',
#  'num_mflix_comments': 1,
#  'plot': 'Two teenagers fall in love over the summer, in spite of cynical and '
#          'disapproving adults who dismiss their relationship as being nothing '
#          'but young love.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BZmE5MDdjNTctYzAwMy00N2RmLTk3NGUtZTM3MWRjODNlMzE0XkEyXkFqcGdeQXVyNzQxNDExNTU@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(1970, 4, 24, 0, 0),
#  'runtime': 115,
#  'title': 'A Swedish Love Story',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 8, 20, 18, 49, 2),
#               'production': 'Vèinèn Filmi',
#               'viewer': {'meter': 91, 'numReviews': 2417, 'rating': 4.2}},
#  'type': 'movie',
#  'writers': ['Roy Andersson'],
#  'year': 1970}
# {'_id': ObjectId('573a13eef29313caabdd6ff4'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Dylan Taylor',
#           'Melanie Scrofano',
#           'Meghan Heffern',
#           'Benjamin Ayres'],
#  'countries': ['Canada'],
#  'directors': ['Geordie Sabbagh'],
#  'fullplot': 'A struggling writer meets death and falls in love. He must '
#              'decide if his true love is in this world or the next, and if his '
#              'dreams of success are worth dying for.',
#  'genres': ['Drama', 'Fantasy', 'Romance'],
#  'imdb': {'id': 3611112, 'rating': '', 'votes': ''},
#  'languages': ['English'],
#  'lastupdated': '2015-09-11 00:04:53.430000000',
#  'num_mflix_comments': 0,
#  'plot': 'A struggling writer meets death and falls in love. He must decide if '
#          'his true love is in this world or the next, and if his dreams of '
#          'success are worth dying for.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTQ1MTQ5ODI2NF5BMl5BanBnXkFtZTgwMzc2MTg0MTE@._V1_SY1000_SX677_AL_.jpg',
#  'runtime': 93,
#  'title': 'A Sunday Kind of Love',
#  'type': 'movie',
#  'writers': ['Geordie Sabbagh', 'Geordie Sabbagh'],
#  'year': 2015}
# {'_id': ObjectId('573a139af29313caabcf1a82'),
#  'awards': {'nominations': 1, 'text': '2 wins & 1 nomination.', 'wins': 2},
#  'cast': ['Roman Klosowski', 'Iva Janzurovè', 'Milan Jelic', 'Milada Jezkovè'],
#  'countries': ['Czechoslovakia'],
#  'directors': ['Dusan Hanèk'],
#  'genres': ['Drama', 'Romance'],
#  'imdb': {'id': 123920, 'rating': 7.2, 'votes': 91},
#  'languages': ['Slovak'],
#  'lastupdated': '2015-03-15 00:52:30.840000000',
#  'num_mflix_comments': 0,
#  'released': datetime.datetime(1989, 2, 15, 0, 0),
#  'runtime': 95,
#  'title': 'I Love, You Love',
#  'tomatoes': {'critic': {'meter': 60, 'numReviews': 5, 'rating': 5.8},
#               'dvd': datetime.datetime(2000, 7, 11, 0, 0),
#               'fresh': 3,
#               'lastUpdated': datetime.datetime(2015, 9, 11, 17, 56, 34),
#               'production': 'Strand',
#               'rotten': 2,
#               'viewer': {'meter': 61, 'numReviews': 888, 'rating': 3.3}},
#  'type': 'movie',
#  'writers': ['Dusan Dusek', 'Dusan Hanèk'],
#  'year': 1989}
# {'_id': ObjectId('573a1399f29313caabcedd00'),
#  'awards': {'nominations': 3, 'text': '1 win & 3 nominations.', 'wins': 1},
#  'cast': ['Thomas Gibson', 'Ruth Marshall', 'Cameron Bancroft', 'Mia Kirshner'],
#  'countries': ['Canada'],
#  'directors': ['Denys Arcand'],
#  'fullplot': 'Set in a dreary urban landscape of an anonymous Canadian city, '
#              'LOVE AND HUMAN REMAINS is a dark comedy about a group of '
#              "twentysomethings looking for love and meaning in the '90s. The "
#              'film focuses on roommates David, a gay waiter who has has given '
#              'up on his acting career, and Candy, a book reviewer who is also '
#              "David's ex-lover. David and Candy's lives are entangled with "
#              "those of David's friends (a busboy, a psychic dominatrix, and a "
#              "misogynistic civil-servant) and Candy's dates (a male bartender "
#              'and a lesbian schoolteacher). Meanwhile, a serial killer menaces '
#              'the concrete and asphalt neighbourhood in which David and Candy '
#              'live.',
#  'genres': ['Drama', 'Comedy'],
#  'imdb': {'id': 107447, 'rating': 6.7, 'votes': 2046},
#  'languages': ['English'],
#  'lastupdated': '2015-08-09 00:54:17.820000000',
#  'num_mflix_comments': 0,
#  'plot': 'Set in a dreary urban landscape of an anonymous Canadian city, LOVE '
#          'AND HUMAN REMAINS is a dark comedy about a group of twentysomethings '
#          "looking for love and meaning in the '90s. The film ...",
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTcxMzQ2OTk5OF5BMl5BanBnXkFtZTcwMDUxNDMzMQ@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(1995, 6, 23, 0, 0),
#  'runtime': 100,
#  'title': 'Love & Human Remains',
#  'tomatoes': {'critic': {'meter': 67, 'numReviews': 12, 'rating': 6.5},
#               'dvd': datetime.datetime(1996, 1, 23, 0, 0),
#               'fresh': 8,
#               'lastUpdated': datetime.datetime(2015, 8, 14, 18, 42, 43),
#               'production': 'Sony Pictures Home Entertainment',
#               'rotten': 4,
#               'viewer': {'meter': 70, 'numReviews': 907, 'rating': 3.5}},
#  'type': 'movie',
#  'writers': ['Brad Fraser (play)', 'Brad Fraser (screenplay)'],
#  'year': 1993}
# {'_id': ObjectId('573a1397f29313caabce66c1'),
#  'awards': {'nominations': 4, 'text': '1 win & 4 nominations.', 'wins': 1},
#  'cast': ['Charles Denner',
#           'Brigitte Fossey',
#           'Nelly Borgeaud',
#           'Geneviève Fontanel'],
#  'countries': ['France'],
#  'directors': ['Franèois Truffaut'],
#  'fullplot': "Many women are attending Bertrand Morane's burial. They are all "
#              'the ones that 40 years old engineer loved. Flashback : '
#              "Bertrand's life and love affairs, told by himself while writing "
#              'an autobiographical novel. A film about the love relationships, '
#              'the need to charm and the literary creation.',
#  'genres': ['Comedy', 'Drama', 'Romance'],
#  'imdb': {'id': 76155, 'rating': 7.5, 'votes': 4560},
#  'languages': ['French'],
#  'lastupdated': '2015-09-01 01:01:55.007000000',
#  'num_mflix_comments': 1,
#  'plot': "Many women are attending Bertrand Morane's burial. They are all the "
#          "ones that 40 years old engineer loved. Flashback : Bertrand's life "
#          'and love affairs, told by himself while writing an ...',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMWIyM2ZiNDctOTJiYy00MzgyLTk2YzMtMzU2Y2Q5YjVkYjNkXkEyXkFqcGdeQXVyMjQzMzQzODY@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(1977, 4, 27, 0, 0),
#  'runtime': 120,
#  'title': 'The Man Who Loved Women',
#  'tomatoes': {'critic': {'meter': 90, 'numReviews': 10, 'rating': 7.0},
#               'dvd': datetime.datetime(2001, 1, 23, 0, 0),
#               'fresh': 9,
#               'lastUpdated': datetime.datetime(2015, 9, 14, 17, 16, 57),
#               'rotten': 1,
#               'viewer': {'meter': 85, 'numReviews': 3951, 'rating': 3.8}},
#  'type': 'movie',
#  'writers': ['Michel Fermaud', 'Suzanne Schiffman', 'Franèois Truffaut'],
#  'year': 1977}
# {'_id': ObjectId('573a139ff29313caabcff62d'),
#  'awards': {'nominations': 2, 'text': '2 nominations.', 'wins': 0},
#  'cast': ['Alessandro Nivola',
#           'Alicia Silverstone',
#           'Natascha McElhone',
#           'Kenneth Branagh'],
#  'countries': ['UK', 'France', 'USA'],
#  'directors': ['Kenneth Branagh'],
#  'fullplot': 'The King of Navarre and his three companions swear a very public '
#              'oath to study together and to renounce women for three years. '
#              'Their honour is immediately put to the test by the arrival of '
#              "the Princess of France and her three lovely companions. It's "
#              "love at first sight for all concerned followed by the men's "
#              'highly entertaining but hopeless efforts to disguise their '
#              'feelings.',
#  'genres': ['Romance', 'Comedy', 'Musical'],
#  'imdb': {'id': 182295, 'rating': 6.1, 'votes': 3701},
#  'languages': ['English'],
#  'lastupdated': '2015-07-31 00:49:30.863000000',
#  'metacritic': 35,
#  'num_mflix_comments': 1,
#  'plot': 'An update of the classic Shakespeare story, director Kenneth Branagh '
#          "shot this movie like a classic 30s musical. Love's Labour's Lost "
#          'tells the story of four best friends who swear off love.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTYxMjYzMDY4N15BMl5BanBnXkFtZTcwODU5ODEyMQ@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG',
#  'released': datetime.datetime(2000, 3, 31, 0, 0),
#  'runtime': 93,
#  'title': "Love's Labour's Lost",
#  'tomatoes': {'consensus': 'Interesting idea, poor execution.',
#               'critic': {'meter': 50, 'numReviews': 64, 'rating': 5.6},
#               'dvd': datetime.datetime(2000, 12, 19, 0, 0),
#               'fresh': 32,
#               'lastUpdated': datetime.datetime(2015, 9, 12, 17, 55, 28),
#               'production': 'Miramax Films',
#               'rotten': 32,
#               'viewer': {'meter': 40, 'numReviews': 3685, 'rating': 3.1},
#               'website': 'http://www.guildpathe.co.uk/LLL'},
#  'type': 'movie',
#  'writers': ['William Shakespeare (play)', 'Kenneth Branagh (screenplay)'],
#  'year': 2000}
# {'_id': ObjectId('573a13ccf29313caabd8181b'),
#  'awards': {'nominations': 2, 'text': '1 win & 2 nominations.', 'wins': 1},
#  'cast': ['Sirin Horwang',
#           'Theeradej Wongpuapan',
#           'Ungsumalynn Sirapatsakmetha',
#           'Piyakarn Butprasert'],
#  'countries': ['Thailand'],
#  'directors': ['Adisorn Trisirikasem'],
#  'fullplot': 'An urban love story set in the center of Bangkok where '
#              'thirty-year-old Mei Li struggling to find true love. When Mei Li '
#              'accidentally meets a handsome BTS engineer whom she considers as '
#              'the right man, she plans to make her first move. Though too many '
#              'obstacles keep popping up, Mei Li will never give up.',
#  'genres': ['Comedy', 'Romance'],
#  'imdb': {'id': 1621642, 'rating': 7.3, 'votes': 575},
#  'languages': ['Thai'],
#  'lastupdated': '2015-08-31 00:28:44.810000000',
#  'num_mflix_comments': 1,
#  'plot': 'An urban love story set in the center of Bangkok where '
#          'thirty-year-old Mei Li struggling to find true love. When Mei Li '
#          'accidentally meets a handsome BTS engineer whom she considers as the '
#          '...',
#  'released': datetime.datetime(2009, 10, 15, 0, 0),
#  'runtime': 126,
#  'title': 'Bangkok Traffic (Love) Story',
#  'type': 'movie',
#  'writers': ['Benjamaporn Srabua (screenplay)',
#              'Nawapol Thamrongrattanarit (screenplay)',
#              'Adisorn Trisirikasem (screenplay)'],
#  'year': 2009}
# {'_id': ObjectId('573a13d8f29313caabda8616'),
#  'awards': {'nominations': 5, 'text': '3 wins & 5 nominations.', 'wins': 3},
#  'cast': ['Selton Mello', 'Camila Pitanga', 'Rodrigo Santoro'],
#  'countries': ['Brazil'],
#  'directors': ['Luiz Bolognesi'],
#  'fullplot': 'In 1566, in Guanabara, the Tupinambè warrior Abeguar is in love '
#              'with Janaèna. When a jaguar attacks Abeguar and Janaèna, he '
#              'jumps off a cliff with her and he flies. The shaman advises '
#              'Abeguar that he was the chosen one by the god Munhè to lead his '
#              'tribe and fight against the evil Anhangè. When the tribe leader '
#              'Piatè joins the French in the fight against the Portuguese, the '
#              'entire Tupinambès are slaughtered and Abeguar turns into a bird '
#              'that flies for more than two hundred years to find Janaina. In '
#              '1825, the warrior is Manuel Balaio that lives with Janaèna and '
#              'their two daughters in Maranhèo. When one of his daughters is '
#              'raped by the abusive police commander, Balaio leads the '
#              'oppressed locals against the police and they take down the '
#              'Caxias city. The government sends Duque de Caxias and his troops '
#              'that vanquish the rebels and Balaio turns into a bird again that '
#              'flies for more than one hundred and forty years to find Janaèna '
#              'again. In 1968, in Rio, the warrior is Cau, but Janaèna is a '
#              'revolutionary student that lives with another insurgent. When '
#              'Cau and Janaèna are arrested by the repressive police, Cau rats '
#              'the insurgents to protect Janaèna from the torture and he '
#              'becomes an outcast by his former fellows. Only the jailer Feijèo '
#              'talks to him and Cau teaches him politics. With the amnesty, Cau '
#              'moves to the slums with Feijèo and becomes a teacher and member '
#              'of the criminal group Falange Vermelha. When the police invade '
#              'the slum, Cau turns into a bird again that flies for more than '
#              'one hundred years to find Janaèna again. In 2096, in Rio de '
#              'Janeiro, very few people can afford water that is mostly used in '
#              'the ethanol plantations by the governmental company Aquabrès. '
#              'The warrior is now a journalist and Janaèna a call-girl. When '
#              'the president of Aquabrès is kidnapped by a group of insurgents, '
#              'the warrior sees Janaèna on television and heads to Aquabrès to '
#              'save her.',
#  'genres': ['Animation', 'Drama', 'History'],
#  'imdb': {'id': 2231208, 'rating': 7.1, 'votes': 715},
#  'languages': ['Portuguese'],
#  'lastupdated': '2015-08-24 00:31:18.900000000',
#  'num_mflix_comments': 1,
#  'plot': 'Revolves around the love between an immortal hero and Janaèna, the '
#          "woman he has been in love with for 600 years, through Brazil's "
# ...
#              'on this case, she will discover the story of two women who, '
#              'despite appearing respectable on the outside have all manner of '
#              'darkness hidden away.',
#  'genres': ['Drama', 'Horror'],
#  'imdb': {'id': 1743724, 'rating': 6.8, 'votes': 2419},
#  'languages': ['Japanese'],
#  'lastupdated': '2015-08-28 00:03:10.050000000',
#  'metacritic': 56,
#  'num_mflix_comments': 0,
#  'plot': 'A grisly murder occurs in Maruyama-cho, Shibuya, Tokyo - a love '
#          'hotel district - a woman was found dead in a derelict apartment. '
#          'Kazuko (Miki Mizuno) is a police officer called to ...',
#  'released': datetime.datetime(2011, 11, 12, 0, 0),
#  'runtime': 144,
#  'title': 'Guilty of Romance',
#  'tomatoes': {'critic': {'meter': 69, 'numReviews': 16, 'rating': 5.7},
#               'dvd': datetime.datetime(2011, 11, 28, 0, 0),
#               'fresh': 11,
#               'lastUpdated': datetime.datetime(2015, 9, 13, 17, 54, 20),
#               'production': 'Olive Films',
#               'rotten': 5,
#               'viewer': {'meter': 59, 'numReviews': 446, 'rating': 3.4},
#               'website': 'http://www.koi-tumi.com/index.html'},
#  'type': 'movie',
#  'writers': ['Shion Sono (screenplay)'],
#  'year': 2011}
# {'_id': ObjectId('573a13cdf29313caabd85e41'),
#  'awards': {'nominations': 3, 'text': '5 wins & 3 nominations.', 'wins': 5},
#  'cast': ['Khaled Abol Naga', 'Menna Shalabi', 'Yousra El Lozy', 'Hani Adel'],
#  'countries': ['Egypt'],
#  'directors': ['Ahmad Abdalla'],
#  'fullplot': "Khaled returns from USA to his mother's funeral at his hometown: "
#              'Alexandria, Egypt. He decides to make it a fresh new start even '
#              'if it meant mending his first love story yet it proved a '
#              'horrific failure. Khaled clashed big time with a changing more '
#              'conservative Alexandria but He also stumbles upon fresh youth '
#              'struggling for their under-ground music bands, art and ideas. in '
#              'the middle of all the confusion, Will it ever all makes sense at '
#              'the end? A question for the youth and the city to answer.',
#  'genres': ['Comedy', 'Drama', 'Music'],
#  'imdb': {'id': 1684913, 'rating': 7.3, 'votes': 882},
#  'languages': ['Arabic'],
#  'lastupdated': '2015-08-22 00:37:49.750000000',
#  'num_mflix_comments': 1,
#  'plot': "Khaled returns from USA to his mother's funeral at his hometown: "
#          'Alexandria, Egypt. He decides to make it a fresh new start even if '
#          'it meant mending his first love story yet it proved a ...',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMjIxMDc4MzQ0NF5BMl5BanBnXkFtZTcwNzczNTg3Mw@@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2011, 9, 29, 0, 0),
#  'runtime': 120,
#  'title': 'Microphone',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 7, 25, 18, 12, 9),
#               'viewer': {'numReviews': 62, 'rating': 3.9}},
#  'type': 'movie',
#  'writers': ['Ahmad Abdalla (screenplay)'],
#  'year': 2010}
# {'_id': ObjectId('573a13ccf29313caabd837ba'),
#  'awards': {'nominations': 6, 'text': '1 win & 6 nominations.', 'wins': 1},
#  'cast': ['Jim Avignon', 'Stas Baretskiy', 'Dmitry Bogdan', 'Stepan Devonin'],
#  'countries': ['Russia'],
#  'directors': ['Sergey Loban'],
#  'fullplot': 'It is a movie-riddle, a movie-joke, a movie-labyrinth. 4 parts '
#              'and 4 travels to the sea, 4 crossed short stories: Love, '
#              'Friendship, Respect and Cooperation. Heroes of each of the short '
#              'stories arrive to seaside town, and go through turning fragments '
#              'of their life. Fragments develop almost synchronously - someone '
#              'goes mad of love, someone suffers as cannot be understood by '
#              "friends, someone tries to win father's respect, and someone - to "
#              'enter into cooperation with partners. As in life, when everyone '
#              'sees themselves as the center of their own drama, heroes of '
#              '"Chapiteau" are heroes in their own story, while in other '
#              "people's stories they are sometimes hardly visible characters. "
#              'Stories are full of tragic pathos - but this is the way everyone '
#              'goes through personal drama, when from outside it looks even '
#              'ridiculous. The more serious character is, the more comic he '
#              'behaves. Love, Friendship, Respect, Cooperation - colors in '
#              'which the life, its walls are painted. Going from one strip to '
#              'another we often do not notice that we run in circles, we live '
#              'the same situations, we say the same words. And sometimes we '
#              'find it hard to notice the border between what is happening "in '
#              'fact" and a chapiteau-show. The film employed professional, '
#              'semiprofessional and amateur actors.',
#  'genres': ['Comedy', 'Musical'],
#  'imdb': {'id': 1651118, 'rating': 7.7, 'votes': 784},
#  'languages': ['Russian'],
#  'lastupdated': '2015-07-13 00:20:43.183000000',
#  'num_mflix_comments': 0,
#  'plot': 'It is a movie-riddle, a movie-joke, a movie-labyrinth. 4 parts and 4 '
#          'travels to the sea, 4 crossed short stories: Love, Friendship, '
#          'Respect and Cooperation. Heroes of each of the short ...',
#  'released': datetime.datetime(2012, 1, 19, 0, 0),
#  'runtime': 207,
#  'title': 'Shapito-shou',
#  'type': 'movie',
#  'writers': ['Marina Potapova'],
#  'year': 2011}
# {'_id': ObjectId('573a13c7f29313caabd7646f'),
#  'awards': {'nominations': 3,
#             'text': 'Nominated for 1 Golden Globe. Another 2 wins & 3 '
#                     'nominations.',
#             'wins': 3},
#  'cast': ['Bill Murray', 'Laura Linney', 'Samuel West', 'Olivia Colman'],
#  'countries': ['UK'],
#  'directors': ['Roger Michell'],
#  'fullplot': 'In 1930s Hudson Valley, Margaret "Daisy" Suckley is reacquainted '
#              'with her distant cousin, President Franklin D. Roosevelt, to '
#              'help him relax at his family estate. That aid soon develops into '
#              'much more as they become lovers. That puts Daisy in a unique '
#              'position as Roosevelt receives the King and Queen of Britain in '
#              "1939 for a visit. As the Royal couple copes with the President's "
#              'oddly plebeian arrangements, Daisy learns that there is far more '
#              "to Roosevelt's life than she realized. With the world about to "
#              'be set ablaze by war, friendships are struck and perspectives '
#              'are gained on that special weekend that would make all the '
#              'difference with a great, but very human, president.',
#  'genres': ['Biography', 'Comedy', 'Drama'],
#  'imdb': {'id': 1477855, 'rating': 5.8, 'votes': 8540},
#  'languages': ['English'],
#  'lastupdated': '2015-08-16 01:13:00.090000000',
#  'metacritic': 55,
#  'num_mflix_comments': 1,
#  'plot': 'The story of the love affair between FDR and his distant cousin '
#          'Margaret "Daisy" Suckley, centered around the weekend in 1939 when '
#          'the King and Queen of the United Kingdom visited upstate New York.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNjU1MzU3Nzc4OF5BMl5BanBnXkFtZTcwOTk5NDI4Nw@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2013, 2, 1, 0, 0),
#  'runtime': 94,
#  'title': 'Hyde Park on Hudson',
#  'tomatoes': {'boxOffice': '$6.4M',
#               'consensus': 'Though bolstered by a thoroughly charming '
#                            'performance by Bill Murray in the central role, '
#                            'Hyde Park on Hudson is an FDR biopic that lets '
#                            'down both its audience and its subject.',
#               'critic': {'meter': 36, 'numReviews': 161, 'rating': 5.3},
#               'dvd': datetime.datetime(2013, 4, 9, 0, 0),
#               'fresh': 58,
#               'lastUpdated': datetime.datetime(2015, 9, 16, 17, 38, 42),
#               'production': 'Focus Features',
#               'rotten': 103,
#               'viewer': {'meter': 31, 'numReviews': 10507, 'rating': 2.9},
#               'website': 'http://focusfeatures.com/hyde_park_on_hudson'},
#  'type': 'movie',
#  'writers': ['Richard Nelson'],
#  'year': 2012}
# {'_id': ObjectId('573a13c5f29313caabd6eb12'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['Steve Clement', 'Thomas Montgomery', 'Ken Case', 'Rex Beaber'],
#  'countries': ['USA'],
#  'directors': ['Barbara Schroeder'],
#  'fullplot': 'This is the true story of a love triangle that takes place '
#              'entirely online. Lies lead to murder in real life, as a teenage '
#              "vixen (screen name 'talhotblond') lures men into her web. "
#              "Revealing a shocking true crime story that shows the Internet's "
#              'power to unleash our most dangerous fantasies.',
#  'genres': ['Documentary', 'Thriller'],
#  'imdb': {'id': 1370889, 'rating': 6.9, 'votes': 1951},
#  'languages': ['English'],
#  'lastupdated': '2015-09-12 00:15:12.707000000',
#  'num_mflix_comments': 0,
#  'plot': 'This is the true story of a love triangle that takes place entirely '
#          'online. Lies lead to murder in real life, as a teenage vixen (screen '
#          "name 'talhotblond') lures men into her web. ...",
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTMwMzUyNDYzNl5BMl5BanBnXkFtZTcwNzUxMjM1Mg@@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2009, 2, 1, 0, 0),
#  'runtime': 83,
#  'title': 'Talhotblond:',
#  'tomatoes': {'dvd': datetime.datetime(2010, 3, 23, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 8, 13, 19, 19, 7),
#               'production': 'Answers Productions',
#               'viewer': {'meter': 56, 'numReviews': 567, 'rating': 3.5},
#               'website': 'http://www.talhotblond.com/'},
#  'type': 'movie',
#  'writers': ['Barbara Schroeder',
#              'Pat Lalama (additional writing)',
#              'Glenn Boozan (additional writing)'],
#  'year': 2009}
# {'_id': ObjectId('573a13c5f29313caabd6e97f'),
#  'awards': {'nominations': 4,
#             'text': 'Won 1 Primetime Emmy. Another 1 win & 4 nominations.',
#             'wins': 2},
#  'cast': ['Selena Gomez', 'David Henrie', 'Jake T. Austin', 'Jennifer Stone'],
#  'countries': ['USA'],
#  'directors': ['Lev L. Spiro'],
#  'fullplot': 'When Alex ruins a family vacation by accidentally casting a '
#              'horrible spell on her loved ones, Max works overtime to keep his '
#              'parents from separating while Alex and Justin seek out the '
#              '"Stone of Dreams" in a desperate race to reverse the curse.',
#  'genres': ['Adventure', 'Comedy', 'Drama'],
#  'imdb': {'id': 1369845, 'rating': 6.4, 'votes': 8046},
#  'languages': ['English'],
#  'lastupdated': '2015-09-10 17:18:21.243000000',
#  'num_mflix_comments': 0,
#  'plot': 'Teenage wizard Alex casts a spell that accidentally changes history '
#          'so her parents never fell in love. She and her brothers face a race '
#          'against time to put things right before they are erased from '
#          'existence.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNzhmNzJlYzEtN2NkNS00MTM2LTlhNWEtMmQxNTM2NDRjNGRlXkEyXkFqcGdeQXVyMTkzODUwNzk@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'TV-G',
#  'released': datetime.datetime(2009, 8, 28, 0, 0),
#  'runtime': 94,
#  'title': 'Wizards of Waverly Place: The Movie',
#  'tomatoes': {'dvd': datetime.datetime(2009, 12, 15, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 8, 19, 18, 35, 18),
#               'viewer': {'meter': 67, 'numReviews': 22813, 'rating': 3.6}},
#  'type': 'movie',
#  'writers': ['Todd J. Greenwald (creator)', 'Dan Berendsen'],
#  'year': 2009}
# {'_id': ObjectId('573a13c2f29313caabd67487'),
#  'awards': {'nominations': 3, 'text': '3 nominations.', 'wins': 0},
#  'cast': ['Daniel Auteuil',
#           'Marie-Josèe Croze',
#           'Florence Loiret Caille',
#           'Christiane Millet'],
#  'countries': ['France', 'Italy', 'Belgium'],
#  'directors': ['Zabou Breitman'],
#  'fullplot': "Someone I loved (Je L'Aimais) is based on the best-selling novel "
#              "by Anna Gavalda. It's the story of Pierre (Daniel Auteuil), who "
#              'takes his daughter-in-law, Chloe (Florence Loiret Caille) and '
#              'two small granddaughters to the family chalet to stay following '
#              "a family crisis. Pierre's son, Adrian, has abruptly dumped his "
#              'wife and children, and Chloe who "never saw it coming" is so '
#              "emotionally devastated, Pierre thinks it's wise to take her away "
#              'somewhere quiet for a few days until she stabilizes.',
#  'genres': ['Drama', 'Romance'],
#  'imdb': {'id': 1258141, 'rating': 6.6, 'votes': 981},
#  'languages': ['French', 'English', 'Cantonese'],
#  'lastupdated': '2015-09-06 00:50:18.917000000',
#  'num_mflix_comments': 1,
#  'plot': "Someone I loved (Je L'Aimais) is based on the best-selling novel by "
#          "Anna Gavalda. It's the story of Pierre (Daniel Auteuil), who takes "
#          'his daughter-in-law, Chloe (Florence Loiret Caille) ...',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMzg0MTkyNjcyNV5BMl5BanBnXkFtZTcwMzAzODQzMw@@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2009, 5, 6, 0, 0),
#  'runtime': 113,
#  'title': "Je l'aimais",
#  'tomatoes': {'dvd': datetime.datetime(2010, 5, 4, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 8, 21, 19, 13, 49),
#               'production': 'SND',
#               'viewer': {'meter': 48, 'numReviews': 304, 'rating': 3.3}},
#  'type': 'movie',
#  'writers': ['Zabou Breitman (screenplay)',
#              'Anna Gavalda (novel)',
#              'Agnès de Sacy (screenplay)'],
#  'year': 2009}
# {'_id': ObjectId('573a13c2f29313caabd668e0'),
#  'awards': {'nominations': 3, 'text': '3 nominations.', 'wins': 0},
#  'cast': ['Bradley Cooper', 'Emma Stone', 'Rachel McAdams', 'Bill Murray'],
#  'countries': ['USA'],
#  'directors': ['Cameron Crowe'],
#  'fullplot': 'A celebrated military contractor returns to the site of his '
#              'greatest career triumphs - the US Space program in Honolulu, '
#              'Hawaii - and reconnects with a long-ago love while unexpectedly '
#              'falling for the hard-charging Air Force watchdog assigned to '
#              'him.',
#  'genres': ['Comedy', 'Drama', 'Romance'],
#  'imdb': {'id': 1243974, 'rating': 5.5, 'votes': 14076},
#  'languages': ['English'],
#  'lastupdated': '2015-09-02 00:02:30.273000000',
#  'metacritic': 40,
#  'num_mflix_comments': 1,
#  'plot': 'A celebrated military contractor returns to the site of his greatest '
#          'career triumphs and reconnects with a long-ago love while '
#          'unexpectedly falling for the hard-charging Air Force watch-dog '
#          'assigned to him.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTg4Mjc0NTE1NV5BMl5BanBnXkFtZTgwNzcwNTQ3NTE@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2015, 5, 29, 0, 0),
#  'runtime': 105,
#  'title': 'Aloha',
#  'tomatoes': {'boxOffice': '$21.1M',
#               'consensus': 'Meandering and insubstantial, Aloha finds '
#                            'writer-director Cameron Crowe at his most '
#                            'sentimental and least compelling.',
#               'critic': {'meter': 19, 'numReviews': 137, 'rating': 4.3},
#               'dvd': datetime.datetime(2015, 8, 25, 0, 0),
#               'fresh': 26,
#               'lastUpdated': datetime.datetime(2015, 8, 21, 18, 9, 32),
#               'production': 'Sony Pictures',
#               'rotten': 111,
#               'viewer': {'meter': 34, 'numReviews': 26281, 'rating': 2.7},
#               'website': 'http://www.sonypictures.com/movies/aloha/'},
#  'type': 'movie',
#  'writers': ['Cameron Crowe'],
#  'year': 2015}
# IOPub data rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_data_rate_limit`.
#
# Current values:
# NotebookApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# NotebookApp.rate_limit_window=3.0 (secs)

# %%
#2. Write a text search query to find movies where the word "war" appears in the title or plot, sorted by IMDb rating (Return only the top 5 results)

#collection.drop_index("title_text")
#collection.create_index([("title", "text"), ("plot", "text")])
#existing text index already includes title and plot so don't need to drop or create 

war_movies = collection.find({"$text": {"$search": "war"}}).sort("imdb.rating", -1).limit(5)

for movie in war_movies:
    pprint.pprint(movie)
# Out:
# {'_id': ObjectId('573a13eef29313caabdd676a'),
#  'awards': {'nominations': 1, 'text': '1 win & 1 nomination.', 'wins': 1},
#  'cast': ['Joe Berry', 'Uncle Bob', 'Sam Doungaphay', 'Sokmakara Hang'],
#  'countries': ['USA'],
#  'directors': ['Sara Dosa'],
#  'fullplot': 'In search of the lucrative matsutake mushroom, two former '
#              'soldiers discover the means to gradually heal their wounds of '
#              "war. Roger, a self-described 'fall-down drunk' and sniper in "
#              'Vietnam, and Kouy, a Cambodian refugee who fought the Khmer '
#              'Rouge, bonded in the bustling tent-city known as Mushroom Camp, '
#              'which pops up each autumn in the Oregon woods. Their friendship '
#              'became an adoptive family; according to a Cambodian custom, if '
#              'you lose your family like Kouy, you must rebuilt it anew. Now, '
#              "however, this new family could be lost. Roger's health is "
#              'declining and trauma flashbacks rack his mind; Kouy gently aids '
#              'his family before the snow falls and the hunting season ends, '
#              'signaling his time to leave.',
#  'genres': ['Documentary', 'Family', 'War'],
#  'imdb': {'id': 3593932, 'rating': '', 'votes': ''},
#  'languages': ['English'],
#  'lastupdated': '2014-09-20 04:04:23.547000000',
#  'num_mflix_comments': 1,
#  'plot': 'In search of the lucrative matsutake mushroom, two former soldiers '
#          'discover the means to gradually heal their wounds of war. Roger, a '
#          "self-described 'fall-down drunk' and sniper in Vietnam,...",
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTY2NDYzNDcyOF5BMl5BanBnXkFtZTgwNTAxNjkyMjE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2014, 4, 25, 0, 0),
#  'runtime': 78,
#  'title': 'The Last Season',
#  'type': 'movie',
#  'year': 2014}
# {'_id': ObjectId('573a13f2f29313caabddcf5f'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Pilou Asbèk', 'Tuva Novotny', 'Sèren Malling', 'Dar Salim'],
#  'countries': ['Denmark'],
#  'directors': ['Tobias Lindholm'],
#  'fullplot': 'Company commander Claus M. Pedersen (Pilou Asbèk) and his men '
#              'are stationed in an Afghan province. Meanwhile back in Denmark '
#              "Claus' wife Maria (Tuva Novotny) is trying to hold everyday life "
#              'together with a husband at war and three children missing their '
#              'father. During a routine mission, the soldiers are caught in '
#              'heavy crossfire and in order to save his men, Claus makes a '
#              'decision that has grave consequences for him - and his family '
#              'back home.',
#  'genres': ['Drama', 'War'],
#  'imdb': {'id': 3830162, 'rating': '', 'votes': ''},
#  'languages': ['Danish'],
#  'lastupdated': '2015-09-05 00:28:23.783000000',
#  'num_mflix_comments': 0,
#  'plot': 'Company commander Claus M. Pedersen (Pilou Asbèk) and his men are '
#          "stationed in an Afghan province. Meanwhile back in Denmark Claus' "
#          'wife Maria (Tuva Novotny) is trying to hold everyday life...',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMjA1ODY3NjQzNV5BMl5BanBnXkFtZTgwNjEzNTUxNzE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2015, 9, 10, 0, 0),
#  'title': 'A War',
#  'type': 'movie',
#  'writers': ['Tobias Lindholm'],
#  'year': 2015}
# {'_id': ObjectId('573a13e2f29313caabdbe708'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Robert Pattinson',
#           'Liam Cunningham',
#           'Stacy Martin',
#           'Bèrènice Bejo'],
#  'countries': ['France'],
#  'directors': ['Brady Corbet'],
#  'fullplot': 'This chilling fable about the rise of fascism in the 20th '
#              'Century tells the story of a young American boy living in France '
#              'in 1918 whose father is working for the US government on the '
#              'creation of the Treaty of Versailles. What he witnesses helps to '
#              'mould his beliefs - and we witness the birth of a terrifying '
#              'ego. Loosely inspired by the early childhood experiences of many '
#              'of the great dictators of the 20th Century and infused with the '
#              'same sense of dread as The Others and The Omen, The Childhood of '
#              'a Leader is an ominous portrait of emerging evil.',
#  'genres': ['Drama', 'Horror', 'Mystery'],
#  'imdb': {'id': 2815902, 'rating': '', 'votes': ''},
#  'lastupdated': '2015-08-31 00:00:22.140000000',
#  'num_mflix_comments': 1,
#  'plot': 'A look at the childhood life of a a post-World War I leader.',
#  'title': 'The Childhood of a Leader',
#  'tomatoes': {'lastUpdated': datetime.datetime(2014, 11, 16, 2, 47, 43),
#               'viewer': {'numReviews': 0, 'rating': 0.0}},
#  'type': 'movie',
#  'writers': ['Brady Corbet (screenplay)', 'Mona Fastvold'],
#  'year': 2015}
# {'_id': ObjectId('573a1398f29313caabcebc0b'),
#  'awards': {'nominations': 3,
#             'text': 'Won 2 Primetime Emmys. Another 8 wins & 3 nominations.',
#             'wins': 10},
#  'cast': ['Sam Waterston', 'Julie Harris', 'Jason Robards', 'Morgan Freeman'],
#  'countries': ['USA'],
#  'fullplot': 'This highly acclaimed mini series traces the course of the U.S. '
#              'Civil War from the abolitionist movement through all the major '
#              'battles to the death of President Lincoln and the beginnings of '
#              'Reconstruction. The story is mostly told in the words of the '
#              'participants themselves, through their diaries, letters, and '
#              'Visuals are usually still photographs and illustrations of the '
#              'time, and the soundtrack is likewise made up of war-era tunes '
#              'played on period instruments. Several modern-day historians '
#              "offer periodic comment and insight on the war's causes and "
#              'events.',
#  'genres': ['Documentary', 'History', 'War'],
#  'imdb': {'id': 98769, 'rating': 9.4, 'votes': 4625},
#  'languages': ['English'],
#  'lastupdated': '2015-09-01 00:13:15.693000000',
#  'num_mflix_comments': 1,
#  'plot': 'A comprehensive survey of the American Civil War.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BZDc1NzI2MGEtZDA2Yy00ZWExLTgwYmItNjU3N2QyYmM0MzYwXkEyXkFqcGdeQXVyNTA4NzY1MzY@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(1990, 9, 23, 0, 0),
#  'runtime': 680,
#  'title': 'The Civil War',
#  'tomatoes': {'dvd': datetime.datetime(2006, 1, 10, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 8, 25, 19, 21, 52),
#               'production': 'Pet Fly Productions',
#               'viewer': {'meter': 56, 'numReviews': 466, 'rating': 3.2}},
#  'type': 'series',
#  'year': 1990}
# {'_id': ObjectId('573a13a3f29313caabd0e77b'),
#  'awards': {'nominations': 3,
#             'text': 'Won 2 Primetime Emmys. Another 8 wins & 3 nominations.',
#             'wins': 10},
#  'cast': ['Sam Waterston', 'Julie Harris', 'Jason Robards', 'Morgan Freeman'],
#  'countries': ['USA'],
#  'fullplot': 'This highly acclaimed mini series traces the course of the U.S. '
#              'Civil War from the abolitionist movement through all the major '
#              'battles to the death of President Lincoln and the beginnings of '
#              'Reconstruction. The story is mostly told in the words of the '
#              'participants themselves, through their diaries, letters, and '
#              'Visuals are usually still photographs and illustrations of the '
#              'time, and the soundtrack is likewise made up of war-era tunes '
#              'played on period instruments. Several modern-day historians '
#              "offer periodic comment and insight on the war's causes and "
#              'events.',
#  'genres': ['Documentary', 'History', 'War'],
#  'imdb': {'id': 98769, 'rating': 9.4, 'votes': 4624},
#  'languages': ['English'],
#  'lastupdated': '2015-08-30 22:52:05.467000000',
#  'num_mflix_comments': 0,
#  'plot': 'A comprehensive survey of the American Civil War.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BZDc1NzI2MGEtZDA2Yy00ZWExLTgwYmItNjU3N2QyYmM0MzYwXkEyXkFqcGdeQXVyNTA4NzY1MzY@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(1990, 9, 23, 0, 0),
#  'runtime': 680,
#  'title': 'The Civil War',
#  'type': 'series',
#  'year': 1990}

# %% [markdown]
# # Exercise 6: Combining Multiple Queries (Bonus Exercise)
# Objective: Combine multiple queries to filter, sort, and transform data

# %%
#1. Write a query to find all movies where the genre is "Action" and the IMDb rating is greater than 8 (Sort the results by release year in descending order).
action_high_rated_movies = collection.find({"genres": "Action", "imdb.rating": {"$gt":
8}}).sort("year", -1)

for movie in action_high_rated_movies:
    pprint.pprint(movie)
# Out:
# {'_id': ObjectId('573a13bef29313caabd5b166'),
#  'awards': {'nominations': 3, 'text': '5 wins & 3 nominations.', 'wins': 5},
#  'cast': ['Vladimir Mashkov',
#           'Mikhail Porechenkov',
#           'Vladimir Menshov',
#           'Sergey Makovetskiy'],
#  'countries': ['Russia'],
#  'genres': ['Action', 'Thriller'],
#  'imdb': {'id': 1048097, 'rating': 8.6, 'votes': 929},
#  'languages': ['Russian', 'Ukrainian'],
#  'lastupdated': '2015-04-08 00:08:01.207000000',
#  'num_mflix_comments': 1,
#  'released': datetime.datetime(2007, 12, 2, 0, 0),
#  'runtime': 45,
#  'title': 'Liquidation',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 9, 13, 17, 10, 27),
#               'viewer': {'meter': 23, 'numReviews': 83, 'rating': 1.9}},
#  'type': 'series',
#  'year': '2007è'}
# {'_id': ObjectId('573a13bdf29313caabd586eb'),
#  'awards': {'nominations': 3, 'text': '5 wins & 3 nominations.', 'wins': 5},
#  'cast': ['Katie Gray', 'Victoria Harwood', 'Crispin Freeman', 'Ralph Lister'],
#  'countries': ['Japan'],
#  'fullplot': 'In flashback, Integra is seen assuming leadership of the '
#              'Hellsing organization as she resolves a conflict with her uncle '
#              'with the help of the vampire Alucard. In present day, Alucard '
#              'goes on a mission to the town of Cheddar to silence a vampiric '
#              'priest who has been killing townspeople, and in the process must '
#              'also present the young police girl Seras Victoria with the '
#              'choice to either die or become a vampire. Also, Alucard battles '
#              'a Vatican priest named Alexander Anderson after they are both '
#              'sent to kill the same vampire in Northern Ireland.',
#  'genres': ['Animation', 'Action', 'Fantasy'],
#  'imdb': {'id': 495212, 'rating': 8.5, 'votes': 8880},
#  'languages': ['Japanese'],
#  'lastupdated': '2015-09-05 08:36:26.777000000',
#  'num_mflix_comments': 0,
#  'plot': 'The vampire Alucard and his newly sired ward Seras tries to protect '
#          'England from a war-crazed SS-Major who seeks to start an eternal war '
#          'with his vampire army.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BYTU5ZWExZjktMmI5MC00MjUwLTk0MjAtNDExMDk1ZDUzZWY3XkEyXkFqcGdeQXVyNjc3OTE4Nzk@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'TV-MA',
#  'released': datetime.datetime(2006, 12, 5, 0, 0),
#  'runtime': 50,
#  'title': 'Hellsing Ultimate',
#  'type': 'series',
#  'writers': ['Kohta Hirano'],
#  'year': '2006è2012'}
# {'_id': ObjectId('573a13b6f29313caabd48af3'),
#  'awards': {'nominations': 3, 'text': '5 wins & 3 nominations.', 'wins': 5},
#  'cast': ['Katie Gray', 'Victoria Harwood', 'Crispin Freeman', 'Ralph Lister'],
#  'countries': ['Japan'],
#  'fullplot': 'In flashback, Integra is seen assuming leadership of the '
#              'Hellsing organization as she resolves a conflict with her uncle '
#              'with the help of the vampire Alucard. In present day, Alucard '
#              'goes on a mission to the town of Cheddar to silence a vampiric '
#              'priest who has been killing townspeople, and in the process must '
#              'also present the young police girl Seras Victoria with the '
#              'choice to either die or become a vampire. Also, Alucard battles '
#              'a Vatican priest named Alexander Anderson after they are both '
#              'sent to kill the same vampire in Northern Ireland.',
#  'genres': ['Animation', 'Action', 'Fantasy'],
#  'imdb': {'id': 495212, 'rating': 8.5, 'votes': 8525},
#  'languages': ['Japanese'],
#  'lastupdated': '2015-08-17 00:55:25.017000000',
#  'num_mflix_comments': 0,
#  'plot': 'The vampire Alucard and his newly sired ward Seras tries to protect '
#          'England from a war-crazed SS-Major who seeks to start an eternal war '
#          'with his vampire army.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BYTU5ZWExZjktMmI5MC00MjUwLTk0MjAtNDExMDk1ZDUzZWY3XkEyXkFqcGdeQXVyNjc3OTE4Nzk@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'TV-MA',
#  'released': datetime.datetime(2006, 12, 5, 0, 0),
#  'runtime': 50,
#  'title': 'Hellsing Ultimate',
#  'tomatoes': {'dvd': datetime.datetime(2003, 12, 9, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 8, 21, 18, 39, 56),
#               'viewer': {'meter': 93, 'numReviews': 1510, 'rating': 3.2}},
#  'type': 'series',
#  'writers': ['Kohta Hirano'],
#  'year': '2006è2012'}
# {'_id': ObjectId('573a1399f29313caabced750'),
#  'awards': {'nominations': 25,
#             'text': 'Won 1 Primetime Emmy. Another 16 wins & 25 nominations.',
#             'wins': 17},
#  'cast': ['Jerry Doyle', 'Mira Furlan', 'Richard Biggs', 'Bill Mumy'],
#  'countries': ['USA'],
#  'genres': ['Action', 'Adventure', 'Drama'],
#  'imdb': {'id': 105946, 'rating': 8.2, 'votes': 21109},
#  'languages': ['English'],
#  'lastupdated': '2015-09-16 07:39:16.083000000',
#  'num_mflix_comments': 0,
#  'plot': 'A space station in neutral territory is the focus of a unique five '
#          'year saga.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BN2Q3ZWM0YzgtMGU0Mi00OWM0LWIwNzctNmQ4NTUyYTk0ZWY2XkEyXkFqcGdeQXVyMzYyMzU2OA@@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(1994, 1, 26, 0, 0),
#  'runtime': 45,
#  'title': 'Babylon 5',
#  'tomatoes': {'dvd': datetime.datetime(2009, 9, 15, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 9, 15, 18, 31, 13),
#               'viewer': {'numReviews': 5, 'rating': 0.0}},
#  'type': 'series',
#  'writers': ['J. Michael Straczynski'],
#  'year': '1994è1998'}
# {'_id': ObjectId('573a13ecf29313caabdd21a3'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['David Sandberg', 'Jorma Taccone', 'Steven Chew', 'Leopold Nilsson'],
#  'countries': ['Sweden'],
#  'directors': ['David Sandberg'],
#  'fullplot': 'During an unfortunate series of events a friend of Kung Fury is '
#              'assassinated by the most dangerous kung fu master criminal of '
#              'all time; Adolf Hitler, a.k.a Kung Fèhrer. Kung Fury decides to '
#              'travel back in time, to Nazi Germany, in order to kill Hitler '
#              'and end the Nazi empire once and for all.',
#  'genres': ['Short', 'Action', 'Comedy'],
#  'imdb': {'id': 3472226, 'rating': 8.3, 'votes': 24575},
#  'languages': ['English', 'Swedish', 'German'],
#  'lastupdated': '2015-09-10 17:20:55.477000000',
#  'num_mflix_comments': 2,
#  'plot': 'In 1985, Kung Fury, the toughest martial artist cop in Miami, goes '
#          'back in time to kill the worst criminal of all time - kung fuhrer '
#          'Hitler.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMjQwMjU2ODU5NF5BMl5BanBnXkFtZTgwNTU1NjM4NTE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2015, 5, 28, 0, 0),
#  'runtime': 31,
#  'title': 'Kung Fury',
#  'type': 'movie',
#  'writers': ['David Sandberg'],
#  'year': 2015}
# {'_id': ObjectId('573a13dff29313caabdb72de'),
#  'awards': {'nominations': 2, 'text': '1 win & 2 nominations.', 'wins': 1},
#  'cast': ['Conrad Anker', 'Grace Chin', 'Jimmy Chin', 'Amee Hinkley'],
#  'countries': ['India', 'USA'],
#  'directors': ['Jimmy Chin', 'Elizabeth Chai Vasarhelyi'],
#  'fullplot': 'Three elite climbers struggle to find their way through '
#              'obsession and loss as they attempt to climb Mount Meru, one of '
#              'the most coveted prizes in the high stakes game of Himalayan big '
#              'wall climbing.',
#  'genres': ['Documentary', 'Action', 'Adventure'],
#  'imdb': {'id': 2545428, 'rating': 8.3, 'votes': 263},
#  'languages': ['English'],
#  'lastupdated': '2015-09-04 00:13:00.430000000',
#  'metacritic': 75,
#  'num_mflix_comments': 1,
#  'plot': 'Three elite climbers struggle to find their way through obsession '
#          'and loss as they attempt to climb Mount Meru, one of the most '
#          'coveted prizes in the high stakes game of Himalayan big wall '
#          'climbing.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTQ4MDM3NjY2Nl5BMl5BanBnXkFtZTgwNjkyNTIzNjE@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2015, 8, 14, 0, 0),
#  'runtime': 87,
#  'title': 'Meru',
#  'tomatoes': {'boxOffice': '$0.7M',
#               'consensus': 'Gripping visually as well as narratively, Meru is '
#                            'the rare documentary that proves thought-provoking '
#                            'while offering thrilling wide-screen vistas.',
#               'critic': {'meter': 93, 'numReviews': 45, 'rating': 7.6},
#               'fresh': 42,
#               'lastUpdated': datetime.datetime(2015, 9, 3, 19, 0, 34),
#               'production': 'Music Box Films',
#               'rotten': 3,
#               'viewer': {'meter': 96, 'numReviews': 1509, 'rating': 4.5},
#               'website': 'http://www.merufilm.com/'},
#  'type': 'movie',
#  'year': 2015}
# {'_id': ObjectId('573a13daf29313caabdad25f'),
#  'awards': {'nominations': 0, 'text': '2 wins.', 'wins': 2},
#  'cast': ['John G. Avildsen',
#           'Billy Blanks',
#           'Lauro Chartrand',
#           'Michael Chavez'],
#  'countries': ['USA', 'Canada', 'Japan', 'Panama'],
#  'directors': ['Kevin Derek'],
#  'fullplot': 'The life of the greatest karate master of a generation.',
#  'genres': ['Documentary', 'Action', 'History'],
#  'imdb': {'id': 2313306, 'rating': 9.3, 'votes': 41},
#  'languages': ['English'],
#  'lastupdated': '2015-08-22 00:43:31.983000000',
#  'num_mflix_comments': 0,
#  'plot': 'The life of the greatest karate master of a generation.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTY3MjI0MjA1OF5BMl5BanBnXkFtZTgwMTI3Nzc2MjE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2015, 2, 20, 0, 0),
#  'runtime': 90,
#  'title': 'The Real Miyagi',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 7, 6, 19, 58, 30),
#               'production': 'Breaking Glass Pictures',
#               'viewer': {'meter': 0, 'numReviews': 37, 'rating': 2.2},
#               'website': 'http://tennesseequeer.popslice.com'},
#  'type': 'movie',
#  'writers': ['Kevin Derek', 'Kevin Derek'],
#  'year': 2015}
# {'_id': ObjectId('573a13c5f29313caabd70568'),
#  'awards': {'nominations': 3, 'text': '1 win & 3 nominations.', 'wins': 1},
#  'cast': ['Tom Hardy', 'Charlize Theron', 'Nicholas Hoult', 'Hugh Keays-Byrne'],
#  'countries': ['Australia', 'USA'],
#  'directors': ['George Miller'],
#  'fullplot': 'An apocalyptic story set in the furthest reaches of our planet, '
#              'in a stark desert landscape where humanity is broken, and almost '
#              'everyone is crazed fighting for the necessities of life. Within '
#              'this world exist two rebels on the run who just might be able to '
#              "restore order. There's Max, a man of action and a man of few "
#              'words, who seeks peace of mind following the loss of his wife '
#              'and child in the aftermath of the chaos. And Furiosa, a woman of '
#              'action and a woman who believes her path to survival may be '
#              'achieved if she can make it across the desert back to her '
#              'childhood homeland.',
#  'genres': ['Action', 'Adventure', 'Sci-Fi'],
#  'imdb': {'id': 1392190, 'rating': 8.3, 'votes': 314071},
#  'languages': ['English', 'Russian'],
#  'lastupdated': '2015-09-10 17:05:45.723000000',
#  'metacritic': 89,
#  'num_mflix_comments': 1,
#  'plot': 'A woman rebels against a tyrannical ruler in post apocalyptic '
#          'Australia in search for her homeland with the help of a group of '
#          'female prisoners, a psychotic worshiper, and a drifter named Max.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BN2EwM2I5OWMtMGQyMi00Zjg1LWJkNTctZTdjYTA4OGUwZjMyXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2015, 5, 15, 0, 0),
#  'runtime': 120,
#  'title': 'Mad Max: Fury Road',
#  'tomatoes': {'boxOffice': '$153.1M',
#               'consensus': 'With exhilarating action and a surprising amount '
#                            'of narrative heft, Mad Max: Fury Road brings '
#                            "George Miller's post-apocalyptic franchise roaring "
#                            'vigorously back to life.',
#               'critic': {'meter': 97, 'numReviews': 301, 'rating': 8.7},
#               'dvd': datetime.datetime(2015, 9, 1, 0, 0),
#               'fresh': 292,
#               'lastUpdated': datetime.datetime(2015, 9, 12, 17, 9, 27),
#               'production': 'Warner Bros.',
#               'rotten': 9,
#               'viewer': {'meter': 88, 'numReviews': 103105, 'rating': 4.3},
#               'website': 'http://www.madmaxmovie.com/'},
#  'type': 'movie',
#  'writers': ['George Miller', 'Brendan McCarthy', 'Nick Lathouris'],
#  'year': 2015}
# {'_id': ObjectId('573a13eff29313caabdd7dbc'),
#  'awards': {'nominations': 8, 'text': '5 wins & 8 nominations.', 'wins': 5},
#  'cast': ['Serkan Keskin', 'Hazal Kaya', 'èner Erkan', 'Osman Sonant'],
#  'countries': ['Turkey'],
#  'directors': ['Onur ènlè'],
#  'fullplot': 'There is a murder while at prayer. Selman Bulut, the imam of '
#              'mosque, starts to investigate the murder and faces with people '
#              'in the neighborhood.',
#  'genres': ['Action', 'Crime', 'Drama'],
#  'imdb': {'id': 3646462, 'rating': 8.1, 'votes': 3587},
#  'languages': ['Turkish'],
#  'lastupdated': '2015-08-23 01:17:38.520000000',
#  'num_mflix_comments': 1,
#  'plot': 'There is a murder while at prayer. Selman Bulut, the imam of mosque, '
#          'starts to investigate the murder and faces with people in the '
#          'neighborhood.',
#  'released': datetime.datetime(2014, 4, 18, 0, 0),
#  'runtime': 110,
#  'title': "Let's Sin",
#  'type': 'movie',
#  'writers': ['Onur ènlè'],
#  'year': 2014}
# {'_id': ObjectId('573a13e0f29313caabdba169'),
#  'awards': {'nominations': 1, 'text': '6 wins & 1 nomination.', 'wins': 6},
#  'cast': ['Elina Abai Kyzy',
#           'Nasira Mambetova',
#           'Aziz Muradillayev',
#           'Adilet Usubaliyev'],
#  'countries': ['Kyrgyzstan'],
#  'directors': ['Sadyk Sher-Niyaz'],
#  'fullplot': 'The historical, epic drama, set in 19th century Central Asia, '
#              'tells the true story of Kurmanjan Datka, a strong willed woman, '
#              'who becomes the ruler of her country and saves the nation from '
#              'total destruction. As a young woman she is forced into an '
#              'arranged marriage but escapes, flees to the mountains and falls '
#              'in love with the local chief Alymbek, whom she marries. When he '
#              'is killed by political rivals, she becomes the "queen of the '
#              'mountains" and a key figure and negotiator in the national '
#              'struggle, when the Russians invade.',
#  'genres': ['Action', 'Biography', 'Drama'],
#  'imdb': {'id': 2640460, 'rating': 8.6, 'votes': 3106},
#  'languages': ['English', 'Kirghiz', 'Russian'],
#  'lastupdated': '2015-08-25 01:09:37.977000000',
#  'num_mflix_comments': 0,
#  'plot': 'The relevant epic story of the strong-willed, courageous and '
#          'independent woman before her time, Kurmanjan, who is revered to this '
#          'day for her diplomacy for saving her nation from complete '
#          'destruction when the Russians invaded.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMjE0ODAxNDQ0MV5BMl5BanBnXkFtZTgwNzY1MDUyMjE@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2015, 1, 6, 0, 0),
#  'runtime': 135,
#  'title': 'Queen of the Mountains',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 9, 13, 18, 1, 44),
#               'viewer': {'meter': 50, 'numReviews': 17, 'rating': 3.4},
#               'website': 'http://www.kurmanjan.com/'},
#  'type': 'movie',
#  'writers': ['Sadyk Sher-Niyaz (screenplay)',
#              'Bakytbek Turdubaev',
#              'Bakyt Turdubayev (creator)'],
#  'year': 2014}
# {'_id': ObjectId('573a13d9f29313caabda92ff'),
#  'awards': {'nominations': 80,
#             'text': 'Nominated for 2 Oscars. Another 43 wins & 80 nominations.',
#             'wins': 45},
#  'cast': ['Chris Pratt', 'Zoe Saldana', 'Dave Bautista', 'Vin Diesel'],
#  'countries': ['USA', 'UK'],
#  'directors': ['James Gunn'],
#  'fullplot': 'After stealing a mysterious orb in the far reaches of outer '
#              'space, Peter Quill from Earth, is now the main target of a '
#              'manhunt led by the villain known as Ronan the Accuser. To help '
#              'fight Ronan and his team and save the galaxy from his power, '
#              'Quill creates a team of space heroes known as the "Guardians of '
#              'the Galaxy" to save the world.',
#  'genres': ['Action', 'Adventure', 'Sci-Fi'],
#  'imdb': {'id': 2015381, 'rating': 8.1, 'votes': 548314},
#  'languages': ['English'],
#  'lastupdated': '2015-09-15 22:57:02.667000000',
#  'metacritic': 76,
#  'num_mflix_comments': 1,
#  'plot': 'A group of intergalactic criminals are forced to work together to '
#          'stop a fanatical warrior from taking control of the universe.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTAwMjU5OTgxNjZeQTJeQWpwZ15BbWU4MDUxNDYxODEx._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2014, 8, 1, 0, 0),
#  'runtime': 121,
#  'title': 'Guardians of the Galaxy',
#  'tomatoes': {'boxOffice': '$333.2M',
#               'consensus': 'Guardians of the Galaxy is just as irreverent as '
#                            'fans of the frequently zany Marvel comic would '
#                            'expect -- as well as funny, thrilling, full of '
#                            'heart, and packed with visual splendor.',
#               'critic': {'meter': 91, 'numReviews': 273, 'rating': 7.8},
#               'dvd': datetime.datetime(2014, 12, 9, 0, 0),
#               'fresh': 249,
#               'lastUpdated': datetime.datetime(2015, 9, 10, 17, 5, 17),
#               'production': 'Walt Disney Pictures',
#               'rotten': 24,
#               'viewer': {'meter': 92, 'numReviews': 241767, 'rating': 4.4},
#               'website': 'http://marvel.com/guardians'},
#  'type': 'movie',
#  'writers': ['James Gunn',
#              'Nicole Perlman',
#              'Dan Abnett (comic book)',
#              'Andy Lanning (comic book)'],
#  'year': 2014}
# {'_id': ObjectId('573a13d5f29313caabd9c312'),
#  'awards': {'nominations': 81,
#             'text': 'Nominated for 2 Oscars. Another 42 wins & 81 nominations.',
#             'wins': 44},
#  'cast': ['Chris Pratt', 'Zoe Saldana', 'Dave Bautista', 'Vin Diesel'],
#  'countries': ['USA', 'UK'],
#  'directors': ['James Gunn'],
#  'fullplot': 'After stealing a mysterious orb in the far reaches of outer '
#              'space, Peter Quill from Earth, is now the main target of a '
#              'manhunt led by the villain known as Ronan the Accuser. To help '
#              'fight Ronan and his team and save the galaxy from his power, '
#              'Quill creates a team of space heroes known as the "Guardians of '
#              'the Galaxy" to save the world.',
#  'genres': ['Action', 'Adventure', 'Sci-Fi'],
#  'imdb': {'id': 2015381, 'rating': 8.1, 'votes': 539583},
#  'languages': ['English'],
#  'lastupdated': '2015-08-28 00:00:43.957000000',
#  'metacritic': 76,
#  'num_mflix_comments': 0,
#  'plot': 'A group of intergalactic criminals are forced to work together to '
#          'stop a fanatical warrior from taking control of the universe.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTAwMjU5OTgxNjZeQTJeQWpwZ15BbWU4MDUxNDYxODEx._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2014, 8, 1, 0, 0),
#  'runtime': 121,
#  'title': 'Guardians of the Galaxy',
#  'tomatoes': {'boxOffice': '$333.2M',
#               'consensus': 'Guardians of the Galaxy is just as irreverent as '
#                            'fans of the frequently zany Marvel comic would '
#                            'expect -- as well as funny, thrilling, full of '
#                            'heart, and packed with visual splendor.',
#               'critic': {'meter': 91, 'numReviews': 273, 'rating': 7.8},
#               'dvd': datetime.datetime(2014, 12, 9, 0, 0),
#               'fresh': 249,
#               'lastUpdated': datetime.datetime(2015, 9, 10, 17, 5, 17),
#               'production': 'Walt Disney Pictures',
#               'rotten': 24,
#               'viewer': {'meter': 92, 'numReviews': 241767, 'rating': 4.4},
#               'website': 'http://marvel.com/guardians'},
#  'type': 'movie',
#  'writers': ['James Gunn',
#              'Nicole Perlman',
#              'Dan Abnett (comic book)',
#              'Andy Lanning (comic book)'],
#  'year': 2014}
# {'_id': ObjectId('573a13d3f29313caabd947a8'),
#  'awards': {'nominations': 38,
#             'text': 'Nominated for 1 Oscar. Another 9 wins & 38 nominations.',
#             'wins': 10},
#  'cast': ['Hugh Jackman',
#           'James McAvoy',
#           'Michael Fassbender',
#           'Jennifer Lawrence'],
#  'countries': ['USA', 'UK', 'Canada'],
#  'directors': ['Bryan Singer'],
#  'fullplot': 'Sentinels, robots that were created for the purpose of hunting '
#              'down mutants were released in 1973. 50 years later the Sentinels '
#              'would also hunt humans who aid mutants. Charles Xavier and his '
#              'X-Men try their best to deal with the Sentinels but they are '
#              'able to adapt and deal with all mutant abilities. Charles '
#              'decides to go back in time and change things. He asks Kitty '
#              "Pryde who can send a person's consciousness into the person's "
#              'past to send him but she can only send someone back a few weeks '
#              'because if she sends someone back further it could harm them. So '
#              'Logan decides to go back himself because he might be able to '
#              "withstand it. So Charles tells him that it's Mystique who's "
#              'responsible because when she learned about the Sentinels she '
#              'sought out Bolivar Trask the man who created them and killed '
#              'him. She would be caught and studied and her ability to change '
#              'was somehow added to the Sentinels which is why they can adapt. '
#              'Logan must go to the younger Charles and ask him to help; '
#              'problem is that he was despondent at that time and without his '
#              'powers because he took a drug which allows him to walk but takes '
#              'away his powers. Logan is also told to find Magneto.',
#  'genres': ['Action', 'Adventure', 'Sci-Fi'],
#  'imdb': {'id': 1877832, 'rating': 8.1, 'votes': 436254},
#  'languages': ['English', 'Vietnamese', 'French'],
#  'lastupdated': '2015-08-31 00:09:15.700000000',
#  'metacritic': 74,
#  'num_mflix_comments': 0,
#  'plot': 'The X-Men send Wolverine to the past in a desperate effort to change '
#          'history and prevent an event that results in doom for both humans '
#          'and mutants.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BZGIzNWYzN2YtMjcwYS00YjQ3LWI2NjMtOTNiYTUyYjE2MGNkXkEyXkFqcGdeQXVyMTQxNzMzNDI@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2014, 5, 23, 0, 0),
#  'runtime': 132,
#  'title': 'X-Men: Days of Future Past',
#  'tomatoes': {'boxOffice': '$233.9M',
#               'consensus': 'X-Men: Days of Future Past combines the best '
#                            'elements of the series to produce a satisfyingly '
#                            "fast-paced outing that ranks among the franchise's "
#                            'finest installments.',
#               'critic': {'meter': 91, 'numReviews': 270, 'rating': 7.6},
#               'dvd': datetime.datetime(2014, 10, 14, 0, 0),
#               'fresh': 245,
#               'lastUpdated': datetime.datetime(2015, 8, 22, 18, 6, 53),
#               'production': '20th Century Fox',
#               'rotten': 25,
#               'viewer': {'meter': 92, 'numReviews': 270716, 'rating': 4.3},
#               'website': 'http://www.x-menmovies.com/'},
#  'type': 'movie',
#  'writers': ['Simon Kinberg (screenplay)',
#              'Jane Goldman (story)',
#              'Simon Kinberg (story)',
#              'Matthew Vaughn (story)'],
#  'year': 2014}
# {'_id': ObjectId('573a13d8f29313caabda6b38'),
#  'awards': {'nominations': 10, 'text': '2 wins & 10 nominations.', 'wins': 2},
#  'cast': ['Kamal Haasan', 'Rahul Bose', 'Shekhar Kapur', 'Pooja Kumar'],
#  'countries': ['India'],
#  'directors': ['Kamal Haasan'],
#  'fullplot': 'Vishwanathan, a Kathak dance teacher in New York, is in a rather '
#              'happy marriage with Nirupama who is a nuclear oncologist. She '
#              'hires a detective to keep a watch on her husband, who apparently '
#              "ends up in a wrong place that reveals Vishwanathan's true "
#              'identity.',
#  'genres': ['Action', 'Adventure', 'Crime'],
#  'imdb': {'id': 2199711, 'rating': 8.8, 'votes': 33015},
#  'languages': ['Tamil', 'Hindi', 'Telugu', 'Arabic', 'Pushto'],
#  'lastupdated': '2015-08-24 00:59:33.400000000',
#  'num_mflix_comments': 0,
#  'plot': 'Vishwanathan, a Kathak dance teacher in New York, is in a rather '
#          'happy marriage with Nirupama who is a nuclear oncologist. She hires '
#          'a detective to keep a watch on her husband, who ...',
#  'released': datetime.datetime(2013, 1, 25, 0, 0),
#  'runtime': 148,
#  'title': 'Vishwaroopam',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 9, 14, 18, 2, 3),
#               'production': 'Blue Sky Cinemas',
#               'viewer': {'meter': 82, 'numReviews': 559, 'rating': 4.1}},
#  'type': 'movie',
#  'writers': ['Kamal Haasan', 'Atul Tiwari (hindi dialogue)'],
#  'year': 2013}
# {'_id': ObjectId('573a13d7f29313caabda4bad'),
#  'awards': {'nominations': 1, 'text': '1 win & 1 nomination.', 'wins': 1},
#  'cast': ['Peter Weller', 'Ariel Winter', 'Michael Emerson', 'David Selby'],
#  'countries': ['USA'],
#  'directors': ['Jay Oliva'],
#  'fullplot': 'After a 10 year absence, the Dark Knight has returned to Gotham '
#              'to fight the Mutant threat. After defeating the mutants, he has '
#              'taken control of a gang loyal to him in order to make Gotham a '
#              'safer place. But, the Joker has decided to stop this, and fights '
#              'against Batman in a deadly duel. Meanwhile, the Man of Steel is '
#              'ordered to stop the Dark Knight because the government believes '
#              'that his ways are wrong. As Batman fights the Joker, the Man of '
#              'Steel prepares for his greatest fight.',
#  'genres': ['Animation', 'Action', 'Crime'],
#  'imdb': {'id': 2166834, 'rating': 8.4, 'votes': 22244},
#  'languages': ['English'],
#  'lastupdated': '2015-08-25 00:09:46.120000000',
#  'num_mflix_comments': 0,
#  'plot': 'The Batman has returned after a 10-year absence. The Gotham '
#          'authorities want to arrest him. An old foe wants a reunion. The Feds '
#          'want the Man of Tomorrow to put a stop to him.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BYTEzMmE0ZDYtYWNmYi00ZWM4LWJjOTUtYTE0ZmQyYWM3ZjA0XkEyXkFqcGdeQXVyNTA4NzY1MzY@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2013, 1, 29, 0, 0),
#  'runtime': 76,
#  'title': 'Batman: The Dark Knight Returns, Part 2',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 6, 27, 18, 50, 14),
#               'viewer': {'meter': 94, 'numReviews': 54, 'rating': 4.4},
#               'website': 'http://www.gowithleflo.com/'},
#  'type': 'movie',
#  'writers': ['Bob Kane (Batman characters)',
#              'Jerry Siegel (Superman characters)',
#              'Joe Shuster (Superman characters)',
#              'Frank Miller (comic book)',
#              'Klaus Janson (comic book)',
#              'Bob Goodman'],
#  'year': 2013}
# {'_id': ObjectId('573a13d4f29313caabd99c55'),
#  'awards': {'nominations': 50,
#             'text': 'Nominated for 2 Golden Globes. Another 8 wins & 50 '
#                     'nominations.',
#             'wins': 10},
#  'cast': ['Chris Hemsworth',
#           'Daniel Brèhl',
#           'Olivia Wilde',
#           'Alexandra Maria Lara'],
#  'countries': ['UK', 'Germany', 'USA'],
#  'directors': ['Ron Howard'],
#  'fullplot': 'Set against the sexy, glamorous golden age of Formula 1 racing '
#              'in the 1970s, the film is based on the true story of a great '
#              'sporting rivalry between handsome English playboy James Hunt '
#              '(Hemsworth), and his methodical, brilliant opponent, Austrian '
#              'driver Niki Lauda (Bruhl). The story follows their distinctly '
#              'different personal styles on and off the track, their loves and '
#              'the astonishing 1976 season in which both drivers were willing '
#              'to risk everything to become world champion in a sport with no '
#              'margin for error: if you make a mistake, you die.',
#  'genres': ['Action', 'Biography', 'Drama'],
#  'imdb': {'id': 1979320, 'rating': 8.2, 'votes': 263143},
#  'languages': ['English', 'German', 'Italian', 'French', 'Spanish'],
#  'lastupdated': '2015-08-31 00:39:49.983000000',
#  'metacritic': 75,
#  'num_mflix_comments': 1,
#  'plot': 'The merciless 1970s rivalry between Formula One rivals James Hunt '
#          'and Niki Lauda.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BOWEwODJmZDItYTNmZC00OGM4LThlNDktOTQzZjIzMGQxODA4XkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2013, 9, 27, 0, 0),
#  'runtime': 123,
#  'title': 'Rush',
#  'tomatoes': {'boxOffice': '$26.9M',
#               'consensus': 'A sleek, slick, well-oiled machine, Rush is a '
#                            'finely crafted sports drama with exhilarating race '
#                            'sequences and strong performances from Chris '
#                            'Hemsworth and Daniel Brèhl.',
#               'critic': {'meter': 89, 'numReviews': 210, 'rating': 7.6},
#               'dvd': datetime.datetime(2014, 1, 28, 0, 0),
#               'fresh': 187,
#               'lastUpdated': datetime.datetime(2015, 8, 20, 18, 2, 24),
#               'production': 'Universal Pictures',
#               'rotten': 23,
#               'viewer': {'meter': 88, 'numReviews': 77154, 'rating': 4.1},
#               'website': 'http://www.rushmovie.com/'},
#  'type': 'movie',
#  'writers': ['Peter Morgan'],
#  'year': 2013}
# {'_id': ObjectId('573a13d1f29313caabd8fefb'),
#  'awards': {'nominations': 0, 'text': '10 wins.', 'wins': 10},
#  'cast': ['Shaan Shahid', 'Hamza Abbasi', 'Shamoon Abbasi', 'Ayesha Khan'],
#  'countries': ['Pakistan'],
#  'directors': ['Bilal Lashari'],
#  'fullplot': 'The film is based on stylized depiction of actual life events '
#              'surrounding the war on terror in Pakistan including the attack '
#              'on a Police Academy at Lahore in 2009. Major Mujtaba is a former '
#              'army officer, who took an early retirement from the service. The '
#              'plot involves a counter-terrorism operation being conducted in '
#              'the Northwestern tribal region of Pakistan, led by Ehtesham and '
#              'coordinated by an intelligence officer played by Ayesha. '
#              'Ehtesham and the intelligence officer come to know of a major '
#              'terrorist attack that can only be countered with the help of '
#              'Major Mujtaba.',
#  'genres': ['Action', 'Drama', 'Thriller'],
#  'imdb': {'id': 1821700, 'rating': 8.5, 'votes': 26769},
#  'languages': ['English', 'Urdu'],
#  'lastupdated': '2015-09-17 04:44:15.710000000',
#  'num_mflix_comments': 1,
#  'plot': 'The efforts of the Pakistani security forces in their fight against '
#          'terrorism and how the lives of security officials are affected. A '
#          'retired security officer returns to save Pakistan from a major '
#          'terrorist attack.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMjI2NjM2MjYzMV5BMl5BanBnXkFtZTgwMjc0NTE1MDE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2013, 10, 16, 0, 0),
#  'runtime': 130,
#  'title': 'Waar',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 5, 3, 18, 58, 41),
#               'viewer': {'numReviews': 1, 'rating': 0.0}},
#  'type': 'movie',
#  'writers': ['Hassan Rana'],
#  'year': 2013}
# {'_id': ObjectId('573a13d4f29313caabd98387'),
#  'awards': {'nominations': 32, 'text': '10 wins & 32 nominations.', 'wins': 10},
#  'cast': ['Manoj Bajpayee',
#           'Richa Chadda',
#           'Nawazuddin Siddiqui',
#           'Tigmanshu Dhulia'],
#  'countries': ['India'],
#  'directors': ['Anurag Kashyap'],
#  'fullplot': 'Shahid Khan is exiled after impersonating the legendary Sultana '
#              'Daku in order to rob British trains. Now outcast, Shahid becomes '
#              "a worker at Ramadhir Singh's colliery, only to spur a revenge "
#              'battle that passes on to generations. At the turn of the decade, '
#              "Shahid's son, the philandering Sardar Khan vows to get his "
#              "father's honor back, becoming the most feared man of Wasseypur.",
#  'genres': ['Action', 'Crime', 'Drama'],
#  'imdb': {'id': 1954470, 'rating': 8.4, 'votes': 35127},
#  'languages': ['Hindi'],
#  'lastupdated': '2015-08-19 00:19:48.483000000',
#  'metacritic': 89,
#  'num_mflix_comments': 0,
#  'plot': 'A clash between Sultan (a Qureishi dacoit chief) and Shahid Khan (a '
#          'Pathan who impersonates him) leads to the expulsion of Khan from '
#          'Wasseypur, and ignites a deadly blood feud spanning three '
#          'generations.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTc5NjY4MjUwNF5BMl5BanBnXkFtZTgwODM3NzM5MzE@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(2012, 8, 2, 0, 0),
#  'runtime': 320,
#  'title': 'Gangs of Wasseypur',
#  'tomatoes': {'critic': {'meter': 95, 'numReviews': 19, 'rating': 8.5},
#               'fresh': 18,
#               'lastUpdated': datetime.datetime(2015, 8, 24, 18, 16, 31),
#               'rotten': 1,
#               'viewer': {'meter': 91, 'numReviews': 1471, 'rating': 4.3},
#               'website': 'http://www.wasseypurworld.com/'},
#  'type': 'movie',
#  'writers': ['Akhilesh Jaiswal',
#              'Anurag Kashyap',
#              'Sachin K. Ladia',
#              'Zeishan Quadri'],
#  'year': 2012}
# {'_id': ObjectId('573a13c4f29313caabd6cc80'),
#  'awards': {'nominations': 86,
#             'text': 'Nominated for 1 BAFTA Film Award. Another 45 wins & 86 '
#                     'nominations.',
#             'wins': 46},
#  'cast': ['Christian Bale', 'Gary Oldman', 'Tom Hardy', 'Joseph Gordon-Levitt'],
#  'countries': ['USA', 'UK'],
#  'directors': ['Christopher Nolan'],
#  'fullplot': 'Despite his tarnished reputation after the events of The Dark '
#              "Knight, in which he took the rap for Dent's crimes, Batman feels "
#              'compelled to intervene to assist the city and its police force '
#              "which is struggling to cope with Bane's plans to destroy the "
#              'city.',
#  'genres': ['Action', 'Thriller'],
#  'imdb': {'id': 1345836, 'rating': 8.5, 'votes': 1004805},
#  'languages': ['English'],
#  'lastupdated': '2015-08-22 00:03:50.157000000',
#  'metacritic': 78,
#  'num_mflix_comments': 129,
#  'plot': "Eight years after the Joker's reign of anarchy, the Dark Knight is "
#          'forced to return from his imposed exile to save Gotham City from the '
#          'brutal guerrilla terrorist Bane with the help of the enigmatic '
#          'Catwoman.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTk4ODQzNDY3Ml5BMl5BanBnXkFtZTcwODA0NTM4Nw@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2012, 7, 20, 0, 0),
#  'runtime': 165,
#  'title': 'The Dark Knight Rises',
#  'tomatoes': {'boxOffice': '$448.1M',
#               'consensus': 'The Dark Knight Rises is an ambitious, thoughtful, '
#                            'and potent action film that concludes Christopher '
#                            "Nolan's franchise in spectacular fashion.",
#               'critic': {'meter': 87, 'numReviews': 327, 'rating': 8.0},
#               'dvd': datetime.datetime(2012, 12, 3, 0, 0),
#               'fresh': 283,
#               'lastUpdated': datetime.datetime(2015, 9, 12, 17, 27, 41),
#               'production': 'Warner Bros. Pictures',
#               'rotten': 44,
#               'viewer': {'meter': 90, 'numReviews': 1203596, 'rating': 4.3},
#               'website': 'http://www.thedarkknightrises.com/'},
#  'type': 'movie',
#  'writers': ['Jonathan Nolan (screenplay)',
#              'Christopher Nolan (screenplay)',
#              'Christopher Nolan (story)',
#              'David S. Goyer (story)',
#              'Bob Kane (characters)'],
#  'year': 2012}
# {'_id': ObjectId('573a13baf29313caabd506e4'),
#  'awards': {'nominations': 67,
#             'text': 'Nominated for 1 Oscar. Another 32 wins & 67 nominations.',
#             'wins': 33},
#  'cast': ['Robert Downey Jr.',
#           'Chris Evans',
#           'Mark Ruffalo',
#           'Chris Hemsworth'],
#  'countries': ['USA'],
#  'directors': ['Joss Whedon'],
#  'fullplot': 'Nick Fury is director of S.H.I.E.L.D, an international peace '
#              "keeping agency. The agency is a who's who of Marvel Super "
#              'Heroes, with Iron Man, The Incredible Hulk, Thor, Captain '
#              'America, Hawkeye and Black Widow. When global security is '
#              'threatened by Loki and his cohorts, Nick Fury and his team will '
#              'need all their powers to save the world from disaster.',
#  'genres': ['Action', 'Adventure', 'Sci-Fi'],
#  'imdb': {'id': 848228, 'rating': 8.1, 'votes': 877226},
#  'languages': ['English', 'Russian'],
#  'lastupdated': '2015-09-10 17:10:29.990000000',
#  'metacritic': 69,
#  'num_mflix_comments': 117,
#  'plot': "Earth's mightiest heroes must come together and learn to fight as a "
#          'team if they are to stop the mischievous Loki and his alien army '
#          'from enslaving humanity.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNDYxNjQyMjAtNTdiOS00NGYwLWFmNTAtNThmYjU5ZGI2YTI1XkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2012, 5, 4, 0, 0),
#  'runtime': 143,
#  'title': 'The Avengers',
#  'tomatoes': {'boxOffice': '$623.3M',
#               'consensus': "Thanks to a script that ephasizes its heroes' "
#                            'humanity and a wealth of superpowered set pieces, '
#                            'The Avengers lives up to its hype and raises the '
#                            'bar for Marvel at the movies.',
#               'critic': {'meter': 92, 'numReviews': 315, 'rating': 8.0},
#               'dvd': datetime.datetime(2012, 9, 25, 0, 0),
#               'fresh': 289,
#               'lastUpdated': datetime.datetime(2015, 9, 12, 17, 31, 32),
#               'production': 'Walt Disney Pictures',
#               'rotten': 26,
#               'viewer': {'meter': 91, 'numReviews': 1124021, 'rating': 4.4},
#               'website': 'http://marvel.com/avengers_movie'},
#  'type': 'movie',
#  'writers': ['Joss Whedon (screenplay)',
#              'Zak Penn (story)',
#              'Joss Whedon (story)'],
#  'year': 2012}
# {'_id': ObjectId('573a13c5f29313caabd6ee61'),
#  'awards': {'nominations': 172,
#             'text': 'Won 4 Oscars. Another 158 wins & 172 nominations.',
#             'wins': 162},
#  'cast': ['Leonardo DiCaprio',
#           'Joseph Gordon-Levitt',
#           'Ellen Page',
#           'Tom Hardy'],
#  'countries': ['USA', 'UK'],
#  'directors': ['Christopher Nolan'],
#  'fullplot': 'Dom Cobb is a skilled thief, the absolute best in the dangerous '
#              'art of extraction, stealing valuable secrets from deep within '
#              'the subconscious during the dream state, when the mind is at its '
#              "most vulnerable. Cobb's rare ability has made him a coveted "
#              'player in this treacherous new world of corporate espionage, but '
#              'it has also made him an international fugitive and cost him '
#              'everything he has ever loved. Now Cobb is being offered a chance '
#              'at redemption. One last job could give him his life back but '
#              'only if he can accomplish the impossible-inception. Instead of '
#              'the perfect heist, Cobb and his team of specialists have to pull '
#              'off the reverse: their task is not to steal an idea but to plant '
#              'one. If they succeed, it could be the perfect crime. But no '
#              'amount of careful planning or expertise can prepare the team for '
#              'the dangerous enemy that seems to predict their every move. An '
#              'enemy that only Cobb could have seen coming.',
#  'genres': ['Action', 'Mystery', 'Sci-Fi'],
#  'imdb': {'id': 1375666, 'rating': 8.8, 'votes': 1294646},
#  'languages': ['English', 'Japanese', 'French'],
#  'lastupdated': '2015-09-12 00:29:01.430000000',
#  'metacritic': 74,
#  'num_mflix_comments': 1,
#  'plot': 'A thief who steals corporate secrets through use of dream-sharing '
#          'technology is given the inverse task of planting an idea into the '
#          'mind of a CEO.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMjAxMzY3NjcxNF5BMl5BanBnXkFtZTcwNTI5OTM0Mw@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2010, 7, 16, 0, 0),
#  'runtime': 148,
#  'title': 'Inception',
#  'tomatoes': {'boxOffice': '$292.6M',
#               'consensus': 'Smart, innovative, and thrilling, Inception is '
#                            'that rare summer blockbuster that succeeds '
#                            'viscerally as well as intellectually.',
#               'critic': {'meter': 86, 'numReviews': 326, 'rating': 8.1},
#               'dvd': datetime.datetime(2010, 12, 7, 0, 0),
#               'fresh': 281,
#               'lastUpdated': datetime.datetime(2015, 9, 12, 17, 13, 32),
#               'production': 'Warner Bros. Pictures',
#               'rotten': 45,
#               'viewer': {'meter': 91, 'numReviews': 561365, 'rating': 4.2},
#               'website': 'http://inceptionmovie.warnerbros.com/'},
#  'type': 'movie',
#  'writers': ['Christopher Nolan'],
#  'year': 2010}
# {'_id': ObjectId('573a13aef29313caabd2c99e'),
#  'awards': {'nominations': 32,
#             'text': 'Nominated for 1 Golden Globe. Another 23 wins & 32 '
#                     'nominations.',
#             'wins': 24},
#  'cast': ['James Badge Dale',
#           'Joseph Mazzello',
#           'Jon Seda',
#           'Sebastian Bertoli'],
#  'countries': ['USA'],
#  'fullplot': 'The Pacific follows the lives of a U.S Marine Corps squad during '
#              'the campaign within the Pacific against the Japanese Empire '
#              'during WW2. Made by the creators of Band of Brothers, it follows '
#              'a similar line of thought to outline the hardships of the common '
#              'man during war. the Pacific is in parts a fast paced war series '
#              'that can be enjoyed by action lovers whilst containing a more '
#              'sensitive side when projecting the relationships (brotherhood) '
#              'of Marines on the battlefield. where the Pacific takes a new '
#              'direction from its "older brother" is in its depiction of the '
#              'lives of soldiers who were picked to return home to increase the '
#              'sales of war bonds, in doing this it also depicts the life cycle '
#              'of returned soldiers from initial joy to the eventual feeling of '
#              'regret and to a certain extent shame felt by soldiers wanting to '
#              'return to the war in service of either their comrades or nation.',
#  'genres': ['Action', 'Adventure', 'Drama'],
#  'imdb': {'id': 374463, 'rating': 8.3, 'votes': 60257},
#  'languages': ['English'],
#  'lastupdated': '2015-09-16 11:04:50.053000000',
#  'num_mflix_comments': 0,
#  'plot': "The intertwined stories of three Marines during America's battle "
#          'with the Japanese in the Pacific during World War II.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNmEwNmI1MjItNjNjYy00NDE5LWJiNTYtM2QxMTI5ZjllZTBhL2ltYWdlXkEyXkFqcGdeQXVyNTAyODkwOQ@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'TV-MA',
#  'released': datetime.datetime(2010, 3, 14, 0, 0),
#  'runtime': 52,
#  'title': 'The Pacific',
#  'type': 'series',
#  'year': 2010}
# {'_id': ObjectId('573a13baf29313caabd512e1'),
#  'awards': {'nominations': 2, 'text': '1 win & 2 nominations.', 'wins': 1},
#  'cast': ['Kotono Mitsuishi',
#           'Megumi Ogata',
#           'Megumi Hayashibara',
#           'Yèko Miyamura'],
#  'countries': ['Japan'],
#  'directors': ['Masayuki', 'Kazuya Tsurumaki', 'Hideaki Anno'],
#  'fullplot': 'Under constant attack by Angels, NERV introduces two new pilots: '
#              'the mysterious Makinami Mari Illustrous and the intense Asuka '
#              'Langley Shikinami. Parallel to the incursion, Gendo Ikari and '
#              'SEELE proceed the secret project that involves both Rei and '
#              'Shinji.',
#  'genres': ['Animation', 'Action', 'Drama'],
#  'imdb': {'id': 860906, 'rating': 8.1, 'votes': 9697},
#  'languages': ['Japanese', 'German'],
#  'lastupdated': '2015-09-07 00:18:49.480000000',
#  'num_mflix_comments': 0,
#  'plot': 'Under constant attack by Angels, NERV introduces two new pilots: the '
#          'mysterious Makinami Mari Illustrous and the intense Asuka Langley '
#          'Shikinami. Parallel to the incursion, Gendo Ikari and ...',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTc1NTk5OTQwOV5BMl5BanBnXkFtZTgwMzg4MjU2MzE@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'TV-14',
#  'released': datetime.datetime(2009, 6, 27, 0, 0),
#  'runtime': 112,
#  'title': 'Evangelion: 2.0 You Can (Not) Advance',
#  'tomatoes': {'critic': {'meter': 75, 'numReviews': 8, 'rating': 6.1},
#               'dvd': datetime.datetime(2011, 3, 29, 0, 0),
#               'fresh': 6,
#               'lastUpdated': datetime.datetime(2015, 9, 10, 17, 15, 23),
#               'production': 'Eleven Arts',
#               'rotten': 2,
#               'viewer': {'meter': 90, 'numReviews': 2983, 'rating': 4.3},
#               'website': 'http://www.funimation.com/evangelion'},
#  'type': 'movie',
#  'writers': ['Hideaki Anno (screenplay)'],
#  'year': 2009}
# {'_id': ObjectId('573a13c1f29313caabd652bb'),
#  'awards': {'nominations': 10, 'text': '14 wins & 10 nominations.', 'wins': 14},
#  'cast': ['Donnie Yen', 'Simon Yam', 'Ka Tung Lam', 'Siu-Wong Fan'],
#  'countries': ['Hong Kong', 'China'],
#  'directors': ['Wilson Yip'],
#  'fullplot': 'In 1935 in Foshan, south China, there are martial arts schools '
#              'on every street corner. Ip Man is the undisputed martial arts '
#              'champion, yet he has not devoted himself to teaching. Despite '
#              'this, it seems that all the kung fu masters of the city are '
#              'eager to fight him to improve their reputation.',
#  'genres': ['Action', 'Biography', 'Drama'],
#  'imdb': {'id': 1220719, 'rating': 8.1, 'votes': 140270},
#  'languages': ['Cantonese', 'Mandarin', 'Japanese'],
#  'lastupdated': '2015-08-31 00:01:21.890000000',
#  'metacritic': 59,
#  'num_mflix_comments': 0,
#  'plot': 'A semi-biographical account of Yip Man, the successful martial arts '
#          'master who taught the Chinese martial art of Wing Chun to the world.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNTFmMjM3M2UtOTIyZC00Zjk3LTkzODUtYTdhNGRmNzFhYzcyXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(2008, 12, 12, 0, 0),
#  'runtime': 106,
#  'title': 'Ip Man',
#  'tomatoes': {'consensus': 'At once beholden to the established conventions of '
#                            'the genre and delightfully subversive of them, Ip '
#                            'Man is one of the most exciting -- and '
#                            'refreshingly character-driven -- martial arts '
#                            'films in years.',
#               'critic': {'meter': 84, 'numReviews': 25, 'rating': 6.5},
#               'dvd': datetime.datetime(2009, 3, 31, 0, 0),
#               'fresh': 21,
#               'lastUpdated': datetime.datetime(2015, 9, 12, 18, 16, 42),
#               'production': 'Well Go USA',
#               'rotten': 4,
#               'viewer': {'meter': 93, 'numReviews': 26167, 'rating': 4.2},
#               'website': 'http:// http://www.ipman-movie.com/'},
#  'type': 'movie',
#  'writers': ['Edmond Wong (screenplay)', 'Chan Tai-Li'],
#  'year': 2008}
# {'_id': ObjectId('573a13b5f29313caabd42722'),
#  'awards': {'nominations': 106,
#             'text': 'Won 2 Oscars. Another 142 wins & 106 nominations.',
#             'wins': 144},
#  'cast': ['Christian Bale', 'Heath Ledger', 'Aaron Eckhart', 'Michael Caine'],
#  'countries': ['USA', 'UK'],
#  'directors': ['Christopher Nolan'],
#  'fullplot': 'Batman raises the stakes in his war on crime. With the help of '
# ...
#          'Princess Leia from the evil Darth Vader.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNzVlY2MwMjktM2E4OS00Y2Y3LWE3ZjctYzhkZGM3YzA1ZWM2XkEyXkFqcGdeQXVyNzkwMjQ5NzM@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG',
#  'released': datetime.datetime(1977, 5, 25, 0, 0),
#  'runtime': 121,
#  'title': 'Star Wars: Episode IV - A New Hope',
#  'tomatoes': {'consensus': 'A legendarily expansive and ambitious start to the '
#                            'sci-fi saga, George Lucas opened our eyes to the '
#                            'possiblites of blockbuster filmmaking and things '
#                            'have never been the same.',
#               'critic': {'meter': 94, 'numReviews': 82, 'rating': 8.5},
#               'dvd': datetime.datetime(2004, 9, 21, 0, 0),
#               'fresh': 77,
#               'lastUpdated': datetime.datetime(2015, 9, 12, 17, 4, 3),
#               'production': '20th Century Fox',
#               'rotten': 5,
#               'viewer': {'meter': 96, 'numReviews': 848179, 'rating': 4.1},
#               'website': 'http://www.starwars.com/episode-iv/'},
#  'type': 'movie',
#  'writers': ['George Lucas'],
#  'year': 1977}
# {'_id': ObjectId('573a1396f29313caabce5a56'),
#  'awards': {'nominations': 0, 'text': '7 wins.', 'wins': 7},
#  'cast': ['Shashi Kapoor', 'Amitabh Bachchan', 'Neetu Singh', 'Nirupa Roy'],
#  'countries': ['India'],
#  'directors': ['Yash Chopra'],
#  'fullplot': 'The movie tells the story of two brothers, Vijay and Ravi Verma, '
#              'who follow different career paths: Vijay is a smuggler and Ravi '
#              'the policeman who is asked to hunt Vijay down. Vijay Verma '
#              '(Amitabh Bachchan) and Ravi Verma (Shashi Kapoor) are the sons '
#              'of a trade unionist, Anand Verma(Satyen Kappu), who was defeated '
#              'and disgraced by the management of his firm using his family as '
#              'bait. Unable to bear the public disgrace father deserts the '
#              'family, and the sons are raised by their mother(Nirupa Roy)who '
#              'brings them to Bombay City, who suffers the trials and '
#              'tribulations of a poor single mother. Vijay Verma, the elder '
#              "brother, grows up with an acute awareness of his father's "
#              "humiliation and is victimized for his father's supposed "
#              'misdeeds. In the process of fighting for his rights Vijay, who '
#              'starts out as a boot polisher and becomes a dockyard worker in '
#              'his youth, becomes a smuggler and a leading figure of the '
#              'underworld.',
#  'genres': ['Action', 'Crime', 'Drama'],
#  'imdb': {'id': 72860, 'rating': 8.1, 'votes': 4753},
#  'languages': ['Hindi'],
#  'lastupdated': '2015-09-17 04:37:47.103000000',
#  'num_mflix_comments': 0,
#  'plot': 'As a youth, Vijay struggles as a dockworker. Eventually, he becomes '
#          'a leading figure of the underworld, while younger brother, Ravi, is '
#          'an educated, upright policeman. But in the end, it all comes down '
#          'to, who does mother love more?',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTU2NTYyOTA3NV5BMl5BanBnXkFtZTcwMDMyNjEzMQ@@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(1979, 5, 1, 0, 0),
#  'runtime': 174,
#  'title': 'Deewaar',
#  'tomatoes': {'dvd': datetime.datetime(2004, 3, 30, 0, 0),
#               'lastUpdated': datetime.datetime(2015, 9, 15, 17, 6, 19),
#               'viewer': {'meter': 85, 'numReviews': 1174, 'rating': 4.0}},
#  'type': 'movie',
#  'writers': ['Javed Akhtar (dialogue)',
#              'Javed Akhtar (screenplay)',
#              'Javed Akhtar (story)',
#              'Salim Khan (dialogue)',
#              'Salim Khan (screenplay)',
#              'Salim Khan (story)'],
#  'year': 1975}
# {'_id': ObjectId('573a1397f29313caabce5d93'),
#  'awards': {'nominations': 0, 'text': '2 wins.', 'wins': 2},
#  'cast': ['Dharmendra', 'Sanjeev Kumar', 'Hema Malini', 'Amitabh Bachchan'],
#  'countries': ['India'],
#  'directors': ['Ramesh Sippy'],
#  'fullplot': 'Sholay means embers in Hindi. In this particular movie, a Police '
#              "Officer, who's family was killed by a bandit named Gabbar Singh, "
#              'decides to fight fire with fire and recruits two convicts, Jai '
#              'and Veeru to capture Gabbar. He approaches them in jail, puts '
#              'the proposal in front of them, and they agree to bring in Gabbar '
#              'Singh alive - for a hefty price. After their discharge from '
#              'jail, they travel by train to the village where the Police '
#              'Officer lives - now with only his widowed daughter-in-law. The '
#              'three band together to fight one of the most elusive and dreaded '
#              'bandits of all time. Will the two ex-cons be able to bring '
#              'Gabbar alive to the Police Officer?',
#  'genres': ['Action', 'Adventure', 'Comedy'],
#  'imdb': {'id': 73707, 'rating': 8.6, 'votes': 22725},
#  'languages': ['Hindi'],
#  'lastupdated': '2015-08-15 00:20:17.553000000',
#  'num_mflix_comments': 0,
#  'plot': 'After his family is murdered by a notorious and ruthless bandit, a '
#          'former police officer enlists the services of two outlaws to capture '
#          'him.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BOGZiM2IwODktNTdiMC00MGU1LWEyZTYtOTk4NTkwYmJkNmI1L2ltYWdlL2ltYWdlXkEyXkFqcGdeQXVyNjU0OTQ0OTY@._V1_SY1000_SX677_AL_.jpg',
#  'released': datetime.datetime(1975, 8, 15, 0, 0),
#  'runtime': 162,
#  'title': 'Sholay',
#  'type': 'movie',
#  'writers': ['Javed Akhtar', 'Salim Khan'],
#  'year': 1975}
# {'_id': ObjectId('573a13acf29313caabd27be4'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Amza Pellea', 'Ion Besoiu', 'Olga Tudorache', 'Irina Gardescu'],
#  'countries': ['Romania', 'France', 'Italy'],
#  'directors': ['Sergiu Nicolaescu'],
#  'fullplot': 'An epic fresco depicting the reign (1593-1601) of Mihai Pètrascu '
#              '(better known as "Mihai Viteazul" / "Michael the Brave"), the '
#              'famous prince who united the three provinces: Transalpine '
#              'Vallachia, Transylvania and Moldavia, into the country of '
#              'Romania, at the end of the 16th century (1599-1601) against the '
#              'opposition of the Ottoman and Austrian Empires, this movie '
#              'features large scale battle scenes mixed with political '
#              'intrigues, murderous treachery, and family drama.',
#  'genres': ['Action', 'Biography', 'Drama'],
#  'imdb': {'id': 66078, 'rating': 8.3, 'votes': 5347},
#  'languages': ['Romanian'],
#  'lastupdated': '2015-08-31 06:29:18.687000000',
#  'num_mflix_comments': 1,
#  'plot': 'At the end of the 16th century Wallachian ruler Prince Michael the '
#          'Brave overcame the adversity of the Ottoman and Austrian Empires to '
#          'unite Wallachia, Moldavia and Transylvania into one country.',
#  'runtime': 203,
#  'title': 'Michael the Brave',
#  'type': 'movie',
#  'writers': ['Titus Popovici'],
#  'year': 1970}
# {'_id': ObjectId('573a1396f29313caabce4122'),
#  'awards': {'nominations': 1, 'text': '1 nomination.', 'wins': 0},
#  'cast': ['Amza Pellea', 'Ion Besoiu', 'Olga Tudorache', 'Irina Gardescu'],
#  'countries': ['Romania', 'France', 'Italy'],
#  'directors': ['Sergiu Nicolaescu'],
#  'fullplot': 'An epic fresco depicting the reign (1593-1601) of Mihai Pètrascu '
#              '(better known as "Mihai Viteazul" / "Michael the Brave"), the '
#              'famous prince who united the three provinces: Transalpine '
#              'Vallachia, Transylvania and Moldavia, into the country of '
#              'Romania, at the end of the 16th century (1599-1601) against the '
#              'opposition of the Ottoman and Austrian Empires, this movie '
#              'features large scale battle scenes mixed with political '
#              'intrigues, murderous treachery, and family drama.',
#  'genres': ['Action', 'Biography', 'Drama'],
#  'imdb': {'id': 66078, 'rating': 8.3, 'votes': 5354},
#  'languages': ['Romanian'],
#  'lastupdated': '2015-09-10 17:55:03.667000000',
#  'num_mflix_comments': 0,
#  'plot': 'At the end of the 16th century Wallachian ruler Prince Michael the '
#          'Brave overcame the adversity of the Ottoman and Austrian Empires to '
#          'unite Wallachia, Moldavia and Transylvania into one country.',
#  'runtime': 203,
#  'title': 'Michael the Brave',
#  'tomatoes': {'critic': {'meter': 89, 'numReviews': 9, 'rating': 6.6},
#               'dvd': datetime.datetime(2004, 4, 27, 0, 0),
#               'fresh': 8,
#               'lastUpdated': datetime.datetime(2015, 9, 12, 19, 17, 38),
#               'production': 'Paramount Home Video',
#               'rotten': 1,
#               'viewer': {'meter': 64, 'numReviews': 1511, 'rating': 3.4}},
#  'type': 'movie',
#  'writers': ['Titus Popovici'],
#  'year': 1970}
# {'_id': ObjectId('573a1396f29313caabce3dcf'),
#  'awards': {'nominations': 3,
#             'text': 'Nominated for 2 Oscars. Another 6 wins & 3 nominations.',
#             'wins': 8},
#  'cast': ['William Holden', 'Ernest Borgnine', 'Robert Ryan', "Edmond O'Brien"],
#  'countries': ['USA'],
#  'directors': ['Sam Peckinpah'],
#  'fullplot': "In the Wild Bunch the movie opens with a group of aging outlaw's "
#              'final score, a bank robbery. The event concludes with a violent '
#              'and overtly bloody shootout that would generally mark the finale '
#              'of a movie. This is correct in that it marks the finale of an '
#              'era, for the characters and the world they live in. They simply '
#              'can no longer keep up, the times are changing, technology '
#              "advancing, and they're style of life is getting left behind in "
#              'the dust that they spent so long galloping through. They abandon '
#              'their careers for the simpler life of retirement. They enjoy '
#              'this time, they live their fantasies. During this time the law '
#              'is always on their tracks, bounty hunters. The further into '
#              'their fantasy they get, the closer their demise seems to get. '
#              'When one of their own is captured they are faced with the choice '
#              'of escape or what is certainly a suicide mission to attempt and '
#              'free their fallen behind comrade. For them it is not a choice. '
#              'They all die in what can only be described as a nauseatingly '
#              'gore filled bloodbath of a battle. They might have succeeded in '
#              'removing themselves from the wild west however they could not be '
#              'separated what is inherently their nature. The west was only '
#              'wild because the wild bunch were present, they influenced their '
#              'surroundings, not the other way around. It is only after the '
#              'final shoot out that the bounty hunters catch up with them, now '
#              'only bullet riddled corpses. They never got caught, they could '
#              'never get caught because they were already trapped in their own '
#              'personalities. They turned themselves in to their instincts. The '
#              'vacation, the fantasy, was bound to end and they knew it.',
#  'genres': ['Action', 'Adventure', 'Western'],
#  'imdb': {'id': 65214, 'rating': 8.1, 'votes': 59133},
#  'languages': ['English', 'Spanish', 'German'],
#  'lastupdated': '2015-08-20 00:39:59.720000000',
#  'num_mflix_comments': 1,
#  'plot': 'An aging group of outlaws look for one last big score as the '
#          '"traditional" American West is disappearing around them.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BNGUyYTZmOWItMDJhMi00N2IxLWIyNDMtNjUxM2ZiYmU5YWU1XkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(1969, 6, 18, 0, 0),
#  'runtime': 145,
#  'title': 'The Wild Bunch',
#  'tomatoes': {'critic': {'meter': 98, 'numReviews': 48, 'rating': 8.8},
#               'dvd': datetime.datetime(1997, 8, 27, 0, 0),
#               'fresh': 47,
#               'lastUpdated': datetime.datetime(2015, 9, 16, 17, 32, 47),
#               'production': 'Warner Bros. Pictures',
#               'rotten': 1,
#               'viewer': {'meter': 91, 'numReviews': 33369, 'rating': 4.1}},
#  'type': 'movie',
#  'writers': ['Walon Green (screenplay)',
#              'Sam Peckinpah (screenplay)',
#              'Walon Green (story)',
#              'Roy N. Sickner (story)'],
#  'year': 1969}
# {'_id': ObjectId('573a139cf29313caabcf835c'),
#  'awards': {'nominations': 0, 'text': '1 win.', 'wins': 1},
#  'cast': ['Kazimir Vitkus',
#           'Regimantas Adomaitis',
#           "Bruno O'Ya",
#           'Juozas Budraitis'],
#  'countries': ['Soviet Union'],
#  'directors': ['Vytautas Zalakevicius'],
#  'fullplot': 'The film is set in Lithuania after the Second World War. It '
#              'shows dramatic events in a small Lithuanian farming community, '
#              'where people are split between the Soviets and the "brothers in '
#              'the woods", who are fighting to defend their land from the '
#              'Soviets after the end of the Second World War.',
#  'genres': ['Action', 'Drama', 'History'],
#  'imdb': {'id': 151750, 'rating': 8.1, 'votes': 421},
#  'languages': ['Lithuanian'],
#  'lastupdated': '2015-08-22 00:15:54.687000000',
#  'num_mflix_comments': 0,
#  'plot': 'The film is set in Lithuania after the Second World War. It shows '
#          'dramatic events in a small Lithuanian farming community, where '
#          'people are split between the Soviets and the "brothers in ...',
#  'released': datetime.datetime(1966, 9, 5, 0, 0),
#  'runtime': 100,
#  'title': 'Niekas nenorejo mirti',
#  'tomatoes': {'lastUpdated': datetime.datetime(2015, 7, 25, 18, 49, 16),
#               'viewer': {'numReviews': 0, 'rating': 0.0}},
#  'type': 'movie',
#  'writers': ['Vytautas Zalakevicius'],
#  'year': 1966}
# {'_id': ObjectId('573a1395f29313caabce2498'),
#  'awards': {'nominations': 1, 'text': '1 win & 1 nomination.', 'wins': 1},
#  'cast': ['Clint Eastwood',
#           'Marianne Koch',
#           'Gian Maria Volontè',
#           'Wolfgang Lukschy'],
#  'countries': ['Italy', 'Spain', 'West Germany'],
#  'directors': ['Sergio Leone'],
#  'fullplot': 'An anonymous, but deadly man rides into a town torn by war '
#              "between two factions, the Baxters and the Rojo's. Instead of "
#              'fleeing or dying, as most other would do, the man schemes to '
#              'play the two sides off each other, getting rich in the bargain.',
#  'genres': ['Action', 'Drama', 'Western'],
#  'imdb': {'id': 58461, 'rating': 8.1, 'votes': 126585},
#  'languages': ['Italian', 'Spanish', 'English'],
#  'lastupdated': '2015-09-02 00:17:22.303000000',
#  'num_mflix_comments': 0,
#  'plot': 'A wandering gunfighter plays two rival families against each other '
#          'in a town torn apart by greed, pride, and revenge.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BYjA1MGVlMGItNzgxMC00OWY4LWI4YjEtNTNmYWIzMGUxOGQzXkEyXkFqcGdeQXVyNjc1NTYyMjg@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'R',
#  'released': datetime.datetime(1967, 1, 18, 0, 0),
#  'runtime': 99,
#  'title': 'A Fistful of Dollars',
#  'tomatoes': {'consensus': "With Akira Kurosawa's Yojimbo as his template, "
#                            "Sergio Leone's A Fistful of Dollars helped define "
#                            'a new era for the Western and usher in its most '
#                            'iconic star, Clint Eastwood.',
#               'critic': {'meter': 98, 'numReviews': 43, 'rating': 8.1},
#               'dvd': datetime.datetime(2001, 6, 19, 0, 0),
#               'fresh': 42,
#               'lastUpdated': datetime.datetime(2015, 9, 14, 17, 1, 55),
#               'production': 'MGM Home Entertainment',
#               'rotten': 1,
#               'viewer': {'meter': 91, 'numReviews': 85171, 'rating': 3.9}},
#  'type': 'movie',
#  'writers': ['Adriano Bolzoni (story)',
#              'Vèctor Andrès Catena (story)',
#              'Sergio Leone (story)',
#              'Vèctor Andrès Catena (screenplay)',
#              'Jaime Comas Gil (screenplay)',
#              'Sergio Leone (screenplay)'],
#  'year': 1964}

# %%
#2. Write a query to find all movies where the directors contain "Christopher Nolan" and the IMDb rating is greater than 8 (Return only the top 3 movies sorted by rating
nolan_movies = collection.find({"directors": "Christopher Nolan", "imdb.rating": {"$gt":
8}}).sort("imdb.rating", -1).limit(3)

for movie in nolan_movies:
    pprint.pprint(movie)
# Out:
# {'_id': ObjectId('573a13b5f29313caabd42722'),
#  'awards': {'nominations': 106,
#             'text': 'Won 2 Oscars. Another 142 wins & 106 nominations.',
#             'wins': 144},
#  'cast': ['Christian Bale', 'Heath Ledger', 'Aaron Eckhart', 'Michael Caine'],
#  'countries': ['USA', 'UK'],
#  'directors': ['Christopher Nolan'],
#  'fullplot': 'Batman raises the stakes in his war on crime. With the help of '
#              'Lieutenant Jim Gordon and District Attorney Harvey Dent, Batman '
#              'sets out to dismantle the remaining criminal organizations that '
#              'plague the city streets. The partnership proves to be effective, '
#              'but they soon find themselves prey to a reign of chaos unleashed '
#              'by a rising criminal mastermind known to the terrified citizens '
#              'of Gotham as The Joker.',
#  'genres': ['Action', 'Crime', 'Drama'],
#  'imdb': {'id': 468569, 'rating': 9.0, 'votes': 1495351},
#  'languages': ['English', 'Mandarin'],
#  'lastupdated': '2015-09-10 17:05:27.667000000',
#  'metacritic': 82,
#  'num_mflix_comments': 136,
#  'plot': 'When the menace known as the Joker wreaks havoc and chaos on the '
#          'people of Gotham, the caped crusader must come to terms with one of '
#          'the greatest psychological tests of his ability to fight injustice.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMTMxNTMwODM0NF5BMl5BanBnXkFtZTcwODAyMTk2Mw@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2008, 7, 18, 0, 0),
#  'runtime': 152,
#  'title': 'The Dark Knight',
#  'tomatoes': {'boxOffice': '$533.3M',
#               'consensus': 'Dark, complex and unforgettable, The Dark Knight '
#                            'succeeds not just as an entertaining comic book '
#                            'film, but as a richly thrilling crime saga.',
#               'critic': {'meter': 94, 'numReviews': 314, 'rating': 8.6},
#               'dvd': datetime.datetime(2008, 12, 9, 0, 0),
#               'fresh': 295,
#               'lastUpdated': datetime.datetime(2015, 9, 10, 17, 5, 30),
#               'production': 'Warner Bros. Pictures/Legendary',
#               'rotten': 19,
#               'viewer': {'meter': 94, 'numReviews': 1818515, 'rating': 4.4},
#               'website': 'http://thedarkknight.warnerbros.com/'},
#  'type': 'movie',
#  'writers': ['Jonathan Nolan (screenplay)',
#              'Christopher Nolan (screenplay)',
#              'Christopher Nolan (story)',
#              'David S. Goyer (story)',
#              'Bob Kane (characters)'],
#  'year': 2008}
# {'_id': ObjectId('573a13c5f29313caabd6ee61'),
#  'awards': {'nominations': 172,
#             'text': 'Won 4 Oscars. Another 158 wins & 172 nominations.',
#             'wins': 162},
#  'cast': ['Leonardo DiCaprio',
#           'Joseph Gordon-Levitt',
#           'Ellen Page',
#           'Tom Hardy'],
#  'countries': ['USA', 'UK'],
#  'directors': ['Christopher Nolan'],
#  'fullplot': 'Dom Cobb is a skilled thief, the absolute best in the dangerous '
#              'art of extraction, stealing valuable secrets from deep within '
#              'the subconscious during the dream state, when the mind is at its '
#              "most vulnerable. Cobb's rare ability has made him a coveted "
#              'player in this treacherous new world of corporate espionage, but '
#              'it has also made him an international fugitive and cost him '
#              'everything he has ever loved. Now Cobb is being offered a chance '
#              'at redemption. One last job could give him his life back but '
#              'only if he can accomplish the impossible-inception. Instead of '
#              'the perfect heist, Cobb and his team of specialists have to pull '
#              'off the reverse: their task is not to steal an idea but to plant '
#              'one. If they succeed, it could be the perfect crime. But no '
#              'amount of careful planning or expertise can prepare the team for '
#              'the dangerous enemy that seems to predict their every move. An '
#              'enemy that only Cobb could have seen coming.',
#  'genres': ['Action', 'Mystery', 'Sci-Fi'],
#  'imdb': {'id': 1375666, 'rating': 8.8, 'votes': 1294646},
#  'languages': ['English', 'Japanese', 'French'],
#  'lastupdated': '2015-09-12 00:29:01.430000000',
#  'metacritic': 74,
#  'num_mflix_comments': 1,
#  'plot': 'A thief who steals corporate secrets through use of dream-sharing '
#          'technology is given the inverse task of planting an idea into the '
#          'mind of a CEO.',
#  'poster': 'https://m.media-amazon.com/images/M/MV5BMjAxMzY3NjcxNF5BMl5BanBnXkFtZTcwNTI5OTM0Mw@@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2010, 7, 16, 0, 0),
#  'runtime': 148,
#  'title': 'Inception',
#  'tomatoes': {'boxOffice': '$292.6M',
#               'consensus': 'Smart, innovative, and thrilling, Inception is '
#                            'that rare summer blockbuster that succeeds '
#                            'viscerally as well as intellectually.',
#               'critic': {'meter': 86, 'numReviews': 326, 'rating': 8.1},
#               'dvd': datetime.datetime(2010, 12, 7, 0, 0),
#               'fresh': 281,
#               'lastUpdated': datetime.datetime(2015, 9, 12, 17, 13, 32),
#               'production': 'Warner Bros. Pictures',
#               'rotten': 45,
#               'viewer': {'meter': 91, 'numReviews': 561365, 'rating': 4.2},
#               'website': 'http://inceptionmovie.warnerbros.com/'},
#  'type': 'movie',
#  'writers': ['Christopher Nolan'],
#  'year': 2010}
# {'_id': ObjectId('573a13b9f29313caabd4ddff'),
#  'awards': {'nominations': 100,
#             'text': 'Won 1 Oscar. Another 44 wins & 100 nominations.',
#             'wins': 45},
#  'cast': ['Ellen Burstyn',
#           'Matthew McConaughey',
#           'Mackenzie Foy',
#           'John Lithgow'],
#  'countries': ['USA', 'UK', 'Canada'],
#  'directors': ['Christopher Nolan'],
#  'fullplot': 'In the near future, Earth has been devastated by drought and '
#              'famine, causing a scarcity in food and extreme changes in '
#              'climate. When humanity is facing extinction, a mysterious rip in '
#              'the space-time continuum is discovered, giving mankind the '
#              'opportunity to widen its lifespan. A group of explorers must '
#              'travel beyond our solar system in search of a planet that can '
#              'sustain life. The crew of the Endurance are required to think '
#              'bigger and go further than any human in history as they embark '
#              'on an interstellar voyage into the unknown. Coop, the pilot of '
#              'the Endurance, must decide between seeing his children again and '
#              'the future of the human race.',
#  'genres': ['Adventure', 'Drama', 'Sci-Fi'],
#  'imdb': {'id': 816692, 'rating': 8.7, 'votes': 699518},
#  'languages': ['English'],
#  'lastupdated': '2015-08-18 00:04:49.173000000',
#  'metacritic': 74,
#  'num_mflix_comments': 1,
#  'plot': 'A team of explorers travel through a wormhole in space in an attempt '
#          "to ensure humanity's survival.",
#  'poster': 'https://m.media-amazon.com/images/M/MV5BZjdkOTU3MDktN2IxOS00OGEyLWFmMjktY2FiMmZkNWIyODZiXkEyXkFqcGdeQXVyMTMxODk2OTU@._V1_SY1000_SX677_AL_.jpg',
#  'rated': 'PG-13',
#  'released': datetime.datetime(2014, 11, 7, 0, 0),
#  'runtime': 169,
#  'title': 'Interstellar',
#  'tomatoes': {'consensus': 'Interstellar represents more of the thrilling, '
#                            'thought-provoking, and visually resplendent '
#                            'filmmaking moviegoers have come to expect from '
#                            'writer-director Christopher Nolan, even if its '
#                            'intellectual reach somewhat exceeds its grasp.',
#               'critic': {'meter': 72, 'numReviews': 293, 'rating': 7.0},
#               'dvd': datetime.datetime(2015, 3, 31, 0, 0),
#               'fresh': 210,
#               'lastUpdated': datetime.datetime(2015, 9, 10, 17, 8, 37),
#               'production': 'Paramount Pictures',
#               'rotten': 83,
#               'viewer': {'meter': 85, 'numReviews': 163082, 'rating': 4.1},
#               'website': 'http://www.InterstellarMovie.com/'},
#  'type': 'movie',
#  'writers': ['Jonathan Nolan', 'Christopher Nolan'],
#  'year': 2014}
